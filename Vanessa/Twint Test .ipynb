# %%
pip install --user --upgrade git+https://github.com/twintproject/twint.git@origin/master#egg=twint
# Out:
# Collecting twint
#   Cloning https://github.com/twintproject/twint.git (to revision origin/master) to /private/var/folders/pj/v81nvr7n4172178fbf37vsym0000gp/T/pip-install-quhontzj/twint_287103b3a09947ef9b332d03ca0fa7de
#   Running command git clone -q https://github.com/twintproject/twint.git /private/var/folders/pj/v81nvr7n4172178fbf37vsym0000gp/T/pip-install-quhontzj/twint_287103b3a09947ef9b332d03ca0fa7de
#   WARNING: Did not find branch or tag 'origin/master', assuming revision or ref.
#   Running command git checkout -q origin/master
#   Resolved https://github.com/twintproject/twint.git to commit origin/master
# Requirement already satisfied: aiohttp in /opt/anaconda3/envs/moon/lib/python3.9/site-packages (from twint) (3.8.1)
# Collecting aiodns
#   Downloading aiodns-3.0.0-py3-none-any.whl (5.0 kB)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/moon/lib/python3.9/site-packages (from twint) (4.11.1)
# Collecting cchardet
#   Downloading cchardet-2.1.7-cp39-cp39-macosx_10_9_x86_64.whl (124 kB)
#      |████████████████████████████████| 124 kB 4.2 MB/s eta 0:00:01
# Collecting dataclasses
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Collecting elasticsearch
#   Downloading elasticsearch-8.3.1-py3-none-any.whl (382 kB)
#      |████████████████████████████████| 382 kB 27.0 MB/s eta 0:00:01
# Requirement already satisfied: pysocks in /opt/anaconda3/envs/moon/lib/python3.9/site-packages (from twint) (1.7.1)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/moon/lib/python3.9/site-packages (from twint) (1.4.2)
# Collecting aiohttp_socks
#   Downloading aiohttp_socks-0.7.1-py3-none-any.whl (9.3 kB)
# Collecting schedule
#   Downloading schedule-1.1.0-py2.py3-none-any.whl (10 kB)
# Collecting geopy
#   Downloading geopy-2.2.0-py3-none-any.whl (118 kB)
#      |████████████████████████████████| 118 kB 101.2 MB/s eta 0:00:01
# Collecting fake-useragent
#   Downloading fake-useragent-0.1.11.tar.gz (13 kB)
# Collecting googletransx
#   Downloading googletransx-2.4.2.tar.gz (13 kB)
# Collecting pycares>=4.0.0
#   Downloading pycares-4.2.1-cp39-cp39-macosx_10_9_x86_64.whl (75 kB)
#      |████████████████████████████████| 75 kB 5.9 MB/s eta 0:00:011
# Requirement already satisfied: cffi>=1.5.0 in /opt/anaconda3/envs/moon/lib/python3.9/site-packages (from pycares>=4.0.0->aiodns->twint) (1.15.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/moon/lib/python3.9/site-packages (from cffi>=1.5.0->pycares>=4.0.0->aiodns->twint) (2.21)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/moon/lib/python3.9/site-packages (from aiohttp->twint) (21.4.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /opt/anaconda3/envs/moon/lib/python3.9/site-packages (from aiohttp->twint) (2.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/envs/moon/lib/python3.9/site-packages (from aiohttp->twint) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/anaconda3/envs/moon/lib/python3.9/site-packages (from aiohttp->twint) (4.0.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/envs/moon/lib/python3.9/site-packages (from aiohttp->twint) (1.6.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/envs/moon/lib/python3.9/site-packages (from aiohttp->twint) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/envs/moon/lib/python3.9/site-packages (from aiohttp->twint) (5.2.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in /opt/anaconda3/envs/moon/lib/python3.9/site-packages (from async-timeout<5.0,>=4.0.0a3->aiohttp->twint) (4.1.1)
# Requirement already satisfied: idna>=2.0 in /opt/anaconda3/envs/moon/lib/python3.9/site-packages (from yarl<2.0,>=1.0->aiohttp->twint) (3.3)
# Collecting python-socks[asyncio]<3.0.0,>=2.0.0
#   Downloading python_socks-2.0.3-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 2.4 MB/s eta 0:00:01
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/moon/lib/python3.9/site-packages (from beautifulsoup4->twint) (2.3.1)
# Collecting elastic-transport<9,>=8
#   Downloading elastic_transport-8.1.2-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 18.1 MB/s eta 0:00:01
# Requirement already satisfied: urllib3<2,>=1.26.2 in /opt/anaconda3/envs/moon/lib/python3.9/site-packages (from elastic-transport<9,>=8->elasticsearch->twint) (1.26.9)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/moon/lib/python3.9/site-packages (from elastic-transport<9,>=8->elasticsearch->twint) (2021.10.8)
# Collecting geographiclib<2,>=1.49
#   Downloading geographiclib-1.52-py3-none-any.whl (38 kB)
# Requirement already satisfied: requests in /opt/anaconda3/envs/moon/lib/python3.9/site-packages (from googletransx->twint) (2.27.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/anaconda3/envs/moon/lib/python3.9/site-packages (from pandas->twint) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/moon/lib/python3.9/site-packages (from pandas->twint) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in /opt/anaconda3/envs/moon/lib/python3.9/site-packages (from pandas->twint) (1.21.5)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/moon/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->twint) (1.16.0)
# Building wheels for collected packages: twint, fake-useragent, googletransx
#   Building wheel for twint (setup.py) ... done
#   Created wheel for twint: filename=twint-2.1.21-py3-none-any.whl size=38869 sha256=f5eb9498359e04c2c9faa870826e412baada234fcacfb94240303428a721576e
#   Stored in directory: /private/var/folders/pj/v81nvr7n4172178fbf37vsym0000gp/T/pip-ephem-wheel-cache-ar1rakkr/wheels/d8/d2/0f/7a146624472827e7ae5427bb9df38249a490ef724626ad56ba
#   Building wheel for fake-useragent (setup.py) ... done
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13502 sha256=6fb8ee5cfdfa354cbdd7ac71054850259d190d9720e405acb0b99264d3dc0f11
#   Stored in directory: /Users/vanessaantworth/Library/Caches/pip/wheels/ae/e7/76/7dd44644d065268ab0e1b4fa2e802fa4bb0157717b7d6c6d92
#   Building wheel for googletransx (setup.py) ... done
#   Created wheel for googletransx: filename=googletransx-2.4.2-py3-none-any.whl size=15968 sha256=753fd7760d18d863ff918095fea98e094ebbd456aa8e810dc928921da923886b
#   Stored in directory: /Users/vanessaantworth/Library/Caches/pip/wheels/b5/28/37/a905af06d6f6c934042babb4748f01b2f9039d2d96f05a4496
# Successfully built twint fake-useragent googletransx
# Installing collected packages: python-socks, pycares, geographiclib, elastic-transport, schedule, googletransx, geopy, fake-useragent, elasticsearch, dataclasses, cchardet, aiohttp-socks, aiodns, twint
#   WARNING: The script twint is installed in '/Users/vanessaantworth/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed aiodns-3.0.0 aiohttp-socks-0.7.1 cchardet-2.1.7 dataclasses-0.6 elastic-transport-8.1.2 elasticsearch-8.3.1 fake-useragent-0.1.11 geographiclib-1.52 geopy-2.2.0 googletransx-2.4.2 pycares-4.2.1 python-socks-2.0.3 schedule-1.1.0 twint-2.1.21
# Note: you may need to restart the kernel to use updated packages.

# %%
import twint

import nest_asyncio
nest_asyncio.apply()

# %%
c = twint.Config()
c.Store_object = True
c.Pandas =True
#c.Search = "dogecoin"
c.Username = "elonmusk"
c.Limit = 100000
c.Lang = 'en'

# %%
# Run
twint.run.Search(c)
# Out:
# 1545485800833372160 2022-07-08 14:11:43 -0500 <elonmusk> @WholeMarsBlog Future wars are all about the drones. Human crews of planes or tanks have no chance.  One exception: a purely analog, human-controlled vehicle is far more resilient to EMF weapons.
# 1545457074389151744 2022-07-08 12:17:34 -0500 <elonmusk> @greg_price11 Whoever controls the teleprompter is the real President!  https://t.co/1rcqmwLe9S
# 1545454408237867010 2022-07-08 12:06:58 -0500 <elonmusk> @ScottAdamsSays @NickCannon We know so little today. I want to know the meaning of life or whatever the right question is to ask, as Douglas Adams would put it.   Wait … are you guys related?
# 1545453113888215040 2022-07-08 12:01:50 -0500 <elonmusk> @ScottAdamsSays @NickCannon But sponges &amp; starfish obv can  https://t.co/v7Bbz7vstW
# 1545451741780463617 2022-07-08 11:56:23 -0500 <elonmusk> @ScottAdamsSays @NickCannon Consciousness can understand the nature of the Universe. Clams, not so much.
# 1545432981241679872 2022-07-08 10:41:50 -0500 <elonmusk> @Andst7 Interesting. Who is behind the bot attack?
# 1545428479830659073 2022-07-08 10:23:56 -0500 <elonmusk> @BLKMDL3 @NickCannon Kids are worth it if at all possible. I’m planning to increase childcare benefits at my companies significantly.  Hopefully, other companies do same.  Also, Musk Foundation plans to donate directly to families.  Hopefully, details to be announced next month.
# 1545424964546748416 2022-07-08 10:09:58 -0500 <elonmusk> @sm Agreed, this needs to be addressed
# 1545420831299227649 2022-07-08 09:53:33 -0500 <elonmusk> @Liv_Boeree The world has gone mad
# 1545419348277202945 2022-07-08 09:47:39 -0500 <elonmusk> @hiromichimizuno Terrible news
# 1545208079331074054 2022-07-07 19:48:09 -0500 <elonmusk> @slashdot Great!
# 1545188187085029376 2022-07-07 18:29:06 -0500 <elonmusk> @BillyM2k @slashdot That is indeed the real question
# 1545176999043379200 2022-07-07 17:44:39 -0500 <elonmusk> @BillyM2k I had same great experience from Tokyo to Osaka
# 1545172331093377024 2022-07-07 17:26:06 -0500 <elonmusk> @BillyM2k China &amp; Japan have awesome trains.   Took bullet train from Beijing to Xi’an to see Terracotta Army of 秦始皇.
# 1545166492408328193 2022-07-07 17:02:54 -0500 <elonmusk> Super fired up for future product development with our awesome Tesla team! Such an honor to work with them.
# 1544244210659999745 2022-07-05 03:58:05 -0500 <elonmusk> @archillect I knew it!
# 1544243943315054593 2022-07-05 03:57:01 -0500 <elonmusk> @slashdot Good
# 1544059562864640011 2022-07-04 15:44:21 -0500 <elonmusk> Elvis is just Elvish without an h
# 1544052094419832836 2022-07-04 15:14:41 -0500 <elonmusk> Happy July 4th!  https://t.co/KYN2XO712Z
# 1544051155562598401 2022-07-04 15:10:57 -0500 <elonmusk>  https://t.co/sUrsfucQ2F
# 1543060584509366272 2022-07-01 21:34:46 -0500 <elonmusk> @ResortsWorldLV @boringcompany @Vegas Great work!
# 1543051486980186112 2022-07-01 20:58:37 -0500 <elonmusk> @The_Taterade My suit is tragic
# 1543051160935874561 2022-07-01 20:57:19 -0500 <elonmusk> @BitcoinStripper Talulah designed that dress herself and much of my 40th birthday party. She is a party genius. ♥️
# 1543050489050402816 2022-07-01 20:54:39 -0500 <elonmusk> Honored to meet @Pontifex yesterday  https://t.co/sLZY8mAQtd
# 1543047940683464705 2022-07-01 20:44:32 -0500 <elonmusk> Venice, a site of Great Remembrance  https://t.co/GWR3xqsoQW
# 1543046762021228544 2022-07-01 20:39:51 -0500 <elonmusk> Feeling … perhaps … a little bored?
# 1543046254397009922 2022-07-01 20:37:50 -0500 <elonmusk> Wise words from SJM  https://t.co/snVNttsvn1
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %%
twint.storage.panda.Tweets_df.head()
# Out:
#                     id      conversation_id    created_at  \
# 0  1545485800833372160  1545120731406614528  1.657308e+12
# 1  1545457074389151744  1545441526133788673  1.657301e+12
# 2  1545454408237867010  1545046146548019201  1.657300e+12
# 3  1545453113888215040  1545046146548019201  1.657300e+12
# 4  1545451741780463617  1545046146548019201  1.657299e+12
#
#                   date timezone place  \
# 0  2022-07-08 14:11:43    -0500
# 1  2022-07-08 12:17:34    -0500
# 2  2022-07-08 12:06:58    -0500
# 3  2022-07-08 12:01:50    -0500
# 4  2022-07-08 11:56:23    -0500
#
#                                                tweet language hashtags  \
# 0  @WholeMarsBlog Future wars are all about the d...       en       []
# 1  @greg_price11 Whoever controls the teleprompte...       en       []
# 2  @ScottAdamsSays @NickCannon We know so little ...       en       []
# 3  @ScottAdamsSays @NickCannon But sponges &amp; ...       en       []
# 4  @ScottAdamsSays @NickCannon Consciousness can ...       en       []
#
#   cashtags  ...  geo source user_rt_id user_rt  retweet_id  \
# 0       []  ...
# 1       []  ...
# 2       []  ...
# 3       []  ...
# 4       []  ...
#
#                                             reply_to retweet_date translate  \
# 0  [{'screen_name': 'WholeMarsBlog', 'name': 'Who...
# 1  [{'screen_name': 'greg_price11', 'name': 'Greg...
# 2  [{'screen_name': 'ScottAdamsSays', 'name': 'Sc...
# 3  [{'screen_name': 'ScottAdamsSays', 'name': 'Sc...
# 4  [{'screen_name': 'ScottAdamsSays', 'name': 'Sc...
#
#   trans_src  trans_dest
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 38 columns]
