# %%
#pip install pmdarima

# %%
# %matplotlib inline
import pandas as pd 
import matplotlib 
import matplotlib.pyplot as plt
import datetime
import numpy as np
from datetime import datetime, timedelta


from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm

from sklearn.preprocessing import StandardScaler
from pmdarima.arima.utils import ndiffs
from pmdarima import auto_arima

# %%
# Database related all the code is moved to this file
# %run -i "SqlConn.py"
#importing local py file
import SqlConn

# %%
#Fetch only Finance Data
try:
    df_dbFinanceData = SqlConn.fetchFinanceData("doge")
    print("Data transfer Done")
except BaseException as err:
    print(err)
# Out:
# Data transfer Done

# %%
df_dbFinanceData["date"] = pd.to_datetime(df_dbFinanceData["date"])
df_dbFinanceData.set_index("date", inplace=True)
df_dbFinanceData
# Out:
#            financeType      open      high       low     close  adjustedClose  \
# date
# 2017-11-09        doge  0.001207  0.001415  0.001181  0.001415       0.001415
# 2017-11-10        doge  0.001421  0.001431  0.001125  0.001163       0.001163
# 2017-11-11        doge  0.001146  0.001257  0.001141  0.001201       0.001201
# 2017-11-12        doge  0.001189  0.001210  0.001002  0.001038       0.001038
# 2017-11-13        doge  0.001046  0.001212  0.001019  0.001211       0.001211
# ...                ...       ...       ...       ...       ...            ...
# 2022-07-09        doge  0.069224  0.070009  0.068995  0.069512       0.069512
# 2022-07-10        doge  0.069509  0.069509  0.066533  0.067263       0.067263
# 2022-07-11        doge  0.067268  0.067268  0.061535  0.061847       0.061847
# 2022-07-12        doge  0.061851  0.062861  0.060087  0.060087       0.060087
# 2022-07-13        doge  0.060085  0.062011  0.058398  0.061953       0.061953
#
#                volume
# date
# 2017-11-09    6259550
# 2017-11-10    4246520
# 2017-11-11    2231080
# 2017-11-12    3288960
# 2017-11-13    2481270
# ...               ...
# 2022-07-09  254272147
# 2022-07-10  299810124
# 2022-07-11  326125900
# 2022-07-12  298462083
# 2022-07-13  446505400
#
# [1708 rows x 7 columns]

# %%
df_dbFinanceData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1708 entries, 2017-11-09 to 2022-07-13
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   financeType    1708 non-null   object
#  1   open           1708 non-null   float64
#  2   high           1708 non-null   float64
#  3   low            1708 non-null   float64
#  4   close          1708 non-null   float64
#  5   adjustedClose  1708 non-null   float64
#  6   volume         1708 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 106.8+ KB

# %%
df_dbFinanceData['adjustedClose'].plot(figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_dbFinanceData.index
# Out:
# DatetimeIndex(['2017-11-09', '2017-11-10', '2017-11-11', '2017-11-12',
#                '2017-11-13', '2017-11-14', '2017-11-15', '2017-11-16',
#                '2017-11-17', '2017-11-18',
#                ...
#                '2022-07-04', '2022-07-05', '2022-07-06', '2022-07-07',
#                '2022-07-08', '2022-07-09', '2022-07-10', '2022-07-11',
#                '2022-07-12', '2022-07-13'],
#               dtype='datetime64[ns]', name='date', length=1708, freq=None)

# %%
df_dbFinanceData['adjustedClose'].plot(xlim=['2020-01-01','2022-07-13'],ylim=[0,1400],figsize=(12,4),ls='--',c='green')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
#Resampling to display monthly data
df_resampled = df_dbFinanceData['adjustedClose'].resample(rule='M')
df_resampled.max().plot(kind='bar',figsize=(16,5))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_filteredData = df_dbFinanceData.loc['2020-01-01':'2022-7-13']
df_filteredData.index
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2022-07-04', '2022-07-05', '2022-07-06', '2022-07-07',
#                '2022-07-08', '2022-07-09', '2022-07-10', '2022-07-11',
#                '2022-07-12', '2022-07-13'],
#               dtype='datetime64[ns]', name='date', length=925, freq=None)

# %%
#Nov 2021 was the month when Tesla had highest value - checked over internet and found Nov 4 2021 was marked as highest price for Tesla stocks.
df_filteredData['adjustedClose'].resample(rule='M').max().plot(kind='bar', figsize=(16,4))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_filteredData['adjustedClose'].plot(xlim=['2021-11-01','2021-11-30'],ylim=[0,1300],figsize=(12,4),ls='--',c='green')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# checked over internet and found Nov 4 2021 was marked as highest price for Tesla stocks.
df_filteredData.loc['2021-11-01':'2021-11-30']['adjustedClose'].plot(kind='bar',figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
#5 and 15 days rolling mean
df_dbFinanceData["adjustedClose:5 Days Rolling mean"]=df_dbFinanceData['adjustedClose'].rolling(5).mean() 
df_dbFinanceData["adjustedClose:15 Days Rolling mean"]=df_dbFinanceData['adjustedClose'].rolling(15).mean() 
df_dbFinanceData["adjustedClose:60 Days Rolling mean"]=df_dbFinanceData['adjustedClose'].rolling(60).mean() 
df_dbFinanceData
# Out:
#            financeType      open      high       low     close  adjustedClose  \
# date
# 2017-11-09        doge  0.001207  0.001415  0.001181  0.001415       0.001415
# 2017-11-10        doge  0.001421  0.001431  0.001125  0.001163       0.001163
# 2017-11-11        doge  0.001146  0.001257  0.001141  0.001201       0.001201
# 2017-11-12        doge  0.001189  0.001210  0.001002  0.001038       0.001038
# 2017-11-13        doge  0.001046  0.001212  0.001019  0.001211       0.001211
# ...                ...       ...       ...       ...       ...            ...
# 2022-07-09        doge  0.069224  0.070009  0.068995  0.069512       0.069512
# 2022-07-10        doge  0.069509  0.069509  0.066533  0.067263       0.067263
# 2022-07-11        doge  0.067268  0.067268  0.061535  0.061847       0.061847
# 2022-07-12        doge  0.061851  0.062861  0.060087  0.060087       0.060087
# 2022-07-13        doge  0.060085  0.062011  0.058398  0.061953       0.061953
#
#                volume  adjustedClose:5 Days Rolling mean  \
# date
# 2017-11-09    6259550                                NaN
# 2017-11-10    4246520                                NaN
# 2017-11-11    2231080                                NaN
# 2017-11-12    3288960                                NaN
# 2017-11-13    2481270                           0.001206
# ...               ...                                ...
# 2022-07-09  254272147                           0.069026
# 2022-07-10  299810124                           0.069047
# 2022-07-11  326125900                           0.067700
# 2022-07-12  298462083                           0.065593
# 2022-07-13  446505400                           0.064132
#
#             adjustedClose:15 Days Rolling mean  \
# date
# 2017-11-09                                 NaN
# 2017-11-10                                 NaN
# 2017-11-11                                 NaN
# 2017-11-12                                 NaN
# 2017-11-13                                 NaN
# ...                                        ...
# 2022-07-09                            0.068672
# 2022-07-10                            0.068589
# 2022-07-11                            0.067834
# 2022-07-12                            0.067024
# 2022-07-13                            0.066757
#
#             adjustedClose:60 Days Rolling mean
# date
# 2017-11-09                                 NaN
# 2017-11-10                                 NaN
# 2017-11-11                                 NaN
# 2017-11-12                                 NaN
# 2017-11-13                                 NaN
# ...                                        ...
# 2022-07-09                            0.074572
# 2022-07-10                            0.074284
# 2022-07-11                            0.073937
# 2022-07-12                            0.073466
# 2022-07-13                            0.073002
#
# [1708 rows x 10 columns]

# %%
#smoothening the line
df_dbFinanceData[['adjustedClose','adjustedClose:5 Days Rolling mean','adjustedClose:15 Days Rolling mean']].plot(figsize=(16,5))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
#smoothening the line
df_dbFinanceData.loc['2020-01-01':'2022-7-13'][['adjustedClose','adjustedClose:5 Days Rolling mean','adjustedClose:15 Days Rolling mean','adjustedClose:60 Days Rolling mean']].plot(figsize=(16,5))

#rolling mean of 5 days is closer compared to 15 days
# Out:
# <AxesSubplot:xlabel='date'>

# %%
#Cummulative moving average
df_dbFinanceData['adjustedClose'].expanding().mean().plot(figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
#exponential weighted moving average
df_dbFinanceData['emw0.2']=df_dbFinanceData['adjustedClose'].ewm(alpha=0.2,adjust=False).mean()
df_dbFinanceData['emw0.4']=df_dbFinanceData['adjustedClose'].ewm(alpha=0.4,adjust=False).mean()
df_dbFinanceData['emw_span5']=df_dbFinanceData['adjustedClose'].ewm(span=2,).mean()

# %%
df_dbFinanceData[['adjustedClose','emw0.2','emw0.4','emw_span5']].plot(xlim=['2021-01-01','2022-7-13'],figsize=(16,5))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_dbFinanceData[['adjustedClose','emw0.2','emw0.4','emw_span5']].plot(xlim=['2021-11-01','2022-7-13'],figsize=(16,5))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# # Applying ARIMA Model

# %%
#Augmented Dickey–Fuller test
def adf_test(series):
    results = adfuller(series)
    print('ADF statistics: {}'.format(results[0]))
    print('P value: {}'.format(results[1]))
    if results[1] < 0.05:
        print("Ho Rejected - data is stationary")
    else:    
        print("Ho Accepted- data is not stationary")

# %%
adf_test(df_dbFinanceData['adjustedClose'])
# Out:
# ADF statistics: -2.4187282724682215
# P value: 0.13652010989240942
# Ho Accepted- data is not stationary

# %%
df_dbFinanceData['adjustedClose_first_diff']=df_dbFinanceData['adjustedClose']-df_dbFinanceData['adjustedClose'].shift(1)

# %%
adf_test(df_dbFinanceData['adjustedClose_first_diff'].dropna())
#d=1
# Out:
# ADF statistics: -8.262922943789192
# P value: 5.02668207286967e-13
# Ho Rejected - data is stationary

# %%
df_dbFinanceData
# Out:
#            financeType      open      high       low     close  adjustedClose  \
# date
# 2017-11-09        doge  0.001207  0.001415  0.001181  0.001415       0.001415
# 2017-11-10        doge  0.001421  0.001431  0.001125  0.001163       0.001163
# 2017-11-11        doge  0.001146  0.001257  0.001141  0.001201       0.001201
# 2017-11-12        doge  0.001189  0.001210  0.001002  0.001038       0.001038
# 2017-11-13        doge  0.001046  0.001212  0.001019  0.001211       0.001211
# ...                ...       ...       ...       ...       ...            ...
# 2022-07-09        doge  0.069224  0.070009  0.068995  0.069512       0.069512
# 2022-07-10        doge  0.069509  0.069509  0.066533  0.067263       0.067263
# 2022-07-11        doge  0.067268  0.067268  0.061535  0.061847       0.061847
# 2022-07-12        doge  0.061851  0.062861  0.060087  0.060087       0.060087
# 2022-07-13        doge  0.060085  0.062011  0.058398  0.061953       0.061953
#
#                volume  adjustedClose:5 Days Rolling mean  \
# date
# 2017-11-09    6259550                                NaN
# 2017-11-10    4246520                                NaN
# 2017-11-11    2231080                                NaN
# 2017-11-12    3288960                                NaN
# 2017-11-13    2481270                           0.001206
# ...               ...                                ...
# 2022-07-09  254272147                           0.069026
# 2022-07-10  299810124                           0.069047
# 2022-07-11  326125900                           0.067700
# 2022-07-12  298462083                           0.065593
# 2022-07-13  446505400                           0.064132
#
#             adjustedClose:15 Days Rolling mean  \
# date
# 2017-11-09                                 NaN
# 2017-11-10                                 NaN
# 2017-11-11                                 NaN
# 2017-11-12                                 NaN
# 2017-11-13                                 NaN
# ...                                        ...
# 2022-07-09                            0.068672
# 2022-07-10                            0.068589
# 2022-07-11                            0.067834
# 2022-07-12                            0.067024
# 2022-07-13                            0.066757
#
#             adjustedClose:60 Days Rolling mean    emw0.2    emw0.4  emw_span5  \
# date
# 2017-11-09                                 NaN  0.001415  0.001415   0.001415
# 2017-11-10                                 NaN  0.001365  0.001314   0.001226
# 2017-11-11                                 NaN  0.001332  0.001269   0.001209
# 2017-11-12                                 NaN  0.001273  0.001177   0.001093
# 2017-11-13                                 NaN  0.001261  0.001190   0.001172
# ...                                        ...       ...       ...        ...
# 2022-07-09                            0.074572  0.068662  0.069292   0.069492
# 2022-07-10                            0.074284  0.068382  0.068480   0.068006
# 2022-07-11                            0.073937  0.067075  0.065827   0.063900
# 2022-07-12                            0.073466  0.065677  0.063531   0.061358
# 2022-07-13                            0.073002  0.064933  0.062900   0.061755
#
#             adjustedClose_first_diff
# date
# 2017-11-09                       NaN
# 2017-11-10                 -0.000252
# 2017-11-11                  0.000038
# 2017-11-12                 -0.000163
# 2017-11-13                  0.000173
# ...                              ...
# 2022-07-09                  0.000255
# 2022-07-10                 -0.002249
# 2022-07-11                 -0.005416
# 2022-07-12                 -0.001760
# 2022-07-13                  0.001866
#
# [1708 rows x 14 columns]

# %% [markdown]
# # Calculate AR(p), I(d), MA(q)

# %%
#Estimate ARIMA differencing term,
ndiffs(df_dbFinanceData['adjustedClose'],test='adf')
# Out:
# 1

# %%
diff= df_dbFinanceData['adjustedClose'].diff().dropna()
fig,(ax1,ax2)=plt.subplots(1, 2, figsize=(16,4))
ax1.plot(diff)
ax1.set_title("Difference once")
ax2.set_ylim(0, 1)
plot_pacf(diff, ax=ax2)
#p=2

# %%
diff= df_dbFinanceData['adjustedClose'].diff().dropna()
fig,(ax1,ax2)=plt.subplots(1, 2, figsize=(16,4))
ax1.plot(diff)
ax1.set_title("Difference once")
ax2.set_ylim(0, 1)
plot_acf(diff, ax=ax2)
#q=2

# %% [markdown]
# #Other ways to find P and Q

# %%
acf = plot_acf(df_dbFinanceData['adjustedClose_first_diff'].dropna())
#q=2

# %%
acf = plot_pacf(df_dbFinanceData['adjustedClose_first_diff'].dropna())
#p=2

# %% [markdown]
# third way to find p,d,q- using Auto_arima

# %%
stepwise_fit = auto_arima(df_dbFinanceData['adjustedClose'],trace=True,suppress_warnings=True)
stepwise_fit.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-10143.695, Time=1.47 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-10089.563, Time=0.21 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-10116.741, Time=0.24 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-10111.709, Time=0.13 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-10091.550, Time=0.07 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-10141.994, Time=1.13 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-10123.208, Time=0.78 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=-10180.791, Time=1.47 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=-10132.767, Time=0.34 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=-10176.230, Time=1.84 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=-10205.557, Time=1.62 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=-10185.604, Time=0.96 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=-10201.790, Time=1.85 sec
#  ARIMA(3,1,4)(0,0,0)[0] intercept   : AIC=-10208.380, Time=1.96 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=-10197.147, Time=1.65 sec
#  ARIMA(4,1,4)(0,0,0)[0] intercept   : AIC=-10214.937, Time=2.12 sec
#  ARIMA(5,1,4)(0,0,0)[0] intercept   : AIC=-10307.308, Time=2.17 sec
#  ARIMA(5,1,3)(0,0,0)[0] intercept   : AIC=-10247.296, Time=0.56 sec
#  ARIMA(5,1,5)(0,0,0)[0] intercept   : AIC=-10285.139, Time=2.86 sec
#  ARIMA(4,1,5)(0,0,0)[0] intercept   : AIC=-10262.686, Time=2.46 sec
#  ARIMA(5,1,4)(0,0,0)[0]             : AIC=-10314.363, Time=1.26 sec
#  ARIMA(4,1,4)(0,0,0)[0]             : AIC=-10214.019, Time=1.11 sec
#  ARIMA(5,1,3)(0,0,0)[0]             : AIC=-10249.273, Time=0.83 sec
#  ARIMA(5,1,5)(0,0,0)[0]             : AIC=-10309.138, Time=1.64 sec
#  ARIMA(4,1,3)(0,0,0)[0]             : AIC=-10206.602, Time=1.00 sec
#  ARIMA(4,1,5)(0,0,0)[0]             : AIC=-10269.199, Time=1.32 sec
#
# Best model:  ARIMA(5,1,4)(0,0,0)[0]
# Total fit time: 33.056 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1708
# Model:               SARIMAX(5, 1, 4)   Log Likelihood                5167.181
# Date:                Mon, 18 Jul 2022   AIC                         -10314.363
# Time:                        23:10:59   BIC                         -10259.938
# Sample:                             0   HQIC                        -10294.219
#                                - 1708
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1542      0.019      8.109      0.000       0.117       0.191
# ar.L2         -0.2673      0.022    -12.261      0.000      -0.310      -0.225
# ar.L3          0.2423      0.018     13.807      0.000       0.208       0.277
# ar.L4         -0.4539      0.014    -32.965      0.000      -0.481      -0.427
# ar.L5         -0.3118      0.006    -51.617      0.000      -0.324      -0.300
# ma.L1         -0.3120      0.020    -15.309      0.000      -0.352      -0.272
# ma.L2          0.4247      0.024     17.394      0.000       0.377       0.473
# ma.L3         -0.2279      0.020    -11.287      0.000      -0.268      -0.188
# ma.L4          0.5620      0.016     35.087      0.000       0.531       0.593
# sigma2         0.0001    9.8e-07    141.263      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.24   Jarque-Bera (JB):            347371.26
# Prob(Q):                              0.62   Prob(JB):                         0.00
# Heteroskedasticity (H):            1682.79   Skew:                             2.91
# Prob(H) (two-sided):                  0.00   Kurtosis:                        72.64
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# # Fitting the Model and Predicting

# %%
df_arima = df_dbFinanceData.copy()
df_arima.drop(columns=['financeType'],inplace=True)
train_dataset_end=datetime(2021,7,31)
test_dataset_end=datetime(2022,7,31)

# %%
train_data=df_arima[:train_dataset_end]
test_data=df_arima[train_dataset_end+timedelta(days=1):test_dataset_end]

# %%
##prediction
pred_start_date=test_data.index[0]
pred_end_date=test_data.index[-1]

# %%
train_data
# Out:
#                 open      high       low     close  adjustedClose      volume  \
# date
# 2017-11-09  0.001207  0.001415  0.001181  0.001415       0.001415     6259550
# 2017-11-10  0.001421  0.001431  0.001125  0.001163       0.001163     4246520
# 2017-11-11  0.001146  0.001257  0.001141  0.001201       0.001201     2231080
# 2017-11-12  0.001189  0.001210  0.001002  0.001038       0.001038     3288960
# 2017-11-13  0.001046  0.001212  0.001019  0.001211       0.001211     2481270
# ...              ...       ...       ...       ...            ...         ...
# 2021-07-27  0.203836  0.209293  0.195350  0.205899       0.205899  2229903212
# 2021-07-28  0.206111  0.213746  0.202011  0.205392       0.205392  2076707890
# 2021-07-29  0.205591  0.206355  0.200716  0.204619       0.204619  1169322798
# 2021-07-30  0.205023  0.210643  0.196535  0.208821       0.208821  1523981522
# 2021-07-31  0.208638  0.214345  0.204897  0.208314       0.208314  1349212924
#
#             adjustedClose:5 Days Rolling mean  \
# date
# 2017-11-09                                NaN
# 2017-11-10                                NaN
# 2017-11-11                                NaN
# 2017-11-12                                NaN
# 2017-11-13                           0.001206
# ...                                       ...
# 2021-07-27                           0.200053
# 2021-07-28                           0.202179
# 2021-07-29                           0.203639
# 2021-07-30                           0.205830
# 2021-07-31                           0.206609
#
#             adjustedClose:15 Days Rolling mean  \
# date
# 2017-11-09                                 NaN
# 2017-11-10                                 NaN
# 2017-11-11                                 NaN
# 2017-11-12                                 NaN
# 2017-11-13                                 NaN
# ...                                        ...
# 2021-07-27                            0.189946
# 2021-07-28                            0.190305
# 2021-07-29                            0.190792
# 2021-07-30                            0.192387
# 2021-07-31                            0.194785
#
#             adjustedClose:60 Days Rolling mean    emw0.2    emw0.4  emw_span5  \
# date
# 2017-11-09                                 NaN  0.001415  0.001415   0.001415
# 2017-11-10                                 NaN  0.001365  0.001314   0.001226
# 2017-11-11                                 NaN  0.001332  0.001269   0.001209
# 2017-11-12                                 NaN  0.001273  0.001177   0.001093
# 2017-11-13                                 NaN  0.001261  0.001190   0.001172
# ...                                        ...       ...       ...        ...
# 2021-07-27                            0.260664  0.196998  0.201501   0.204602
# 2021-07-28                            0.259035  0.198677  0.203057   0.205129
# 2021-07-29                            0.257408  0.199865  0.203682   0.204789
# 2021-07-30                            0.255458  0.201656  0.205738   0.207477
# 2021-07-31                            0.252762  0.202988  0.206768   0.208035
#
#             adjustedClose_first_diff
# date
# 2017-11-09                       NaN
# 2017-11-10                 -0.000252
# 2017-11-11                  0.000038
# 2017-11-12                 -0.000163
# 2017-11-13                  0.000173
# ...                              ...
# 2021-07-27                  0.001480
# 2021-07-28                 -0.000507
# 2021-07-29                 -0.000773
# 2021-07-30                  0.004202
# 2021-07-31                 -0.000507
#
# [1361 rows x 13 columns]

# %%
test_data
# Out:
#                 open      high       low     close  adjustedClose      volume  \
# date
# 2021-08-01  0.207753  0.217611  0.201389  0.204437       0.204437  1711494501
# 2021-08-02  0.204279  0.209959  0.202188  0.203600       0.203600  1181469976
# 2021-08-03  0.203431  0.205077  0.193750  0.195967       0.195967  1121632377
# 2021-08-04  0.196312  0.203110  0.194450  0.201490       0.201490  1095300718
# 2021-08-05  0.201575  0.202513  0.194685  0.200974       0.200974  1139204754
# ...              ...       ...       ...       ...            ...         ...
# 2022-07-09  0.069224  0.070009  0.068995  0.069512       0.069512   254272147
# 2022-07-10  0.069509  0.069509  0.066533  0.067263       0.067263   299810124
# 2022-07-11  0.067268  0.067268  0.061535  0.061847       0.061847   326125900
# 2022-07-12  0.061851  0.062861  0.060087  0.060087       0.060087   298462083
# 2022-07-13  0.060085  0.062011  0.058398  0.061953       0.061953   446505400
#
#             adjustedClose:5 Days Rolling mean  \
# date
# 2021-08-01                           0.206317
# 2021-08-02                           0.205958
# 2021-08-03                           0.204228
# 2021-08-04                           0.202762
# 2021-08-05                           0.201294
# ...                                       ...
# 2022-07-09                           0.069026
# 2022-07-10                           0.069047
# 2022-07-11                           0.067700
# 2022-07-12                           0.065593
# 2022-07-13                           0.064132
#
#             adjustedClose:15 Days Rolling mean  \
# date
# 2021-08-01                            0.196006
# 2021-08-02                            0.197430
# 2021-08-03                            0.198925
# 2021-08-04                            0.200970
# 2021-08-05                            0.201679
# ...                                        ...
# 2022-07-09                            0.068672
# 2022-07-10                            0.068589
# 2022-07-11                            0.067834
# 2022-07-12                            0.067024
# 2022-07-13                            0.066757
#
#             adjustedClose:60 Days Rolling mean    emw0.2    emw0.4  emw_span5  \
# date
# 2021-08-01                            0.249113  0.203278  0.205836   0.205636
# 2021-08-02                            0.245841  0.203342  0.204941   0.204279
# 2021-08-03                            0.242835  0.201867  0.201352   0.198738
# 2021-08-04                            0.239990  0.201792  0.201407   0.200573
# 2021-08-05                            0.237143  0.201628  0.201234   0.200840
# ...                                        ...       ...       ...        ...
# 2022-07-09                            0.074572  0.068662  0.069292   0.069492
# 2022-07-10                            0.074284  0.068382  0.068480   0.068006
# 2022-07-11                            0.073937  0.067075  0.065827   0.063900
# 2022-07-12                            0.073466  0.065677  0.063531   0.061358
# 2022-07-13                            0.073002  0.064933  0.062900   0.061755
#
#             adjustedClose_first_diff
# date
# 2021-08-01                 -0.003877
# 2021-08-02                 -0.000837
# 2021-08-03                 -0.007633
# 2021-08-04                  0.005523
# 2021-08-05                 -0.000516
# ...                              ...
# 2022-07-09                  0.000255
# 2022-07-10                 -0.002249
# 2022-07-11                 -0.005416
# 2022-07-12                 -0.001760
# 2022-07-13                  0.001866
#
# [347 rows x 13 columns]

# %%
startdate=datetime(2019,1,1)
plt.figure(figsize=(16,5))
plt.grid(True)
plt.xlabel("Date")
plt.ylabel("Adjusted Closing Price")
plt.plot(train_data[startdate:],'blue', label="training data")
plt.plot(test_data, 'green' , label="testing data")
#plt.legend(loc="upper left")
# Out:
# [<matplotlib.lines.Line2D at 0x171a36ba430>,
#  <matplotlib.lines.Line2D at 0x171a36ba3a0>,
#  <matplotlib.lines.Line2D at 0x171a36ba520>,
#  <matplotlib.lines.Line2D at 0x171a36ba640>,
#  <matplotlib.lines.Line2D at 0x171a36ba760>,
#  <matplotlib.lines.Line2D at 0x171a36ba880>,
#  <matplotlib.lines.Line2D at 0x171a36ba9a0>,
#  <matplotlib.lines.Line2D at 0x171a36baac0>,
#  <matplotlib.lines.Line2D at 0x171a36babe0>,
#  <matplotlib.lines.Line2D at 0x171a36bad00>,
#  <matplotlib.lines.Line2D at 0x171a36bae20>,
#  <matplotlib.lines.Line2D at 0x171a36baf40>,
#  <matplotlib.lines.Line2D at 0x171a36b50a0>]

# %% [markdown]
# # Train the ARIMA Model

# %% [raw]
# # - Scenario 1 - (p,d,q) = (2,1,2)

# %%
model_ARIMA=sm.tsa.arima.ARIMA(train_data['adjustedClose'],order=(2,1,2))
# Out:
# C:\Users\dantw\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\dantw\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\dantw\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'

# %%
model_ARIMA_fit = model_ARIMA.fit()
# Out:
# C:\Users\dantw\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\dantw\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\dantw\anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
model_ARIMA_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:          adjustedClose   No. Observations:                 1361
# Model:                 ARIMA(2, 1, 2)   Log Likelihood                4032.692
# Date:                Tue, 19 Jul 2022   AIC                          -8055.383
# Time:                        00:01:20   BIC                          -8029.307
# Sample:                    11-09-2017   HQIC                         -8045.622
#                          - 07-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5634      0.015     37.085      0.000       0.534       0.593
# ar.L2         -0.5131      0.016    -31.452      0.000      -0.545      -0.481
# ma.L1         -0.7111      0.014    -52.380      0.000      -0.738      -0.684
# ma.L2          0.7920      0.013     59.985      0.000       0.766       0.818
# sigma2         0.0002   1.12e-06    138.345      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):            281827.10
# Prob(Q):                              0.86   Prob(JB):                         0.00
# Heteroskedasticity (H):            1556.90   Skew:                             2.47
# Prob(H) (two-sided):                  0.00   Kurtosis:                        73.35
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
model_ARIMA_fit.resid.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
resids = pd.DataFrame(model_ARIMA_fit.resid)
fig, (ax1, ax2) = plt.subplots(1 ,2, figsize=(16,4))
ax1.plot(resids)
ax2.hist(resids, density=True)
# Out:
# (array([7.35192139e-02, 1.47038428e-01, 3.43089665e-01, 3.14662235e+01,
#         8.82230567e-01, 2.94076856e-01, 4.90128093e-02, 7.35192139e-02,
#         0.00000000e+00, 2.45064046e-02]),
#  array([-0.11424783, -0.08426571, -0.0542836 , -0.02430148,  0.00568063,
#          0.03566275,  0.06564486,  0.09562698,  0.1256091 ,  0.15559121,
#          0.18557333]),
#  <BarContainer object of 10 artists>)

# %%
##prediction
pred_start_date=pd.to_datetime(test_data.index[0])
pred_end_date=pd.to_datetime(test_data.index[-1])
print(pred_start_date)
print(pred_end_date)
# Out:
# 2021-08-01 00:00:00
# 2022-07-13 00:00:00

# %%
-len(train_data)
# Out:
# -1361

# %%
from statsmodels.graphics.tsaplots import plot_predict
adjustedCloseByArima_pred =model_ARIMA_fit.predict(start=len(train_data),end=(len(train_data) + len(test_data)-1)) 
adjustedCloseByArima_predictions = model_ARIMA_fit.get_prediction(start = -len(test_data))
residuals = test_data['adjustedClose']-adjustedCloseByArima_pred
print("Predicted Adjustclose Values")
print(adjustedCloseByArima_pred)
plot_predict(model_ARIMA_fit, start=1, end=60,dynamic=False)
# Out:
# Predicted Adjustclose Values
# 2021-08-01    0.205803
# 2021-08-02    0.205744
# 2021-08-03    0.206999
# 2021-08-04    0.207737
# 2021-08-05    0.207508
#                 ...
# 2022-07-09    0.207098
# 2022-07-10    0.207098
# 2022-07-11    0.207098
# 2022-07-12    0.207098
# 2022-07-13    0.207098
# Freq: D, Name: predicted_mean, Length: 347, dtype: float64

# %%
df_yPred = adjustedCloseByArima_predictions.summary_frame(alpha=0.10)

# Extract prediction mean
mean_forecast = adjustedCloseByArima_predictions.predicted_mean

# Get confidence intervals of predictions
confidence_intervals = adjustedCloseByArima_predictions.conf_int()
confidence_intervals
# Out:
#             lower adjustedClose  upper adjustedClose
# 2020-08-19            -0.020918             0.027972
# 2020-08-20            -0.021004             0.027886
# 2020-08-21            -0.021014             0.027876
# 2020-08-22            -0.021066             0.027824
# 2020-08-23            -0.021017             0.027874
# ...                         ...                  ...
# 2021-07-27             0.175247             0.224137
# 2021-07-28             0.181224             0.230114
# 2021-07-29             0.185014             0.233905
# 2021-07-30             0.183221             0.232111
# 2021-07-31             0.182485             0.231376
#
# [347 rows x 2 columns]

# %%
df_yPred.plot(figsize=(16,5))
# Out:
# <AxesSubplot:>

# %%
d1 = pd.DataFrame(test_data['adjustedClose'])
d2 = pd.DataFrame(mean_forecast)
d2['date'] = d1.index
d2.set_index('date',inplace=True)
df_y_yPred = pd.concat([d1,d2],axis=1)

# %%
df_y_yPred
# Out:
#             adjustedClose  predicted_mean
# date
# 2021-08-01       0.204437        0.003527
# 2021-08-02       0.203600        0.003441
# 2021-08-03       0.195967        0.003431
# 2021-08-04       0.201490        0.003379
# 2021-08-05       0.200974        0.003428
# ...                   ...             ...
# 2022-07-09       0.069512        0.199692
# 2022-07-10       0.067263        0.205669
# 2022-07-11       0.061847        0.209460
# 2022-07-12       0.060087        0.207666
# 2022-07-13       0.061953        0.206930
#
# [347 rows x 2 columns]

# %%
df_y_yPred.plot(figsize=(17,5))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# # Forecasting

# %%
step = 30
fc = model_ARIMA_fit.forecast(step)
lst_fc = list(fc)
lst_fc
# Out:
# [0.20580281278217094,
#  0.205743898086193,
#  0.20699923575610368,
#  0.20773674638540524,
#  0.20750813923219413,
#  0.2070009089340563,
#  0.2068324280490323,
#  0.2069977709685876,
#  0.2071773785394392,
#  0.20719373261626267,
#  0.20711078721941806,
#  0.20705566269919495,
#  0.20706716516380202,
#  0.2071019311602084,
#  0.20711561686456273,
#  0.2071054886419744,
#  0.20709275985433917,
#  0.20709078517616994,
#  0.20709620395532657,
#  0.2071002702357585,
#  0.20709978078923375,
#  0.2070974185508728,
#  0.207096338764984,
#  0.2070969424967849,
#  0.20709783670631243,
#  0.2070980307358725,
#  0.2070976812221679,
#  0.2070973847399161,
#  0.20709739703752275,
#  0.2070975560961232]

# %%
fc
# Out:
# 2021-08-01    0.205803
# 2021-08-02    0.205744
# 2021-08-03    0.206999
# 2021-08-04    0.207737
# 2021-08-05    0.207508
# 2021-08-06    0.207001
# 2021-08-07    0.206832
# 2021-08-08    0.206998
# 2021-08-09    0.207177
# 2021-08-10    0.207194
# 2021-08-11    0.207111
# 2021-08-12    0.207056
# 2021-08-13    0.207067
# 2021-08-14    0.207102
# 2021-08-15    0.207116
# 2021-08-16    0.207105
# 2021-08-17    0.207093
# 2021-08-18    0.207091
# 2021-08-19    0.207096
# 2021-08-20    0.207100
# 2021-08-21    0.207100
# 2021-08-22    0.207097
# 2021-08-23    0.207096
# 2021-08-24    0.207097
# 2021-08-25    0.207098
# 2021-08-26    0.207098
# 2021-08-27    0.207098
# 2021-08-28    0.207097
# 2021-08-29    0.207097
# 2021-08-30    0.207098
# Freq: D, Name: predicted_mean, dtype: float64

# %%
import time
import datetime
from datetime import date,timedelta


end_date = pred_end_date 

date_future = end_date + datetime.timedelta(41)

df_future_dates = pd.date_range(start=end_date, end=date_future,freq='B')
df_future_dates
# Out:
# DatetimeIndex(['2022-07-13', '2022-07-14', '2022-07-15', '2022-07-18',
#                '2022-07-19', '2022-07-20', '2022-07-21', '2022-07-22',
#                '2022-07-25', '2022-07-26', '2022-07-27', '2022-07-28',
#                '2022-07-29', '2022-08-01', '2022-08-02', '2022-08-03',
#                '2022-08-04', '2022-08-05', '2022-08-08', '2022-08-09',
#                '2022-08-10', '2022-08-11', '2022-08-12', '2022-08-15',
#                '2022-08-16', '2022-08-17', '2022-08-18', '2022-08-19',
#                '2022-08-22', '2022-08-23'],
#               dtype='datetime64[ns]', freq='B')

# %%
df_future_dates
# Out:
# DatetimeIndex(['2022-07-13', '2022-07-14', '2022-07-15', '2022-07-18',
#                '2022-07-19', '2022-07-20', '2022-07-21', '2022-07-22',
#                '2022-07-25', '2022-07-26', '2022-07-27', '2022-07-28',
#                '2022-07-29', '2022-08-01', '2022-08-02', '2022-08-03',
#                '2022-08-04', '2022-08-05', '2022-08-08', '2022-08-09',
#                '2022-08-10', '2022-08-11', '2022-08-12', '2022-08-15',
#                '2022-08-16', '2022-08-17', '2022-08-18', '2022-08-19',
#                '2022-08-22', '2022-08-23'],
#               dtype='datetime64[ns]', freq='B')

# %%
df_combine = pd.DataFrame(df_future_dates,lst_fc)
df_combine.columns=['date']
df_combine
# Out:
#                date
# 0.205803 2022-07-13
# 0.205744 2022-07-14
# 0.206999 2022-07-15
# 0.207737 2022-07-18
# 0.207508 2022-07-19
# 0.207001 2022-07-20
# 0.206832 2022-07-21
# 0.206998 2022-07-22
# 0.207177 2022-07-25
# 0.207194 2022-07-26
# 0.207111 2022-07-27
# 0.207056 2022-07-28
# 0.207067 2022-07-29
# 0.207102 2022-08-01
# 0.207116 2022-08-02
# 0.207105 2022-08-03
# 0.207093 2022-08-04
# 0.207091 2022-08-05
# 0.207096 2022-08-08
# 0.207100 2022-08-09
# 0.207100 2022-08-10
# 0.207097 2022-08-11
# 0.207096 2022-08-12
# 0.207097 2022-08-15
# 0.207098 2022-08-16
# 0.207098 2022-08-17
# 0.207098 2022-08-18
# 0.207097 2022-08-19
# 0.207097 2022-08-22
# 0.207098 2022-08-23

# %%
df_combine = df_combine.reset_index()
df_combine = df_combine.set_index('date')
df_combine
# Out:
#                index
# date
# 2022-07-13  0.205803
# 2022-07-14  0.205744
# 2022-07-15  0.206999
# 2022-07-18  0.207737
# 2022-07-19  0.207508
# 2022-07-20  0.207001
# 2022-07-21  0.206832
# 2022-07-22  0.206998
# 2022-07-25  0.207177
# 2022-07-26  0.207194
# 2022-07-27  0.207111
# 2022-07-28  0.207056
# 2022-07-29  0.207067
# 2022-08-01  0.207102
# 2022-08-02  0.207116
# 2022-08-03  0.207105
# 2022-08-04  0.207093
# 2022-08-05  0.207091
# 2022-08-08  0.207096
# 2022-08-09  0.207100
# 2022-08-10  0.207100
# 2022-08-11  0.207097
# 2022-08-12  0.207096
# 2022-08-15  0.207097
# 2022-08-16  0.207098
# 2022-08-17  0.207098
# 2022-08-18  0.207098
# 2022-08-19  0.207097
# 2022-08-22  0.207097
# 2022-08-23  0.207098

# %%
df_combine.rename(columns={"index":"forecasted_mean"},inplace=True)

# %%
df_combine
# Out:
#             forecasted_mean
# date
# 2022-07-13         0.205803
# 2022-07-14         0.205744
# 2022-07-15         0.206999
# 2022-07-18         0.207737
# 2022-07-19         0.207508
# 2022-07-20         0.207001
# 2022-07-21         0.206832
# 2022-07-22         0.206998
# 2022-07-25         0.207177
# 2022-07-26         0.207194
# 2022-07-27         0.207111
# 2022-07-28         0.207056
# 2022-07-29         0.207067
# 2022-08-01         0.207102
# 2022-08-02         0.207116
# 2022-08-03         0.207105
# 2022-08-04         0.207093
# 2022-08-05         0.207091
# 2022-08-08         0.207096
# 2022-08-09         0.207100
# 2022-08-10         0.207100
# 2022-08-11         0.207097
# 2022-08-12         0.207096
# 2022-08-15         0.207097
# 2022-08-16         0.207098
# 2022-08-17         0.207098
# 2022-08-18         0.207098
# 2022-08-19         0.207097
# 2022-08-22         0.207097
# 2022-08-23         0.207098

# %%
test_data
# Out:
#                 open      high       low     close  adjustedClose      volume  \
# date
# 2021-08-01  0.207753  0.217611  0.201389  0.204437       0.204437  1711494501
# 2021-08-02  0.204279  0.209959  0.202188  0.203600       0.203600  1181469976
# 2021-08-03  0.203431  0.205077  0.193750  0.195967       0.195967  1121632377
# 2021-08-04  0.196312  0.203110  0.194450  0.201490       0.201490  1095300718
# 2021-08-05  0.201575  0.202513  0.194685  0.200974       0.200974  1139204754
# ...              ...       ...       ...       ...            ...         ...
# 2022-07-09  0.069224  0.070009  0.068995  0.069512       0.069512   254272147
# 2022-07-10  0.069509  0.069509  0.066533  0.067263       0.067263   299810124
# 2022-07-11  0.067268  0.067268  0.061535  0.061847       0.061847   326125900
# 2022-07-12  0.061851  0.062861  0.060087  0.060087       0.060087   298462083
# 2022-07-13  0.060085  0.062011  0.058398  0.061953       0.061953   446505400
#
#             adjustedClose:5 Days Rolling mean  \
# date
# 2021-08-01                           0.206317
# 2021-08-02                           0.205958
# 2021-08-03                           0.204228
# 2021-08-04                           0.202762
# 2021-08-05                           0.201294
# ...                                       ...
# 2022-07-09                           0.069026
# 2022-07-10                           0.069047
# 2022-07-11                           0.067700
# 2022-07-12                           0.065593
# 2022-07-13                           0.064132
#
#             adjustedClose:15 Days Rolling mean  \
# date
# 2021-08-01                            0.196006
# 2021-08-02                            0.197430
# 2021-08-03                            0.198925
# 2021-08-04                            0.200970
# 2021-08-05                            0.201679
# ...                                        ...
# 2022-07-09                            0.068672
# 2022-07-10                            0.068589
# 2022-07-11                            0.067834
# 2022-07-12                            0.067024
# 2022-07-13                            0.066757
#
#             adjustedClose:60 Days Rolling mean    emw0.2    emw0.4  emw_span5  \
# date
# 2021-08-01                            0.249113  0.203278  0.205836   0.205636
# 2021-08-02                            0.245841  0.203342  0.204941   0.204279
# 2021-08-03                            0.242835  0.201867  0.201352   0.198738
# 2021-08-04                            0.239990  0.201792  0.201407   0.200573
# 2021-08-05                            0.237143  0.201628  0.201234   0.200840
# ...                                        ...       ...       ...        ...
# 2022-07-09                            0.074572  0.068662  0.069292   0.069492
# 2022-07-10                            0.074284  0.068382  0.068480   0.068006
# 2022-07-11                            0.073937  0.067075  0.065827   0.063900
# 2022-07-12                            0.073466  0.065677  0.063531   0.061358
# 2022-07-13                            0.073002  0.064933  0.062900   0.061755
#
#             adjustedClose_first_diff
# date
# 2021-08-01                 -0.003877
# 2021-08-02                 -0.000837
# 2021-08-03                 -0.007633
# 2021-08-04                  0.005523
# 2021-08-05                 -0.000516
# ...                              ...
# 2022-07-09                  0.000255
# 2022-07-10                 -0.002249
# 2022-07-11                 -0.005416
# 2022-07-12                 -0.001760
# 2022-07-13                  0.001866
#
# [347 rows x 13 columns]

# %%
test_data
# Out:
#                 open      high       low     close  adjustedClose      volume  \
# date
# 2021-08-01  0.207753  0.217611  0.201389  0.204437       0.204437  1711494501
# 2021-08-02  0.204279  0.209959  0.202188  0.203600       0.203600  1181469976
# 2021-08-03  0.203431  0.205077  0.193750  0.195967       0.195967  1121632377
# 2021-08-04  0.196312  0.203110  0.194450  0.201490       0.201490  1095300718
# 2021-08-05  0.201575  0.202513  0.194685  0.200974       0.200974  1139204754
# ...              ...       ...       ...       ...            ...         ...
# 2022-07-09  0.069224  0.070009  0.068995  0.069512       0.069512   254272147
# 2022-07-10  0.069509  0.069509  0.066533  0.067263       0.067263   299810124
# 2022-07-11  0.067268  0.067268  0.061535  0.061847       0.061847   326125900
# 2022-07-12  0.061851  0.062861  0.060087  0.060087       0.060087   298462083
# 2022-07-13  0.060085  0.062011  0.058398  0.061953       0.061953   446505400
#
#             adjustedClose:5 Days Rolling mean  \
# date
# 2021-08-01                           0.206317
# 2021-08-02                           0.205958
# 2021-08-03                           0.204228
# 2021-08-04                           0.202762
# 2021-08-05                           0.201294
# ...                                       ...
# 2022-07-09                           0.069026
# 2022-07-10                           0.069047
# 2022-07-11                           0.067700
# 2022-07-12                           0.065593
# 2022-07-13                           0.064132
#
#             adjustedClose:15 Days Rolling mean  \
# date
# 2021-08-01                            0.196006
# 2021-08-02                            0.197430
# 2021-08-03                            0.198925
# 2021-08-04                            0.200970
# 2021-08-05                            0.201679
# ...                                        ...
# 2022-07-09                            0.068672
# 2022-07-10                            0.068589
# 2022-07-11                            0.067834
# 2022-07-12                            0.067024
# 2022-07-13                            0.066757
#
#             adjustedClose:60 Days Rolling mean    emw0.2    emw0.4  emw_span5  \
# date
# 2021-08-01                            0.249113  0.203278  0.205836   0.205636
# 2021-08-02                            0.245841  0.203342  0.204941   0.204279
# 2021-08-03                            0.242835  0.201867  0.201352   0.198738
# 2021-08-04                            0.239990  0.201792  0.201407   0.200573
# 2021-08-05                            0.237143  0.201628  0.201234   0.200840
# ...                                        ...       ...       ...        ...
# 2022-07-09                            0.074572  0.068662  0.069292   0.069492
# 2022-07-10                            0.074284  0.068382  0.068480   0.068006
# 2022-07-11                            0.073937  0.067075  0.065827   0.063900
# 2022-07-12                            0.073466  0.065677  0.063531   0.061358
# 2022-07-13                            0.073002  0.064933  0.062900   0.061755
#
#             adjustedClose_first_diff
# date
# 2021-08-01                 -0.003877
# 2021-08-02                 -0.000837
# 2021-08-03                 -0.007633
# 2021-08-04                  0.005523
# 2021-08-05                 -0.000516
# ...                              ...
# 2022-07-09                  0.000255
# 2022-07-10                 -0.002249
# 2022-07-11                 -0.005416
# 2022-07-12                 -0.001760
# 2022-07-13                  0.001866
#
# [347 rows x 13 columns]

# %%
#plot the predictions for validation set
plt.figure(figsize=(16, 8))
plt.plot(test_data["adjustedClose"], label='Adj Close Rolling mean 60 days')
#plt.plot(valid, label='Valid')
plt.plot(df_y_yPred["predicted_mean"], label='Prediction mean')
plt.plot(df_combine["forecasted_mean"], label='Forecast mean')
plt.legend()
plt.show()

# %%
mape = np.mean(np.abs(np.array(fc[:1])-np.array(test_data["adjustedClose"]))/np.abs(test_data["adjustedClose"]))
print("MAPE: " + str(mape))
#MEAN ABSOLUTE PERCENTAGE ERROR (MAPE) = 59.9% 59.9% deviation of Predicted value to the Actual Value
# Out:
# MAPE: 0.5989713913785936
