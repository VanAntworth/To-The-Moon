# %%
#pip install TextBlob

# %%
import json
import pandas as pd
import re
import seaborn as sns
import matplotlib.pyplot as plt
from textblob import TextBlob
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import unicodedata
from sqlalchemy import create_engine
from sqlalchemy.orm import scoped_session, sessionmaker
import psycopg2
import pyodbc

# %%
# Database related all the code is moved to this file
# %run -i "SqlConn.py"
#importing local py file
import SqlConn

# %%
#Fetch Tweets and Sentiment data - Join from Tweet and Sentiment tables
try:
    df_dbSentimentData = SqlConn.fetchTweetFinance()
    print("Data transfer Done")
except BaseException as err:
    print(err)
# Out:
# Data transfer Done

# %%
df_dbSentimentData
# Out:
#                   tweetID financeType        date  \
# 0      156927468836630528       tesla  2012-01-11
# 1      157700726515183616       tesla  2012-01-13
# 2      159330976378519552       tesla  2012-01-17
# 3      159396536621596672       tesla  2012-01-17
# 4      168022238061268992       tesla  2012-02-10
# ...                   ...         ...         ...
# 1074  1544719143387238400     twitter  2022-07-06
# 1075  1544743525585141760        doge  2022-07-06
# 1076  1545051509020192768       tesla  2022-07-07
# 1077  1545166492408328192       tesla  2022-07-07
# 1078  1546666417759653888       tesla  2022-07-12
#
#                                                fullText  replyCount  \
# 0     The exec conf room at Tesla used to be called ...        32.0
# 1     A Tesla Roadster just passed the 100,000 mile ...         5.0
# 2     Will communicate better in the future. Too man...        44.0
# 3     That's not just paranoia (a healthy trait at t...        23.0
# 4                                   Tesla Model X video        12.0
# ...                                                 ...         ...
# 1074  Can you say more about this: “… pressures that...         NaN
# 1075                  Supporting Doge wherever possible         NaN
# 1076  Maybe Tesla should make a highly configurable ...         NaN
# 1077  Super fired up for future product development ...         NaN
# 1078  Tesla’s automatic cabin overheat protection sh...         NaN
#
#       likesCount  retweetCount  adjustedClose     volume
# 0            315            67       5.646000    3361500
# 1             15            51       4.558000   27502000
# 2            163            43       5.320000   23258000
# 3             16            14       5.320000   23258000
# 4             16            47       6.220000    9371000
# ...          ...           ...            ...        ...
# 1074       39322          4695      38.209999    4870300
# 1075       10646          2085       0.068583  398926503
# 1076      120221          6731     733.630005   27310200
# 1077      137575          8685     733.630005   27310200
# 1078       56429          4023     699.210022   29310300
#
# [1079 rows x 9 columns]

# %%
# Read the csv files containin the tweets by Eon Musk from 2010 to 2022 for DogeCOin, Tesla, spaceX, twitter.
#df_doge = pd.read_csv('../Data_Resources/scrapped_data/doge_tweets.csv')
#df_spaceX = pd.read_csv('../Data_Resources/scrapped_data/spaceX_tweets.csv')
#df_tesla = pd.read_csv('../Data_Resources/scrapped_data/tesla_tweets.csv')
#df_twitter = pd.read_csv('../Data_Resources/scrapped_data/twitter_tweets.csv')

# %%
df_doge = df_dbSentimentData.loc[df_dbSentimentData.financeType == 'doge']
df_tesla = df_dbSentimentData.loc[df_dbSentimentData.financeType == 'tesla']
df_twitter = df_dbSentimentData.loc[df_dbSentimentData.financeType == 'twitter']

# %%
df_doge
# Out:
#                   tweetID financeType        date  \
# 456   1113009339743100928        doge  2019-04-02
# 457   1113173498384441344        doge  2019-04-02
# 458   1113178951403180032        doge  2019-04-02
# 620   1254039929333649408        doge  2020-04-25
# 663   1284290215561986048        doge  2020-07-18
# ...                   ...         ...         ...
# 1051  1530209049261658112        doge  2022-05-27
# 1059  1531696049064116224        doge  2022-05-31
# 1060  1531699416490557440        doge  2022-05-31
# 1071  1538406040374595584        doge  2022-06-19
# 1075  1544743525585141760        doge  2022-07-06
#
#                                                fullText  replyCount  \
# 456   Dogecoin might be my fav cryptocurrency. It’s ...       558.0
# 457                                       Dogecoin rulz      1732.0
# 458                             Dogecoin value may vary      1080.0
# 620                                       Dogecoin Mode       124.0
# 663                        Excuse me, I only sell Doge!       416.0
# ...                                                 ...         ...
# 1051  Tesla merch can be bought with Doge, soon Spac...         NaN
# 1059  And Palmer always forgets to mention that he n...         NaN
# 1060  You’re humble bro. Billy’s sense of humor &amp...         NaN
# 1071                    I will keep supporting Dogecoin         NaN
# 1075                  Supporting Doge wherever possible         NaN
#
#       likesCount  retweetCount  adjustedClose      volume
# 456         9063          2428       0.002795    60298362
# 457       138893         16539       0.002795    60298362
# 458        20160          1959       0.002795    60298362
# 620         2192           207       0.002142   229810398
# 663        15930           775       0.003473   204080851
# ...          ...           ...            ...         ...
# 1051      203719         19599       0.081335  1310057650
# 1059        3663           317       0.085865   672444588
# 1060       12204          1237       0.085865   672444588
# 1071      396566         37467       0.060396  1166163984
# 1075       10646          2085       0.068583   398926503
#
# [75 rows x 9 columns]

# %%
print(f"shape of doge df: " + str(df_doge.shape))
print(f"shape of tesla df: " + str(df_tesla.shape))
print(f"shape of twitter df: " + str(df_twitter.shape))
# Out:
# shape of doge df: (75, 9)
# shape of tesla df: (910, 9)
# shape of twitter df: (94, 9)

# %%
df_doge.head()
# Out:
#                  tweetID financeType        date  \
# 456  1113009339743100928        doge  2019-04-02
# 457  1113173498384441344        doge  2019-04-02
# 458  1113178951403180032        doge  2019-04-02
# 620  1254039929333649408        doge  2020-04-25
# 663  1284290215561986048        doge  2020-07-18
#
#                                               fullText  replyCount  \
# 456  Dogecoin might be my fav cryptocurrency. It’s ...       558.0
# 457                                      Dogecoin rulz      1732.0
# 458                            Dogecoin value may vary      1080.0
# 620                                      Dogecoin Mode       124.0
# 663                       Excuse me, I only sell Doge!       416.0
#
#      likesCount  retweetCount  adjustedClose     volume
# 456        9063          2428       0.002795   60298362
# 457      138893         16539       0.002795   60298362
# 458       20160          1959       0.002795   60298362
# 620        2192           207       0.002142  229810398
# 663       15930           775       0.003473  204080851

# %%
df_tesla.head()
# Out:
#               tweetID financeType        date  \
# 0  156927468836630528       tesla  2012-01-11
# 1  157700726515183616       tesla  2012-01-13
# 2  159330976378519552       tesla  2012-01-17
# 3  159396536621596672       tesla  2012-01-17
# 4  168022238061268992       tesla  2012-02-10
#
#                                             fullText  replyCount  likesCount  \
# 0  The exec conf room at Tesla used to be called ...        32.0         315
# 1  A Tesla Roadster just passed the 100,000 mile ...         5.0          15
# 2  Will communicate better in the future. Too man...        44.0         163
# 3  That's not just paranoia (a healthy trait at t...        23.0          16
# 4                                Tesla Model X video        12.0          16
#
#    retweetCount  adjustedClose    volume
# 0            67          5.646   3361500
# 1            51          4.558  27502000
# 2            43          5.320  23258000
# 3            14          5.320  23258000
# 4            47          6.220   9371000

# %%
df_twitter.head()
# Out:
#                 tweetID financeType        date  \
# 154  601669073441697792     twitter  2015-05-22
# 155  601669073441697792     twitter  2015-05-22
# 184  716780425939521536     twitter  2016-04-04
# 185  716780425939521536     twitter  2016-04-04
# 206  750354728169644032     twitter  2016-07-05
#
#                                               fullText  replyCount  \
# 154  What are the best riddles you've heard that ar...       638.0
# 155  What are the best riddles you've heard that ar...       638.0
# 184  Signing off from impromptu Twitter AMA. Thanks...       241.0
# 185  Signing off from impromptu Twitter AMA. Thanks...       241.0
# 206                           Exactly! I love Twitter.        13.0
#
#      likesCount  retweetCount  adjustedClose    volume
# 154         599           208      49.546001  11115500
# 155         599           208      36.599998   9861800
# 184        3252           367      17.090000  38258800
# 185        3252           367      49.397999  67376500
# 206         328            41      17.139999  15718000

# %% [markdown]
# # Vader Sentiment Analyzer

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\15125\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
vader = SentimentIntensityAnalyzer()

# %%
df_doge_vader = df_doge.copy()
df_tesla_vader = df_tesla.copy()
df_twitter_vader = df_twitter.copy()

# %%
# df_doge_vader["normalized"] = df_doge_vader["Tweet"].apply(lambda tweet:unicodedata.normalize('NFKD', tweet))
df_doge_vader["compound_sc"] = df_doge_vader["fullText"].apply(lambda tweet: vader.polarity_scores(tweet)["compound"])
df_doge_vader["negative_sc"] = df_doge_vader["fullText"].apply(lambda tweet: vader.polarity_scores(tweet)["neg"])
df_doge_vader["neutral_sc"] = df_doge_vader["fullText"].apply(lambda tweet: vader.polarity_scores(tweet)["neu"])
df_doge_vader["positive_sc"] = df_doge_vader["fullText"].apply(lambda tweet: vader.polarity_scores(tweet)["pos"])
df_doge_vader.head()
# Out:
#                  tweetID financeType        date  \
# 456  1113009339743100928        doge  2019-04-02
# 457  1113173498384441344        doge  2019-04-02
# 458  1113178951403180032        doge  2019-04-02
# 620  1254039929333649408        doge  2020-04-25
# 663  1284290215561986048        doge  2020-07-18
#
#                                               fullText  replyCount  \
# 456  Dogecoin might be my fav cryptocurrency. It’s ...       558.0
# 457                                      Dogecoin rulz      1732.0
# 458                            Dogecoin value may vary      1080.0
# 620                                      Dogecoin Mode       124.0
# 663                       Excuse me, I only sell Doge!       416.0
#
#      likesCount  retweetCount  adjustedClose     volume  compound_sc  \
# 456        9063          2428       0.002795   60298362       0.8176
# 457      138893         16539       0.002795   60298362       0.0000
# 458       20160          1959       0.002795   60298362       0.3400
# 620        2192           207       0.002142  229810398       0.0000
# 663       15930           775       0.003473  204080851       0.1511
#
#      negative_sc  neutral_sc  positive_sc
# 456          0.0       0.414        0.586
# 457          0.0       1.000        0.000
# 458          0.0       0.556        0.444
# 620          0.0       1.000        0.000
# 663          0.0       0.715        0.285

# %%
# df_doge_vader["normalized"] = df_doge_vader["Tweet"].apply(lambda tweet:unicodedata.normalize('NFKD', tweet))
df_tesla_vader["compound_sc"] = df_tesla_vader["fullText"].apply(lambda tweet: vader.polarity_scores(tweet)["compound"])
df_tesla_vader["negative_sc"] = df_tesla_vader["fullText"].apply(lambda tweet: vader.polarity_scores(tweet)["neg"])
df_tesla_vader["neutral_sc"] = df_tesla_vader["fullText"].apply(lambda tweet: vader.polarity_scores(tweet)["neu"])
df_tesla_vader["positive_sc"] = df_tesla_vader["fullText"].apply(lambda tweet: vader.polarity_scores(tweet)["pos"])
df_tesla_vader.head()
# Out:
#               tweetID financeType        date  \
# 0  156927468836630528       tesla  2012-01-11
# 1  157700726515183616       tesla  2012-01-13
# 2  159330976378519552       tesla  2012-01-17
# 3  159396536621596672       tesla  2012-01-17
# 4  168022238061268992       tesla  2012-02-10
#
#                                             fullText  replyCount  likesCount  \
# 0  The exec conf room at Tesla used to be called ...        32.0         315
# 1  A Tesla Roadster just passed the 100,000 mile ...         5.0          15
# 2  Will communicate better in the future. Too man...        44.0         163
# 3  That's not just paranoia (a healthy trait at t...        23.0          16
# 4                                Tesla Model X video        12.0          16
#
#    retweetCount  adjustedClose    volume  compound_sc  negative_sc  \
# 0            67          5.646   3361500       0.6616        0.000
# 1            51          4.558  27502000       0.0000        0.000
# 2            43          5.320  23258000      -0.0772        0.122
# 3            14          5.320  23258000       0.0875        0.138
# 4            47          6.220   9371000       0.0000        0.000
#
#    neutral_sc  positive_sc
# 0       0.826        0.174
# 1       1.000        0.000
# 2       0.732        0.146
# 3       0.665        0.197
# 4       1.000        0.000

# %%
# df_doge_vader["normalized"] = df_doge_vader["Tweet"].apply(lambda tweet:unicodedata.normalize('NFKD', tweet))
df_twitter_vader["compound_sc"] = df_twitter_vader["fullText"].apply(lambda tweet: vader.polarity_scores(tweet)["compound"])
df_twitter_vader["negative_sc"] = df_twitter_vader["fullText"].apply(lambda tweet: vader.polarity_scores(tweet)["neg"])
df_twitter_vader["neutral_sc"] = df_twitter_vader["fullText"].apply(lambda tweet: vader.polarity_scores(tweet)["neu"])
df_twitter_vader["positive_sc"] = df_twitter_vader["fullText"].apply(lambda tweet: vader.polarity_scores(tweet)["pos"])
df_twitter_vader.head()
# Out:
#                 tweetID financeType        date  \
# 115  601669073441697792     twitter  2015-05-22
# 130  716780425939521536     twitter  2016-04-04
# 141  750354728169644032     twitter  2016-07-05
# 164  783347230245736448     twitter  2016-10-04
# 165  783842202220802048     twitter  2016-10-06
#
#                                               fullText  replyCount  \
# 115  What are the best riddles you've heard that ar...       638.0
# 130  Signing off from impromptu Twitter AMA. Thanks...       241.0
# 141                           Exactly! I love Twitter.        13.0
# 164  I use twitter for news orgs. My Insta has same...       312.0
# 165  Yeah, and several others at various times. My ...        20.0
#
#      likesCount  retweetCount  adjustedClose     volume  compound_sc  \
# 115         599           208      36.599998    9861800       0.6369
# 130        3252           367      17.090000   38258800       0.4404
# 141         328            41      17.139999   15718000       0.6696
# 164        5254          1598      23.520000   22230700       0.0000
# 165         225            16      19.870001  109388200       0.2960
#
#      negative_sc  neutral_sc  positive_sc
# 115          0.0       0.741        0.259
# 130          0.0       0.854        0.146
# 141          0.0       0.308        0.692
# 164          0.0       1.000        0.000
# 165          0.0       0.891        0.109

# %% [markdown]
# ### Sentiment Analysis by TextBlob

# %%
# Create a function to get the subjectivity
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

# Create a function to get the polarity
def getPolarity(text):
    return TextBlob(text).sentiment.polarity

# Create a function to compute the negative, neutral, and positive analysis
def getAnalysis(score):
    if score < 0:
        return "Negative"
    elif score == 0:
        return "Neutral"
    else:
        return "Positive"

# %%
#Make a copy of the df_doge df
df_doge_txtblb = df_doge.copy()

# Create 2 new columns
df_doge_txtblb["subjectivity"] = df_doge_txtblb["fullText"].apply(getSubjectivity)
df_doge_txtblb["polarity"] = df_doge_txtblb["fullText"].apply(getPolarity)
df_doge_txtblb['Sentiment'] = df_doge_txtblb['polarity'].apply(getAnalysis)
df_doge_txtblb.head()
df_doge_txtblb.to_csv("filename.csv")

# %%
df_doge_txtblb["Sentiment"].value_counts()
# Out:
# Neutral     119
# Positive     53
# Negative     16
# Name: Sentiment, dtype: int64

# %%
# Plot the polarity and subjectivity 
plt.figure(figsize=(8,6))
plt.scatter(df_doge_txtblb["polarity"],df_doge_txtblb["subjectivity"], color = 'Blue')
plt.title("Sentiment Analysis")
plt.xlabel("Polarity")
plt.ylabel("Subjectivity")
plt.grid()
plt.show()

# %%
#Make a copy of the df_tesla df
df_tesla_txtblb = df_tesla.copy()

# Create 2 new columns
df_tesla_txtblb["subjectivity"] = df_tesla_txtblb["fullText"].apply(getSubjectivity)
df_tesla_txtblb["polarity"] = df_tesla_txtblb["fullText"].apply(getPolarity)
df_tesla_txtblb['Sentiment'] = df_tesla_txtblb['polarity'].apply(getAnalysis)
df_tesla_txtblb.head()
# Out:
#               tweetID financeType        date  \
# 0  156927468836630528       tesla  2012-01-11
# 1  157700726515183616       tesla  2012-01-13
# 2  159330976378519552       tesla  2012-01-17
# 3  159396536621596672       tesla  2012-01-17
# 4  168022238061268992       tesla  2012-02-10
#
#                                             fullText  replyCount  likesCount  \
# 0  The exec conf room at Tesla used to be called ...        32.0         315
# 1  A Tesla Roadster just passed the 100,000 mile ...         5.0          15
# 2  Will communicate better in the future. Too man...        44.0         163
# 3  That's not just paranoia (a healthy trait at t...        23.0          16
# 4                                Tesla Model X video        12.0          16
#
#    retweetCount  adjustedClose    volume  subjectivity  polarity Sentiment
# 0            67          5.646   3361500      0.650000     0.350  Positive
# 1            51          4.558  27502000      0.333333     0.250  Positive
# 2            43          5.320  23258000      0.435000     0.150  Positive
# 3            14          5.320  23258000      0.500000     0.175  Positive
# 4            47          6.220   9371000      0.000000     0.000   Neutral

# %%
df_tesla_txtblb["Sentiment"].value_counts()
# Out:
# Positive    2006
# Neutral      812
# Negative     565
# Name: Sentiment, dtype: int64

# %%
# Plot the polarity and subjectivity 
plt.figure(figsize=(8,6))
plt.scatter(df_tesla_txtblb["polarity"],df_tesla_txtblb["subjectivity"], color = 'Blue')
plt.title("Sentiment Analysis")
plt.xlabel("Polarity")
plt.ylabel("Subjectivity")
plt.grid()
plt.show()

# %%
#Make a copy of the df_twitter df
df_twitter_txtblb = df_twitter.copy()

# Create 2 new columns
df_twitter_txtblb["subjectivity"] = df_twitter_txtblb["fullText"].apply(getSubjectivity)
df_twitter_txtblb["polarity"] = df_twitter_txtblb["fullText"].apply(getPolarity)
df_twitter_txtblb['Sentiment'] = df_twitter_txtblb['polarity'].apply(getAnalysis)
df_twitter_txtblb.head()
# Out:
#                 tweetID financeType        date  \
# 154  601669073441697792     twitter  2015-05-22
# 155  601669073441697792     twitter  2015-05-22
# 184  716780425939521536     twitter  2016-04-04
# 185  716780425939521536     twitter  2016-04-04
# 206  750354728169644032     twitter  2016-07-05
#
#                                               fullText  replyCount  \
# 154  What are the best riddles you've heard that ar...       638.0
# 155  What are the best riddles you've heard that ar...       638.0
# 184  Signing off from impromptu Twitter AMA. Thanks...       241.0
# 185  Signing off from impromptu Twitter AMA. Thanks...       241.0
# 206                           Exactly! I love Twitter.        13.0
#
#      likesCount  retweetCount  adjustedClose    volume  subjectivity  \
# 154         599           208      49.546001  11115500      0.366667
# 155         599           208      36.599998   9861800      0.366667
# 184        3252           367      17.090000  38258800      0.266667
# 185        3252           367      49.397999  67376500      0.266667
# 206         328            41      17.139999  15718000      0.600000
#
#      polarity Sentiment
# 154  0.333333  Positive
# 155  0.333333  Positive
# 184  0.191667  Positive
# 185  0.191667  Positive
# 206  0.500000  Positive

# %%
df_twitter_txtblb["Sentiment"].value_counts()
# Out:
# Positive    213
# Neutral     108
# Negative     50
# Name: Sentiment, dtype: int64

# %%
# Plot the polarity and subjectivity 
plt.figure(figsize=(8,6))
plt.scatter(df_twitter_txtblb["polarity"],df_twitter_txtblb["subjectivity"], color = 'Blue')
plt.title("Sentiment Analysis")
plt.xlabel("Polarity")
plt.ylabel("Subjectivity")
plt.grid()
plt.show()

# %%
df_dbSentimentData_Combine = pd.concat([df_doge_vader,df_tesla_vader,df_twitter_vader],ignore_index=False)
df_dbSentimentData_Combine.rename(columns = {'Sentiment':'sentiment','compound_sc':'sentimentScore'} ,inplace=True)

# %%
df_dbSentimentData_Combine
# Out:
#                   tweetID financeType        date  \
# 456   1113009339743100928        doge  2019-04-02
# 457   1113173498384441344        doge  2019-04-02
# 458   1113178951403180032        doge  2019-04-02
# 620   1254039929333649408        doge  2020-04-25
# 663   1284290215561986048        doge  2020-07-18
# ...                   ...         ...         ...
# 1057  1531632887866576896     twitter  2022-05-31
# 1058  1531640532350513152     twitter  2022-05-31
# 1067  1534938078279880704     twitter  2022-06-09
# 1072  1539292625433501696     twitter  2022-06-21
# 1074  1544719143387238400     twitter  2022-07-06
#
#                                                fullText  replyCount  \
# 456   Dogecoin might be my fav cryptocurrency. It’s ...       558.0
# 457                                       Dogecoin rulz      1732.0
# 458                             Dogecoin value may vary      1080.0
# 620                                       Dogecoin Mode       124.0
# 663                        Excuse me, I only sell Doge!       416.0
# ...                                                 ...         ...
# 1057  My kids wrote better code when they were 12 th...         NaN
# 1058  Maybe if they do the opposite, Twitter will be...         NaN
# 1067                                       Only Twitter         NaN
# 1072  Twitter me &amp; real-life me are quite differ...         NaN
# 1074  Can you say more about this: “… pressures that...         NaN
#
#       likesCount  retweetCount  adjustedClose     volume  compound_sc  \
# 456         9063          2428       0.002795   60298362       0.8176
# 457       138893         16539       0.002795   60298362       0.0000
# 458        20160          1959       0.002795   60298362       0.3400
# 620         2192           207       0.002142  229810398       0.0000
# 663        15930           775       0.003473  204080851       0.1511
# ...          ...           ...            ...        ...          ...
# 1057        7563           696      39.599998   11579000       0.9192
# 1058        3306           231      39.599998   11579000       0.4404
# 1067       57460          2473      39.529999    7970300       0.0000
# 1072      147051          8697      38.910000   16902200       0.5530
# 1074       39322          4695      38.209999    4870300      -0.3182
#
#       negative_sc  neutral_sc  positive_sc
# 456         0.000       0.414        0.586
# 457         0.000       1.000        0.000
# 458         0.000       0.556        0.444
# 620         0.000       1.000        0.000
# 663         0.000       0.715        0.285
# ...           ...         ...          ...
# 1057        0.045       0.695        0.260
# 1058        0.000       0.828        0.172
# 1067        0.000       1.000        0.000
# 1072        0.000       0.691        0.309
# 1074        0.126       0.874        0.000
#
# [1079 rows x 13 columns]

# %%
df_sentiment_tostore = df_dbSentimentData_Combine[["tweetID","date","adjustedClose","volume","sentimentScore"]]

# %%
#Insert Sentiment data
try:
    SqlConn.insertSentiment(df_sentiment_tostore)
    print("Data transfer Done")
except BaseException as err:
    print(err)
# Out:
# Data transfer Done
