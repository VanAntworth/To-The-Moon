# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Activation, Dense,LSTM,Dropout
from sklearn.metrics import mean_absolute_error
plt.style.use('fivethirtyeight')

# %%
import requests
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, LSTM
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error
# %matplotlib inline

# %%
doge_price = pd.read_csv('csv/doge_price.csv')
tesla_price = pd.read_csv('csv/tesla_price.csv')
twitter_price = pd.read_csv('csv/twitter_price.csv')

# %%
print(f"Shape of doge_price df: "+ str(doge_price.shape))
print(f"Shape of tesla_price df: "+ str(tesla_price.shape))
print(f"Shape of twitter_price df: "+ str(twitter_price.shape))
# Out:
# Shape of doge_price df: (1707, 7)
# Shape of tesla_price df: (3030, 7)
# Shape of twitter_price df: (2183, 7)

# %%
end_date = doge_price['Date'].iloc[-1]
end_date
# Out:
# '2022-07-12'

# %%
doge_price['Date'] = pd.to_datetime(doge_price['Date'], format='%Y-%m-%d')
tesla_price['Date'] = pd.to_datetime(tesla_price['Date'], format='%Y-%m-%d')
twitter_price['Date'] = pd.to_datetime(twitter_price['Date'], format='%Y-%m-%d')

# %%
doge_price.set_index("Date",inplace = True)
tesla_price.set_index("Date",inplace = True)
twitter_price.set_index("Date",inplace = True)

# %%
# Let's see a historical view of the closing price

plt.figure(figsize=(16, 8))
plt.subplots_adjust(top=1.25, bottom=1.2)
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Price USD($)',fontsize=18)

# Plot the closing price of DogeCoin
plt.subplot(2, 2, 1)
plt.title('Close Price History Of DogeCoin')
plt.plot(doge_price['Close'])

# Plot the closing price of Tesla
plt.subplot(2, 2, 2)
plt.title('Close Price History Of Tesla')
plt.plot(tesla_price['Close'])

# Plot the closing price of Twitter
plt.subplot(2, 2, 3)
plt.title('Close Price History Of Twitter')
plt.plot(twitter_price['Close'])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### DogeCoin Prediction

# %%
data = doge_price.drop(['Open', 'High', 'Low', 'Adj Close', 'Volume'], axis = 1)
price_column = 'Close'
data.head()
# Out:
#                Close
# Date
# 2017-11-09  0.001415
# 2017-11-10  0.001163
# 2017-11-11  0.001201
# 2017-11-12  0.001038
# 2017-11-13  0.001211

# %%
# This function splits the data in 70,30 ratio.
def train_test_split(df, test_size=0.3):
    split_row = len(df) - int(test_size * len(df))
    train_data = df.iloc[:split_row]
    test_data = df.iloc[split_row:]
    return train_data, test_data

# %%
train, test = train_test_split(data, test_size=0.2)

# %%
train.shape, test.shape
# Out:
# ((1366, 1), (341, 1))

# %%
train
# Out:
#                Close
# Date
# 2017-11-09  0.001415
# 2017-11-10  0.001163
# 2017-11-11  0.001201
# 2017-11-12  0.001038
# 2017-11-13  0.001211
# ...              ...
# 2021-08-01  0.204437
# 2021-08-02  0.203600
# 2021-08-03  0.195967
# 2021-08-04  0.201490
# 2021-08-05  0.200974
#
# [1366 rows x 1 columns]

# %%
test
# Out:
#                Close
# Date
# 2021-08-06  0.204688
# 2021-08-07  0.260341
# 2021-08-08  0.240045
# 2021-08-09  0.256897
# 2021-08-10  0.257325
# ...              ...
# 2022-07-08  0.069257
# 2022-07-09  0.069512
# 2022-07-10  0.067263
# 2022-07-11  0.061847
# 2022-07-12  0.060462
#
# [341 rows x 1 columns]

# %%
# Perform MinMax scaling
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(data).reshape(-1,1))
df1
# Out:
# array([[0.00055138],
#        [0.00018282],
#        [0.0002384 ],
#        ...,
#        [0.09685713],
#        [0.08893598],
#        [0.08691036]])

# %%
##splitting dataset into train and test split
training_size=int(len(df1)*0.8)
# test_size=len(df1)-training_size

test_size = 0.2
split_row = len(df1) - int(test_size * len(df1))
# train_data = df.iloc[:split_row]
# test_data = df.iloc[split_row:]
    
train_scaled,test_scaled=df1[0:split_row,:],df1[split_row:,]
training_size,split_row
# Out:
# (1365, 1366)

# %%
train_scaled.shape,test_scaled.shape
# Out:
# ((1366, 1), (341, 1))

# %%
train_scaled
# Out:
# array([[5.51379986e-04],
#        [1.82818298e-04],
#        [2.38395060e-04],
#        ...,
#        [2.85092704e-01],
#        [2.93170347e-01],
#        [2.92415673e-01]])

# %%
test_scaled
# Out:
# array([[0.29784757],
#        [0.37924266],
#        [0.34955882],
#        [0.37420565],
#        [0.37483162],
#        [0.38644132],
#        [0.38447858],
#        [0.41795188],
#        [0.42717323],
#        [0.49785518],
#        [0.46754244],
#        [0.43642969],
#        [0.44271425],
#        [0.46231969],
#        [0.47745265],
#        [0.46181218],
#        [0.45912987],
#        [0.46344585],
#        [0.42077606],
#        [0.42587596],
#        [0.39177376],
#        [0.4291038 ],
#        [0.41622754],
#        [0.40964023],
#        [0.39647731],
#        [0.4057323 ],
#        [0.42905699],
#        [0.43132979],
#        [0.43179488],
#        [0.43635071],
#        [0.4584922 ],
#        [0.45006501],
#        [0.36959425],
#        [0.37452156],
#        [0.36791524],
#        [0.34946668],
#        [0.35158737],
#        [0.36502086],
#        [0.34350534],
#        [0.35052995],
#        [0.36075023],
#        [0.35322981],
#        [0.34939063],
#        [0.3515201 ],
#        [0.33946287],
#        [0.30133282],
#        [0.29249319],
#        [0.32734713],
#        [0.3273091 ],
#        [0.30481368],
#        [0.30362755],
#        [0.29824831],
#        [0.29137434],
#        [0.28631685],
#        [0.28934725],
#        [0.2971982 ],
#        [0.32464435],
#        [0.31897405],
#        [0.32279861],
#        [0.3507391 ],
#        [0.36706697],
#        [0.37162719],
#        [0.35376803],
#        [0.35512527],
#        [0.35913996],
#        [0.33458235],
#        [0.33706575],
#        [0.3293713 ],
#        [0.33862921],
#        [0.33819191],
#        [0.34039889],
#        [0.34553243],
#        [0.34641874],
#        [0.36014181],
#        [0.35795823],
#        [0.37010467],
#        [0.35298996],
#        [0.35566642],
#        [0.36665306],
#        [0.40367743],
#        [0.38562814],
#        [0.37250179],
#        [0.34611453],
#        [0.43789955],
#        [0.41948024],
#        [0.39094889],
#        [0.40835172],
#        [0.39589668],
#        [0.39793401],
#        [0.39250211],
#        [0.38354109],
#        [0.38088657],
#        [0.38151985],
#        [0.38797992],
#        [0.41144501],
#        [0.39852634],
#        [0.37246815],
#        [0.38045073],
#        [0.37788688],
#        [0.38123904],
#        [0.38300287],
#        [0.37366744],
#        [0.34546954],
#        [0.34581763],
#        [0.32226478],
#        [0.33941606],
#        [0.33929028],
#        [0.32949707],
#        [0.31976822],
#        [0.32976618],
#        [0.32291123],
#        [0.31486869],
#        [0.29228843],
#        [0.29881139],
#        [0.3019193 ],
#        [0.31318529],
#        [0.31251252],
#        [0.30486633],
#        [0.30521588],
#        [0.29098092],
#        [0.26006268],
#        [0.24895026],
#        [0.25940015],
#        [0.25706739],
#        [0.26049852],
#        [0.24636009],
#        [0.23895668],
#        [0.24568   ],
#        [0.24695534],
#        [0.228928  ],
#        [0.26196985],
#        [0.2633227 ],
#        [0.2521664 ],
#        [0.24566684],
#        [0.25062487],
#        [0.24649464],
#        [0.24319806],
#        [0.24883325],
#        [0.25181539],
#        [0.26830706],
#        [0.27142521],
#        [0.27732658],
#        [0.27639494],
#        [0.27300915],
#        [0.25313607],
#        [0.24384597],
#        [0.24903509],
#        [0.24784018],
#        [0.25155359],
#        [0.25355435],
#        [0.24724347],
#        [0.24536409],
#        [0.23164102],
#        [0.23280082],
#        [0.2252102 ],
#        [0.22072165],
#        [0.21942145],
#        [0.20815106],
#        [0.22283503],
#        [0.23490542],
#        [0.25010274],
#        [0.2669308 ],
#        [0.2692036 ],
#        [0.25760999],
#        [0.24878938],
#        [0.24051136],
#        [0.23593506],
#        [0.22547493],
#        [0.20709949],
#        [0.19284259],
#        [0.20596309],
#        [0.20001784],
#        [0.20769767],
#        [0.20877996],
#        [0.20506217],
#        [0.20566035],
#        [0.20770791],
#        [0.20246468],
#        [0.20587827],
#        [0.20708633],
#        [0.19919443],
#        [0.19964197],
#        [0.21421186],
#        [0.21368241],
#        [0.22337763],
#        [0.24064738],
#        [0.23015654],
#        [0.23120664],
#        [0.22062658],
#        [0.21032733],
#        [0.20968089],
#        [0.21632524],
#        [0.21201804],
#        [0.22043938],
#        [0.21654023],
#        [0.2011206 ],
#        [0.20143651],
#        [0.2050022 ],
#        [0.19865767],
#        [0.18640446],
#        [0.19088424],
#        [0.18546258],
#        [0.17956413],
#        [0.18506769],
#        [0.18517153],
#        [0.17853742],
#        [0.1932287 ],
#        [0.19437241],
#        [0.19298592],
#        [0.18804251],
#        [0.1777769 ],
#        [0.18129432],
#        [0.17510775],
#        [0.16975337],
#        [0.16964222],
#        [0.17630997],
#        [0.16943161],
#        [0.16755516],
#        [0.16687362],
#        [0.16171375],
#        [0.16528237],
#        [0.16343371],
#        [0.16946525],
#        [0.16887146],
#        [0.17297244],
#        [0.17920727],
#        [0.17275013],
#        [0.1730207 ],
#        [0.17761602],
#        [0.18821363],
#        [0.19819259],
#        [0.19009447],
#        [0.19719513],
#        [0.21015914],
#        [0.20712436],
#        [0.20977595],
#        [0.20793314],
#        [0.20005879],
#        [0.20516162],
#        [0.20164858],
#        [0.21267618],
#        [0.21580311],
#        [0.25136638],
#        [0.20823589],
#        [0.21216283],
#        [0.2069664 ],
#        [0.20953171],
#        [0.21718375],
#        [0.1954196 ],
#        [0.20042443],
#        [0.20335537],
#        [0.20897155],
#        [0.21205167],
#        [0.20866734],
#        [0.20244713],
#        [0.20365666],
#        [0.20713606],
#        [0.20452249],
#        [0.19792201],
#        [0.19796589],
#        [0.19481557],
#        [0.19146048],
#        [0.22950424],
#        [0.1999725 ],
#        [0.20279961],
#        [0.19938164],
#        [0.19596513],
#        [0.18503991],
#        [0.19266855],
#        [0.18998477],
#        [0.18791088],
#        [0.19710884],
#        [0.18631671],
#        [0.18554302],
#        [0.18500334],
#        [0.18014038],
#        [0.15179184],
#        [0.15713452],
#        [0.12218551],
#        [0.11939205],
#        [0.12767006],
#        [0.12981269],
#        [0.13426907],
#        [0.12695341],
#        [0.13042257],
#        [0.12082242],
#        [0.12531829],
#        [0.12130213],
#        [0.12201293],
#        [0.12441443],
#        [0.12024325],
#        [0.12080487],
#        [0.11985129],
#        [0.11292906],
#        [0.11743809],
#        [0.11817521],
#        [0.11941399],
#        [0.12699729],
#        [0.12406342],
#        [0.11703004],
#        [0.11953977],
#        [0.11613203],
#        [0.11808453],
#        [0.11728306],
#        [0.11918583],
#        [0.11623587],
#        [0.1146651 ],
#        [0.11451446],
#        [0.10883685],
#        [0.10070656],
#        [0.09257626],
#        [0.07734384],
#        [0.07978776],
#        [0.0906223 ],
#        [0.07896434],
#        [0.08183971],
#        [0.07601439],
#        [0.08681383],
#        [0.08649353],
#        [0.09438251],
#        [0.08873708],
#        [0.09213165],
#        [0.09665384],
#        [0.09867069],
#        [0.10550663],
#        [0.10413476],
#        [0.09494705],
#        [0.10008205],
#        [0.09513572],
#        [0.09526588],
#        [0.0960308 ],
#        [0.09673428],
#        [0.1000879 ],
#        [0.09669918],
#        [0.0987877 ],
#        [0.10176836],
#        [0.09977345],
#        [0.1001464 ],
#        [0.09685713],
#        [0.08893598],
#        [0.08691036]])

# %%
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 100
X_train, y_train = create_dataset(train_scaled, time_step)
X_test, ytest = create_dataset(test_scaled, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (1265, 100)
# (1265,)
# (None, None)

# %%
print(X_test.shape), print(ytest.shape)
# Out:
# (240, 100)
# (240,)
# (None, None)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (1265, 100, 1)
# (1265,)
# (None, None)

# %%
print(X_test.shape), print(ytest.shape)
# Out:
# (240, 100, 1)
# (240,)
# (None, None)

# %%
X_test
# Out:
# array([[[0.29784757],
#         [0.37924266],
#         [0.34955882],
#         ...,
#         [0.38045073],
#         [0.37788688],
#         [0.38123904]],
#
#        [[0.37924266],
#         [0.34955882],
#         [0.37420565],
#         ...,
#         [0.37788688],
#         [0.38123904],
#         [0.38300287]],
#
#        [[0.34955882],
#         [0.37420565],
#         [0.37483162],
#         ...,
#         [0.38123904],
#         [0.38300287],
#         [0.37366744]],
#
#        ...,
#
#        [[0.20005879],
#         [0.20516162],
#         [0.20164858],
#         ...,
#         [0.0987877 ],
#         [0.10176836],
#         [0.09977345]],
#
#        [[0.20516162],
#         [0.20164858],
#         [0.21267618],
#         ...,
#         [0.10176836],
#         [0.09977345],
#         [0.1001464 ]],
#
#        [[0.20164858],
#         [0.21267618],
#         [0.21580311],
#         ...,
#         [0.09977345],
#         [0.1001464 ],
#         [0.09685713]]])

# %%
ytest
# Out:
# array([0.38300287, 0.37366744, 0.34546954, 0.34581763, 0.32226478,
#        0.33941606, 0.33929028, 0.32949707, 0.31976822, 0.32976618,
#        0.32291123, 0.31486869, 0.29228843, 0.29881139, 0.3019193 ,
#        0.31318529, 0.31251252, 0.30486633, 0.30521588, 0.29098092,
#        0.26006268, 0.24895026, 0.25940015, 0.25706739, 0.26049852,
#        0.24636009, 0.23895668, 0.24568   , 0.24695534, 0.228928  ,
#        0.26196985, 0.2633227 , 0.2521664 , 0.24566684, 0.25062487,
#        0.24649464, 0.24319806, 0.24883325, 0.25181539, 0.26830706,
#        0.27142521, 0.27732658, 0.27639494, 0.27300915, 0.25313607,
#        0.24384597, 0.24903509, 0.24784018, 0.25155359, 0.25355435,
#        0.24724347, 0.24536409, 0.23164102, 0.23280082, 0.2252102 ,
#        0.22072165, 0.21942145, 0.20815106, 0.22283503, 0.23490542,
#        0.25010274, 0.2669308 , 0.2692036 , 0.25760999, 0.24878938,
#        0.24051136, 0.23593506, 0.22547493, 0.20709949, 0.19284259,
#        0.20596309, 0.20001784, 0.20769767, 0.20877996, 0.20506217,
#        0.20566035, 0.20770791, 0.20246468, 0.20587827, 0.20708633,
#        0.19919443, 0.19964197, 0.21421186, 0.21368241, 0.22337763,
#        0.24064738, 0.23015654, 0.23120664, 0.22062658, 0.21032733,
#        0.20968089, 0.21632524, 0.21201804, 0.22043938, 0.21654023,
#        0.2011206 , 0.20143651, 0.2050022 , 0.19865767, 0.18640446,
#        0.19088424, 0.18546258, 0.17956413, 0.18506769, 0.18517153,
#        0.17853742, 0.1932287 , 0.19437241, 0.19298592, 0.18804251,
#        0.1777769 , 0.18129432, 0.17510775, 0.16975337, 0.16964222,
#        0.17630997, 0.16943161, 0.16755516, 0.16687362, 0.16171375,
#        0.16528237, 0.16343371, 0.16946525, 0.16887146, 0.17297244,
#        0.17920727, 0.17275013, 0.1730207 , 0.17761602, 0.18821363,
#        0.19819259, 0.19009447, 0.19719513, 0.21015914, 0.20712436,
#        0.20977595, 0.20793314, 0.20005879, 0.20516162, 0.20164858,
#        0.21267618, 0.21580311, 0.25136638, 0.20823589, 0.21216283,
#        0.2069664 , 0.20953171, 0.21718375, 0.1954196 , 0.20042443,
#        0.20335537, 0.20897155, 0.21205167, 0.20866734, 0.20244713,
#        0.20365666, 0.20713606, 0.20452249, 0.19792201, 0.19796589,
#        0.19481557, 0.19146048, 0.22950424, 0.1999725 , 0.20279961,
#        0.19938164, 0.19596513, 0.18503991, 0.19266855, 0.18998477,
#        0.18791088, 0.19710884, 0.18631671, 0.18554302, 0.18500334,
#        0.18014038, 0.15179184, 0.15713452, 0.12218551, 0.11939205,
#        0.12767006, 0.12981269, 0.13426907, 0.12695341, 0.13042257,
#        0.12082242, 0.12531829, 0.12130213, 0.12201293, 0.12441443,
#        0.12024325, 0.12080487, 0.11985129, 0.11292906, 0.11743809,
#        0.11817521, 0.11941399, 0.12699729, 0.12406342, 0.11703004,
#        0.11953977, 0.11613203, 0.11808453, 0.11728306, 0.11918583,
#        0.11623587, 0.1146651 , 0.11451446, 0.10883685, 0.10070656,
#        0.09257626, 0.07734384, 0.07978776, 0.0906223 , 0.07896434,
#        0.08183971, 0.07601439, 0.08681383, 0.08649353, 0.09438251,
#        0.08873708, 0.09213165, 0.09665384, 0.09867069, 0.10550663,
#        0.10413476, 0.09494705, 0.10008205, 0.09513572, 0.09526588,
#        0.0960308 , 0.09673428, 0.1000879 , 0.09669918, 0.0987877 ,
#        0.10176836, 0.09977345, 0.1001464 , 0.09685713, 0.08893598])

# %%
np.random.seed(42)
window_len = 100
test_size = 0.2
zero_base = True
lstm_neurons = 100
epochs = 100
batch_size = 32
loss = 'mse'
dropout = 0.2
optimizer = 'adam'
activ_func = "relu"

# %%
model = Sequential()
model.add(LSTM(100, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(dropout))
model.add(Dense(units=1))
model.add(Activation(activ_func))
model.compile(loss=loss, optimizer=optimizer)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100)               40800
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense (Dense)               (None, 1)                 101
#
#  activation (Activation)     (None, 1)                 0
#
# =================================================================
# Total params: 40,901
# Trainable params: 40,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=1, shuffle=True)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 5s 62ms/step - loss: 0.0025
# Epoch 2/100
# 40/40 [==============================] - 2s 62ms/step - loss: 0.0012
# Epoch 3/100
# 40/40 [==============================] - 2s 60ms/step - loss: 0.0014
# Epoch 4/100
# 40/40 [==============================] - 2s 60ms/step - loss: 0.0013
# Epoch 5/100
# 40/40 [==============================] - 2s 60ms/step - loss: 0.0011
# Epoch 6/100
# 40/40 [==============================] - 2s 60ms/step - loss: 9.9783e-04
# Epoch 7/100
# 40/40 [==============================] - 3s 62ms/step - loss: 9.6931e-04
# Epoch 8/100
# 40/40 [==============================] - 2s 60ms/step - loss: 8.3081e-04
# Epoch 9/100
# 40/40 [==============================] - 2s 59ms/step - loss: 8.6673e-04
# Epoch 10/100
# 40/40 [==============================] - 2s 60ms/step - loss: 0.0010
# Epoch 11/100
# 40/40 [==============================] - 2s 62ms/step - loss: 7.1509e-04
# Epoch 12/100
# 40/40 [==============================] - 2s 60ms/step - loss: 8.4517e-04
# Epoch 13/100
# 40/40 [==============================] - 2s 60ms/step - loss: 7.0798e-04
# Epoch 14/100
# 40/40 [==============================] - 3s 69ms/step - loss: 6.7169e-04
# Epoch 15/100
# 40/40 [==============================] - 3s 72ms/step - loss: 7.1330e-04
# Epoch 16/100
# 40/40 [==============================] - 3s 67ms/step - loss: 6.1863e-04
# Epoch 17/100
# 40/40 [==============================] - 3s 65ms/step - loss: 8.3688e-04
# Epoch 18/100
# 40/40 [==============================] - 3s 65ms/step - loss: 7.6839e-04
# Epoch 19/100
# 40/40 [==============================] - 3s 69ms/step - loss: 6.9775e-04
# Epoch 20/100
# 40/40 [==============================] - 3s 65ms/step - loss: 0.0010
# Epoch 21/100
# 40/40 [==============================] - 3s 65ms/step - loss: 6.4460e-04
# Epoch 22/100
# 40/40 [==============================] - 3s 66ms/step - loss: 6.3585e-04
# Epoch 23/100
# 40/40 [==============================] - 3s 69ms/step - loss: 5.7052e-04
# Epoch 24/100
# 40/40 [==============================] - 3s 66ms/step - loss: 6.9487e-04
# Epoch 25/100
# 40/40 [==============================] - 3s 65ms/step - loss: 6.5751e-04
# Epoch 26/100
# 40/40 [==============================] - 3s 65ms/step - loss: 5.8075e-04
# Epoch 27/100
# 40/40 [==============================] - 3s 69ms/step - loss: 5.6788e-04
# Epoch 28/100
# 40/40 [==============================] - 3s 66ms/step - loss: 7.5328e-04
# Epoch 29/100
# 40/40 [==============================] - 3s 65ms/step - loss: 6.5831e-04
# Epoch 30/100
# 40/40 [==============================] - 3s 66ms/step - loss: 5.7306e-04
# Epoch 31/100
# 40/40 [==============================] - 3s 67ms/step - loss: 4.4546e-04
# Epoch 32/100
# 40/40 [==============================] - 3s 66ms/step - loss: 5.2033e-04
# Epoch 33/100
# 40/40 [==============================] - 3s 67ms/step - loss: 4.5725e-04
# Epoch 34/100
# 40/40 [==============================] - 3s 67ms/step - loss: 4.5114e-04
# Epoch 35/100
# 40/40 [==============================] - 3s 68ms/step - loss: 5.6260e-04
# Epoch 36/100
# 40/40 [==============================] - 3s 67ms/step - loss: 4.5591e-04
# Epoch 37/100
# 40/40 [==============================] - 3s 65ms/step - loss: 5.2067e-04
# Epoch 38/100
# 40/40 [==============================] - 3s 66ms/step - loss: 5.1239e-04
# Epoch 39/100
# 40/40 [==============================] - 3s 69ms/step - loss: 4.7926e-04
# Epoch 40/100
# 40/40 [==============================] - 3s 68ms/step - loss: 4.2899e-04
# Epoch 41/100
# 40/40 [==============================] - 3s 66ms/step - loss: 4.5020e-04
# Epoch 42/100
# 40/40 [==============================] - 3s 65ms/step - loss: 5.5706e-04
# Epoch 43/100
# 40/40 [==============================] - 3s 67ms/step - loss: 4.8449e-04
# Epoch 44/100
# 40/40 [==============================] - 3s 68ms/step - loss: 5.3610e-04
# Epoch 45/100
# 40/40 [==============================] - 3s 66ms/step - loss: 4.4727e-04
# Epoch 46/100
# 40/40 [==============================] - 3s 65ms/step - loss: 4.3574e-04
# Epoch 47/100
# 40/40 [==============================] - 3s 66ms/step - loss: 4.6360e-04
# Epoch 48/100
# 40/40 [==============================] - 3s 69ms/step - loss: 4.3411e-04
# Epoch 49/100
# 40/40 [==============================] - 3s 66ms/step - loss: 4.2873e-04
# Epoch 50/100
# 40/40 [==============================] - 3s 65ms/step - loss: 4.9078e-04
# Epoch 51/100
# 40/40 [==============================] - 3s 66ms/step - loss: 5.2583e-04
# Epoch 52/100
# 40/40 [==============================] - 3s 68ms/step - loss: 4.8362e-04
# Epoch 53/100
# 40/40 [==============================] - 3s 66ms/step - loss: 5.1375e-04
# Epoch 54/100
# 40/40 [==============================] - 3s 66ms/step - loss: 5.0951e-04
# Epoch 55/100
# 40/40 [==============================] - 3s 65ms/step - loss: 4.7276e-04
# Epoch 56/100
# 40/40 [==============================] - 3s 73ms/step - loss: 4.3118e-04
# Epoch 57/100
# 40/40 [==============================] - 3s 69ms/step - loss: 4.9934e-04
# Epoch 58/100
# 40/40 [==============================] - 3s 67ms/step - loss: 5.3817e-04
# Epoch 59/100
# 40/40 [==============================] - 3s 68ms/step - loss: 4.8477e-04
# Epoch 60/100
# 40/40 [==============================] - 3s 70ms/step - loss: 5.0925e-04
# Epoch 61/100
# 40/40 [==============================] - 3s 65ms/step - loss: 4.4585e-04
# Epoch 62/100
# 40/40 [==============================] - 3s 66ms/step - loss: 4.6224e-04
# Epoch 63/100
# 40/40 [==============================] - 3s 67ms/step - loss: 4.8460e-04
# Epoch 64/100
# 40/40 [==============================] - 3s 71ms/step - loss: 3.7524e-04
# Epoch 65/100
# 40/40 [==============================] - 3s 66ms/step - loss: 4.6749e-04
# Epoch 66/100
# 40/40 [==============================] - 3s 66ms/step - loss: 4.4380e-04
# Epoch 67/100
# 40/40 [==============================] - 3s 66ms/step - loss: 4.3242e-04
# Epoch 68/100
# 40/40 [==============================] - 3s 69ms/step - loss: 4.0071e-04
# Epoch 69/100
# 40/40 [==============================] - 3s 66ms/step - loss: 4.9803e-04
# Epoch 70/100
# 40/40 [==============================] - 3s 66ms/step - loss: 3.9518e-04
# Epoch 71/100
# 40/40 [==============================] - 3s 66ms/step - loss: 4.9430e-04
# Epoch 72/100
# 40/40 [==============================] - 3s 70ms/step - loss: 3.8281e-04
# Epoch 73/100
# 40/40 [==============================] - 3s 66ms/step - loss: 3.7270e-04
# Epoch 74/100
# 40/40 [==============================] - 3s 66ms/step - loss: 4.6196e-04
# Epoch 75/100
# 40/40 [==============================] - 3s 65ms/step - loss: 4.2688e-04
# Epoch 76/100
# 40/40 [==============================] - 3s 68ms/step - loss: 3.6117e-04
# Epoch 77/100
# 40/40 [==============================] - 3s 66ms/step - loss: 3.8030e-04
# Epoch 78/100
# 40/40 [==============================] - 3s 65ms/step - loss: 3.8963e-04
# Epoch 79/100
# 40/40 [==============================] - 3s 67ms/step - loss: 4.2635e-04
# Epoch 80/100
# 40/40 [==============================] - 3s 69ms/step - loss: 4.7894e-04
# Epoch 81/100
# 40/40 [==============================] - 3s 66ms/step - loss: 5.3779e-04
# Epoch 82/100
# 40/40 [==============================] - 3s 66ms/step - loss: 3.8907e-04
# Epoch 83/100
# 40/40 [==============================] - 3s 66ms/step - loss: 3.9550e-04
# Epoch 84/100
# 40/40 [==============================] - 3s 70ms/step - loss: 4.9569e-04
# Epoch 85/100
# 40/40 [==============================] - 3s 65ms/step - loss: 4.2863e-04
# Epoch 86/100
# 40/40 [==============================] - 3s 70ms/step - loss: 4.1297e-04
# Epoch 87/100
# 40/40 [==============================] - 3s 71ms/step - loss: 4.5970e-04
# Epoch 88/100
# 40/40 [==============================] - 3s 73ms/step - loss: 4.7718e-04
# Epoch 89/100
# 40/40 [==============================] - 3s 67ms/step - loss: 4.0809e-04
# Epoch 90/100
# 40/40 [==============================] - 3s 66ms/step - loss: 4.9798e-04
# Epoch 91/100
# 40/40 [==============================] - 3s 66ms/step - loss: 4.9245e-04
# Epoch 92/100
# 40/40 [==============================] - 3s 68ms/step - loss: 4.7409e-04
# Epoch 93/100
# 40/40 [==============================] - 3s 66ms/step - loss: 4.1373e-04
# Epoch 94/100
# 40/40 [==============================] - 3s 66ms/step - loss: 4.5143e-04
# Epoch 95/100
# 40/40 [==============================] - 3s 66ms/step - loss: 3.7871e-04
# Epoch 96/100
# 40/40 [==============================] - 3s 68ms/step - loss: 4.2976e-04
# Epoch 97/100
# 40/40 [==============================] - 3s 65ms/step - loss: 4.6947e-04
# Epoch 98/100
# 40/40 [==============================] - 3s 65ms/step - loss: 4.3800e-04
# Epoch 99/100
# 40/40 [==============================] - 3s 65ms/step - loss: 4.0452e-04
# Epoch 100/100
# 40/40 [==============================] - 3s 68ms/step - loss: 3.9247e-04

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# 40/40 [==============================] - 2s 23ms/step
# 8/8 [==============================] - 0s 27ms/step

# %%
test_predict
# Out:
# array([[0.3855347 ],
#        [0.39439917],
#        [0.39390203],
#        [0.37142205],
#        [0.3538855 ],
#        [0.33183146],
#        [0.3347512 ],
#        [0.3453468 ],
#        [0.34839493],
#        [0.3408029 ],
#        [0.33875665],
#        [0.33350345],
#        [0.32579634],
#        [0.30779073],
#        [0.30218354],
#        [0.30598998],
#        [0.31963462],
#        [0.32877588],
#        [0.3259625 ],
#        [0.31958944],
#        [0.304904  ],
#        [0.27643386],
#        [0.2540946 ],
#        [0.2542368 ],
#        [0.2618117 ],
#        [0.27215537],
#        [0.26821616],
#        [0.25608677],
#        [0.25052732],
#        [0.25024062],
#        [0.24136409],
#        [0.25789845],
#        [0.27326053],
#        [0.27387726],
#        [0.26457193],
#        [0.25874504],
#        [0.2538417 ],
#        [0.25108117],
#        [0.25535274],
#        [0.26194426],
#        [0.2767118 ],
#        [0.2870379 ],
#        [0.29346874],
#        [0.29289976],
#        [0.28725895],
#        [0.26993537],
#        [0.25351974],
#        [0.25065643],
#        [0.2541507 ],
#        [0.26186934],
#        [0.2681034 ],
#        [0.26548758],
#        [0.25917843],
#        [0.24512151],
#        [0.23751464],
#        [0.23161533],
#        [0.22824994],
#        [0.2276291 ],
#        [0.22125596],
#        [0.22643164],
#        [0.23925757],
#        [0.25755486],
#        [0.27809742],
#        [0.28826362],
#        [0.28055894],
#        [0.26438782],
#        [0.24852714],
#        [0.23981217],
#        [0.23344782],
#        [0.22150081],
#        [0.20622449],
#        [0.20666856],
#        [0.20722784],
#        [0.21364573],
#        [0.21862227],
#        [0.21772617],
#        [0.21527132],
#        [0.21428633],
#        [0.2108978 ],
#        [0.2115376 ],
#        [0.21409577],
#        [0.21124724],
#        [0.20897287],
#        [0.21716085],
#        [0.22341557],
#        [0.23259345],
#        [0.24819574],
#        [0.24947509],
#        [0.24622563],
#        [0.23502705],
#        [0.2209543 ],
#        [0.21393573],
#        [0.21822757],
#        [0.22207078],
#        [0.23020247],
#        [0.2318449 ],
#        [0.21994212],
#        [0.20982158],
#        [0.20719466],
#        [0.20493042],
#        [0.19757476],
#        [0.1963312 ],
#        [0.19375056],
#        [0.18885617],
#        [0.18953265],
#        [0.19129336],
#        [0.18850042],
#        [0.19558926],
#        [0.20184726],
#        [0.20403782],
#        [0.2003398 ],
#        [0.18976441],
#        [0.18503264],
#        [0.18059862],
#        [0.17641038],
#        [0.17518903],
#        [0.18006599],
#        [0.17968526],
#        [0.17702314],
#        [0.17402965],
#        [0.16887045],
#        [0.16838105],
#        [0.16845101],
#        [0.17320903],
#        [0.1764611 ],
#        [0.18035641],
#        [0.18591475],
#        [0.18433365],
#        [0.18164772],
#        [0.182523  ],
#        [0.19086376],
#        [0.20371509],
#        [0.20594421],
#        [0.2083629 ],
#        [0.2164553 ],
#        [0.2192091 ],
#        [0.22091404],
#        [0.21969554],
#        [0.21306105],
#        [0.21185046],
#        [0.21050903],
#        [0.21779397],
#        [0.22566617],
#        [0.25287157],
#        [0.24142244],
#        [0.22799948],
#        [0.21463203],
#        [0.21064109],
#        [0.21807921],
#        [0.21240593],
#        [0.21057455],
#        [0.21141014],
#        [0.21593465],
#        [0.22095853],
#        [0.22110914],
#        [0.21542677],
#        [0.21146382],
#        [0.21218255],
#        [0.21271953],
#        [0.20939597],
#        [0.20699646],
#        [0.20384279],
#        [0.20014967],
#        [0.22321916],
#        [0.22180244],
#        [0.21758556],
#        [0.21026553],
#        [0.20326847],
#        [0.19349054],
#        [0.19420968],
#        [0.1963571 ],
#        [0.19753805],
#        [0.20381904],
#        [0.20046982],
#        [0.19558895],
#        [0.19166884],
#        [0.18702143],
#        [0.16696046],
#        [0.15768635],
#        [0.1335855 ],
#        [0.11839397],
#        [0.11918577],
#        [0.12667467],
#        [0.13649337],
#        [0.13710168],
#        [0.13633262],
#        [0.12780938],
#        [0.12426507],
#        [0.12125084],
#        [0.12155482],
#        [0.12492411],
#        [0.12519407],
#        [0.12507902],
#        [0.12389053],
#        [0.11835355],
#        [0.11747816],
#        [0.11868154],
#        [0.12118272],
#        [0.1279459 ],
#        [0.13032699],
#        [0.12569535],
#        [0.12266974],
#        [0.11887064],
#        [0.11849929],
#        [0.11909546],
#        [0.1213989 ],
#        [0.12116982],
#        [0.11935452],
#        [0.11762816],
#        [0.11296421],
#        [0.10484748],
#        [0.09494035],
#        [0.08015962],
#        [0.07393018],
#        [0.08054534],
#        [0.08065554],
#        [0.08200255],
#        [0.07848466],
#        [0.08210851],
#        [0.08492602],
#        [0.09160788],
#        [0.09209415],
#        [0.09302446],
#        [0.09594291],
#        [0.09908602],
#        [0.10523993],
#        [0.10803461],
#        [0.10255735],
#        [0.10071576],
#        [0.09698323],
#        [0.09526449],
#        [0.09571675],
#        [0.09731913],
#        [0.10077026],
#        [0.10063762],
#        [0.10085214],
#        [0.10247436],
#        [0.10217872],
#        [0.10185735],
#        [0.0994657 ]], dtype=float32)

# %%
##Transformback to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
test_predict
# Out:
# array([[0.2646431 ],
#        [0.2707041 ],
#        [0.2703642 ],
#        [0.25499374],
#        [0.24300332],
#        [0.22792411],
#        [0.22992045],
#        [0.2371651 ],
#        [0.2392492 ],
#        [0.23405825],
#        [0.23265913],
#        [0.22906733],
#        [0.22379766],
#        [0.21148653],
#        [0.20765267],
#        [0.2102553 ],
#        [0.21958466],
#        [0.22583489],
#        [0.22391129],
#        [0.21955377],
#        [0.20951277],
#        [0.19004661],
#        [0.1747724 ],
#        [0.17486961],
#        [0.18004888],
#        [0.18712124],
#        [0.18442786],
#        [0.17613451],
#        [0.1723333 ],
#        [0.17213728],
#        [0.16606805],
#        [0.17737323],
#        [0.1878769 ],
#        [0.18829857],
#        [0.18193616],
#        [0.17795208],
#        [0.17459947],
#        [0.172712  ],
#        [0.17563263],
#        [0.18013951],
#        [0.19023664],
#        [0.19729702],
#        [0.20169403],
#        [0.20130499],
#        [0.19744815],
#        [0.18560335],
#        [0.17437933],
#        [0.17242157],
#        [0.17481074],
#        [0.18008828],
#        [0.18435074],
#        [0.18256222],
#        [0.1782484 ],
#        [0.16863714],
#        [0.16343603],
#        [0.15940244],
#        [0.1571014 ],
#        [0.15667689],
#        [0.15231933],
#        [0.15585814],
#        [0.16462775],
#        [0.17713831],
#        [0.19118406],
#        [0.19813508],
#        [0.1928671 ],
#        [0.18181026],
#        [0.1709657 ],
#        [0.16500694],
#        [0.16065538],
#        [0.15248676],
#        [0.14204173],
#        [0.14234535],
#        [0.14272776],
#        [0.14711592],
#        [0.15051858],
#        [0.14990588],
#        [0.14822741],
#        [0.14755392],
#        [0.14523706],
#        [0.14567451],
#        [0.14742364],
#        [0.14547598],
#        [0.14392091],
#        [0.14951935],
#        [0.15379594],
#        [0.16007121],
#        [0.17073911],
#        [0.17161386],
#        [0.16939206],
#        [0.16173516],
#        [0.15211308],
#        [0.1473142 ],
#        [0.1502487 ],
#        [0.15287647],
#        [0.1584364 ],
#        [0.15955941],
#        [0.15142101],
#        [0.14450121],
#        [0.14270507],
#        [0.14115693],
#        [0.13612758],
#        [0.1352773 ],
#        [0.13351282],
#        [0.13016634],
#        [0.13062887],
#        [0.13183273],
#        [0.12992309],
#        [0.13477   ],
#        [0.13904884],
#        [0.14054662],
#        [0.13801813],
#        [0.13078733],
#        [0.12755203],
#        [0.12452032],
#        [0.12165666],
#        [0.12082158],
#        [0.12415615],
#        [0.12389583],
#        [0.12207563],
#        [0.12002886],
#        [0.11650132],
#        [0.1161667 ],
#        [0.11621453],
#        [0.11946777],
#        [0.12169134],
#        [0.12435472],
#        [0.12815517],
#        [0.12707411],
#        [0.12523763],
#        [0.12583609],
#        [0.131539  ],
#        [0.14032595],
#        [0.1418501 ],
#        [0.14350384],
#        [0.14903693],
#        [0.15091982],
#        [0.15208554],
#        [0.15125242],
#        [0.14671615],
#        [0.14588843],
#        [0.14497124],
#        [0.14995223],
#        [0.15533476],
#        [0.17393616],
#        [0.16610795],
#        [0.15693013],
#        [0.1477903 ],
#        [0.14506154],
#        [0.15014726],
#        [0.14626823],
#        [0.14501604],
#        [0.14558735],
#        [0.14868094],
#        [0.15211597],
#        [0.15221894],
#        [0.1483337 ],
#        [0.14562407],
#        [0.1461155 ],
#        [0.14648265],
#        [0.1442102 ],
#        [0.14256956],
#        [0.14041327],
#        [0.13788813],
#        [0.15366165],
#        [0.15269299],
#        [0.14980975],
#        [0.14480475],
#        [0.14002058],
#        [0.13333502],
#        [0.13382673],
#        [0.13529502],
#        [0.13610247],
#        [0.14039703],
#        [0.13810705],
#        [0.1347698 ],
#        [0.13208947],
#        [0.12891185],
#        [0.11519539],
#        [0.10885432],
#        [0.09237562],
#        [0.08198857],
#        [0.08252995],
#        [0.08765042],
#        [0.09436385],
#        [0.09477977],
#        [0.09425393],
#        [0.08842626],
#        [0.08600289],
#        [0.08394193],
#        [0.08414977],
#        [0.08645349],
#        [0.08663808],
#        [0.08655941],
#        [0.08574679],
#        [0.08196093],
#        [0.0813624 ],
#        [0.08218519],
#        [0.08389535],
#        [0.0885196 ],
#        [0.09014765],
#        [0.08698082],
#        [0.08491208],
#        [0.08231449],
#        [0.08206058],
#        [0.08246821],
#        [0.08404317],
#        [0.08388653],
#        [0.08264533],
#        [0.08146496],
#        [0.07827603],
#        [0.07272631],
#        [0.06595242],
#        [0.05584626],
#        [0.05158695],
#        [0.05610999],
#        [0.05618533],
#        [0.05710634],
#        [0.05470102],
#        [0.05717879],
#        [0.05910523],
#        [0.06367388],
#        [0.06400637],
#        [0.06464245],
#        [0.0666379 ],
#        [0.06878698],
#        [0.07299464],
#        [0.07490548],
#        [0.07116046],
#        [0.06990129],
#        [0.06734922],
#        [0.06617405],
#        [0.06648327],
#        [0.06757888],
#        [0.06993856],
#        [0.06984787],
#        [0.06999454],
#        [0.07110371],
#        [0.07090157],
#        [0.07068184],
#        [0.06904658]], dtype=float32)

# %%
### Calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 0.04761678197878784

# %%
### Test Data RMSE
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 0.057978759734941855

# %%
test_predict.shape
# Out:
# (240, 1)

# %%
# targets = test[price_column][window_len:]
# preds = model.predict(X_test).squeeze()
# preds
# mean_absolute_error(preds, y_test)

# %%
targets = test[price_column][window_len+1:]
targets
# Out:
# Date
# 2021-11-15    0.256529
# 2021-11-16    0.237249
# 2021-11-17    0.237487
# 2021-11-18    0.221383
# 2021-11-19    0.233110
#                 ...
# 2022-07-08    0.069257
# 2022-07-09    0.069512
# 2022-07-10    0.067263
# 2022-07-11    0.061847
# 2022-07-12    0.060462
# Name: Close, Length: 240, dtype: float64

# %%
preds = pd.Series(index=targets.index, data=test_predict.squeeze())
preds
# Out:
# Date
# 2021-11-15    0.264643
# 2021-11-16    0.270704
# 2021-11-17    0.270364
# 2021-11-18    0.254994
# 2021-11-19    0.243003
#                 ...
# 2022-07-08    0.069995
# 2022-07-09    0.071104
# 2022-07-10    0.070902
# 2022-07-11    0.070682
# 2022-07-12    0.069047
# Length: 240, dtype: float32

# %%
def line_plot(line1, line2, label1=None, label2=None, title='', lw=2):
    fig, ax = plt.subplots(1, figsize=(13, 7))
    ax.plot(line1, label=label1, linewidth=lw)
    ax.plot(line2, label=label2, linewidth=lw)
    ax.set_ylabel('Price [USD]', fontsize=14)
    ax.set_xlabel('Time', fontsize = 14)
    ax.set_title(title, fontsize=16)
    ax.legend(loc='best', fontsize=16)
line_plot(train["Close"], test["Close"], 'Training Prices', 'Testing Prices', title='Project Outline')

# %%
line_plot(targets, preds, 'actual_value', 'predicted_value', lw=3)

# %% [markdown]
# ### Future Prediction for 30 days

# %%
len(test)
# Out:
# 341

# %%
len(test_scaled)
# Out:
# 341

# %%
#Getting the last 100 days records
fut_inp = test_scaled[241:]
fut_inp.shape
# Out:
# (100, 1)

# %%
fut_inp = fut_inp.reshape(1,-1)

# %%
fut_inp.shape
# Out:
# (1, 100)

# %%
fut_inp
# Out:
# array([[0.21580311, 0.25136638, 0.20823589, 0.21216283, 0.2069664 ,
#         0.20953171, 0.21718375, 0.1954196 , 0.20042443, 0.20335537,
#         0.20897155, 0.21205167, 0.20866734, 0.20244713, 0.20365666,
#         0.20713606, 0.20452249, 0.19792201, 0.19796589, 0.19481557,
#         0.19146048, 0.22950424, 0.1999725 , 0.20279961, 0.19938164,
#         0.19596513, 0.18503991, 0.19266855, 0.18998477, 0.18791088,
#         0.19710884, 0.18631671, 0.18554302, 0.18500334, 0.18014038,
#         0.15179184, 0.15713452, 0.12218551, 0.11939205, 0.12767006,
#         0.12981269, 0.13426907, 0.12695341, 0.13042257, 0.12082242,
#         0.12531829, 0.12130213, 0.12201293, 0.12441443, 0.12024325,
#         0.12080487, 0.11985129, 0.11292906, 0.11743809, 0.11817521,
#         0.11941399, 0.12699729, 0.12406342, 0.11703004, 0.11953977,
#         0.11613203, 0.11808453, 0.11728306, 0.11918583, 0.11623587,
#         0.1146651 , 0.11451446, 0.10883685, 0.10070656, 0.09257626,
#         0.07734384, 0.07978776, 0.0906223 , 0.07896434, 0.08183971,
#         0.07601439, 0.08681383, 0.08649353, 0.09438251, 0.08873708,
#         0.09213165, 0.09665384, 0.09867069, 0.10550663, 0.10413476,
#         0.09494705, 0.10008205, 0.09513572, 0.09526588, 0.0960308 ,
#         0.09673428, 0.1000879 , 0.09669918, 0.0987877 , 0.10176836,
#         0.09977345, 0.1001464 , 0.09685713, 0.08893598, 0.08691036]])

# %%
tmp_inp = list(fut_inp)

# %%
tmp_inp
# Out:
# [array([0.21580311, 0.25136638, 0.20823589, 0.21216283, 0.2069664 ,
#         0.20953171, 0.21718375, 0.1954196 , 0.20042443, 0.20335537,
#         0.20897155, 0.21205167, 0.20866734, 0.20244713, 0.20365666,
#         0.20713606, 0.20452249, 0.19792201, 0.19796589, 0.19481557,
#         0.19146048, 0.22950424, 0.1999725 , 0.20279961, 0.19938164,
#         0.19596513, 0.18503991, 0.19266855, 0.18998477, 0.18791088,
#         0.19710884, 0.18631671, 0.18554302, 0.18500334, 0.18014038,
#         0.15179184, 0.15713452, 0.12218551, 0.11939205, 0.12767006,
#         0.12981269, 0.13426907, 0.12695341, 0.13042257, 0.12082242,
#         0.12531829, 0.12130213, 0.12201293, 0.12441443, 0.12024325,
#         0.12080487, 0.11985129, 0.11292906, 0.11743809, 0.11817521,
#         0.11941399, 0.12699729, 0.12406342, 0.11703004, 0.11953977,
#         0.11613203, 0.11808453, 0.11728306, 0.11918583, 0.11623587,
#         0.1146651 , 0.11451446, 0.10883685, 0.10070656, 0.09257626,
#         0.07734384, 0.07978776, 0.0906223 , 0.07896434, 0.08183971,
#         0.07601439, 0.08681383, 0.08649353, 0.09438251, 0.08873708,
#         0.09213165, 0.09665384, 0.09867069, 0.10550663, 0.10413476,
#         0.09494705, 0.10008205, 0.09513572, 0.09526588, 0.0960308 ,
#         0.09673428, 0.1000879 , 0.09669918, 0.0987877 , 0.10176836,
#         0.09977345, 0.1001464 , 0.09685713, 0.08893598, 0.08691036])]

# %%
#Creating list of the last 100 data
tmp_inp = tmp_inp[0].tolist()

# %%
tmp_inp
# Out:
# [0.21580310615600398,
#  0.2513663839564512,
#  0.20823589118069905,
#  0.21216282821368976,
#  0.20696640092198926,
#  0.20953170727426693,
#  0.21718374993966996,
#  0.1954195972439776,
#  0.20042443095976684,
#  0.20335537390729505,
#  0.20897155201034312,
#  0.21205167468873357,
#  0.2086673423630947,
#  0.20244713260469274,
#  0.20365665846178146,
#  0.20713605630218548,
#  0.20452248591933472,
#  0.19792201410187218,
#  0.19796589049330227,
#  0.19481556558862373,
#  0.1914604841906049,
#  0.22950424065323172,
#  0.19997250412803716,
#  0.20279960628251423,
#  0.19938163539011233,
#  0.19596512704409141,
#  0.18503990557800565,
#  0.19266854750131265,
#  0.18998477489217377,
#  0.18791088412391277,
#  0.19710883831403506,
#  0.18631670856862048,
#  0.18554302153307037,
#  0.1850033419184806,
#  0.18014037520164858,
#  0.15179183869868473,
#  0.15713452062848543,
#  0.12218551230805907,
#  0.11939204872034505,
#  0.12767006123681698,
#  0.12981269168498508,
#  0.1342690705078985,
#  0.12695341351012596,
#  0.13042257352586295,
#  0.12082241908096511,
#  0.1253182866561656,
#  0.1213021342939338,
#  0.12201293183510083,
#  0.1244144329927063,
#  0.12024325071408827,
#  0.1208048685243931,
#  0.11985128828397972,
#  0.11292905626269674,
#  0.11743808675532624,
#  0.1181752101313513,
#  0.11941398691606007,
#  0.126997289901556,
#  0.12406342186126579,
#  0.11703003631502665,
#  0.11953976590482626,
#  0.11613203283709135,
#  0.11808453225572917,
#  0.11728305683894001,
#  0.11918582968062376,
#  0.1162358736301425,
#  0.11466509881694623,
#  0.11451445653970303,
#  0.10883685148865282,
#  0.10070655615666212,
#  0.09257626082467141,
#  0.07734384026653446,
#  0.07978775526918898,
#  0.09062229885965259,
#  0.0789643416566848,
#  0.08183970784173493,
#  0.07601438560620354,
#  0.0868138280835231,
#  0.08649353042608364,
#  0.09438250560520901,
#  0.08873707657454089,
#  0.09213164672484678,
#  0.09665384013490529,
#  0.09867069159430718,
#  0.10550663337911105,
#  0.10413476487373106,
#  0.09494704850827583,
#  0.10008204885197423,
#  0.0951357169914251,
#  0.09526588361933429,
#  0.09603079537659838,
#  0.0967342801858604,
#  0.10008789903749825,
#  0.09669917907271636,
#  0.09878769530478737,
#  0.10176836482926965,
#  0.09977345156558277,
#  0.10014640089273832,
#  0.09685713408186458,
#  0.08893598288235716,
#  0.08691035614466924]

# %%
#Predicting next 30 days price suing the current data
#It will predict in sliding window manner (algorithm) with stride 1
lst_output=[]
n_steps=100
i=0
while(i<30):
    
    if(len(tmp_inp)>100):
        fut_inp = np.array(tmp_inp[1:])
        fut_inp=fut_inp.reshape(1,-1)
        fut_inp = fut_inp.reshape((1, n_steps, 1))
        yhat = model.predict(fut_inp, verbose=0)
        tmp_inp.extend(yhat[0].tolist())
        tmp_inp = tmp_inp[1:]
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        fut_inp = fut_inp.reshape((1, n_steps,1))
        yhat = model.predict(fut_inp, verbose=0)
        tmp_inp.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i=i+1
    

print(lst_output)
# Out:
# [[0.08709654957056046], [0.08480767905712128], [0.08354143798351288], [0.08295869827270508], [0.08271109312772751], [0.08252943307161331], [0.08225322514772415], [0.08182042837142944], [0.08123691380023956], [0.0805421844124794], [0.07978137582540512], [0.07898835837841034], [0.07817921787500381], [0.07735335826873779], [0.07649841159582138], [0.07559601962566376], [0.0746263712644577], [0.07357102632522583], [0.07241383194923401], [0.07114055752754211], [0.06973785907030106], [0.06819212436676025], [0.06648842990398407], [0.06460974365472794], [0.0625365823507309], [0.06024667248129845], [0.05771477892994881], [0.054912466555833817], [0.05180785432457924], [0.04836509749293327]]

# %%
# from datetime import date
# from datetime import datetime

# end_date = test[-1:].index.value()
end_date
# Out:
# '2022-07-12'

# %%
temp = pd.to_datetime(end_date, format='%Y-%m-%d')
temp
end_date_new = temp.strftime('%m/%d/%Y')
end_date_new
# Out:
# '07/12/2022'

# %%
preds = scaler.inverse_transform(lst_output)
preds
# Out:
# array([[0.06058931],
#        [0.05902432],
#        [0.05815854],
#        [0.0577601 ],
#        [0.0575908 ],
#        [0.05746659],
#        [0.05727774],
#        [0.05698182],
#        [0.05658285],
#        [0.05610783],
#        [0.05558764],
#        [0.05504542],
#        [0.05449218],
#        [0.05392751],
#        [0.05334295],
#        [0.05272595],
#        [0.05206296],
#        [0.05134138],
#        [0.05055016],
#        [0.04967957],
#        [0.04872049],
#        [0.04766361],
#        [0.04649873],
#        [0.0452142 ],
#        [0.0437967 ],
#        [0.042231  ],
#        [0.04049985],
#        [0.03858379],
#        [0.03646105],
#        [0.0341071 ]])

# %%
# preds = pd.Series(data=lst_output.squeeze())
# preds

# %%
import datetime
date_future = temp + datetime.timedelta(29)
date_future_str = date_future.strftime('%m/%d/%Y')
date_future_str
# Out:
# '08/10/2022'

# %%
c = pd.date_range(start=end_date_new, end=date_future_str)
c
# Out:
# DatetimeIndex(['2022-07-12', '2022-07-13', '2022-07-14', '2022-07-15',
#                '2022-07-16', '2022-07-17', '2022-07-18', '2022-07-19',
#                '2022-07-20', '2022-07-21', '2022-07-22', '2022-07-23',
#                '2022-07-24', '2022-07-25', '2022-07-26', '2022-07-27',
#                '2022-07-28', '2022-07-29', '2022-07-30', '2022-07-31',
#                '2022-08-01', '2022-08-02', '2022-08-03', '2022-08-04',
#                '2022-08-05', '2022-08-06', '2022-08-07', '2022-08-08',
#                '2022-08-09', '2022-08-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
len(c)
# Out:
# 30

# %%
fut_preds = pd.Series(index=c, data=preds.squeeze())
fut_preds
# Out:
# 2022-07-12    0.060589
# 2022-07-13    0.059024
# 2022-07-14    0.058159
# 2022-07-15    0.057760
# 2022-07-16    0.057591
# 2022-07-17    0.057467
# 2022-07-18    0.057278
# 2022-07-19    0.056982
# 2022-07-20    0.056583
# 2022-07-21    0.056108
# 2022-07-22    0.055588
# 2022-07-23    0.055045
# 2022-07-24    0.054492
# 2022-07-25    0.053928
# 2022-07-26    0.053343
# 2022-07-27    0.052726
# 2022-07-28    0.052063
# 2022-07-29    0.051341
# 2022-07-30    0.050550
# 2022-07-31    0.049680
# 2022-08-01    0.048720
# 2022-08-02    0.047664
# 2022-08-03    0.046499
# 2022-08-04    0.045214
# 2022-08-05    0.043797
# 2022-08-06    0.042231
# 2022-08-07    0.040500
# 2022-08-08    0.038584
# 2022-08-09    0.036461
# 2022-08-10    0.034107
# Freq: D, dtype: float64

# %%
fig, ax = plt.subplots(1, figsize=(13, 7))
ax.plot(fut_preds, label="predicted value_30", linewidth=3)
# ax.plot(line2, label=label2, linewidth=lw)

# %%
line_plot(doge_price["Close"], fut_preds, 'actual_value', 'predicted_value_30', lw=3)
