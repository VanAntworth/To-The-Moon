# %%
import pandas as pd 
import datetime

# %%
# Database related all the code is moved to this file
# %run -i "SqlConn.py"
#importing local py file
import SqlConn

# %%
#Fetch Tweets and Sentiment data - Join from Tweet and Sentiment tables
try:
    df_dbSentimentData = SqlConn.fetchFinanceDeltaPercents()
    print("Data transfer Done")
except BaseException as err:
    print(err)
# Out:
# Data transfer Done

# %%
df_dbSentimentData
# Out:
#         id              tweetID financeType        date  \
# 0        1   153099684280410112       tesla  2011-12-31
# 1        2   156927468836630528       tesla  2012-01-10
# 2        3   157700726515183616       tesla  2012-01-12
# 3        4   159330976378519552       tesla  2012-01-17
# 4        5   159396536621596672       tesla  2012-01-17
# ...    ...                  ...         ...         ...
# 3013  3014  1530209049261658112        doge  2022-05-27
# 3014  3015  1531696049064116225        doge  2022-05-31
# 3015  3016  1531699416490557440        doge  2022-05-31
# 3016  3017  1538406040374595585        doge  2022-06-19
# 3017  3018  1544743525585141761        doge  2022-07-06
#
#                                                fullText  likesCount  \
# 0     Hacked my Tesla charge connector on a small is...         405
# 1     The exec conf room at Tesla used to be called ...         315
# 2     A Tesla Roadster just passed the 100,000 mile ...          15
# 3     Will communicate better in the future. Too man...         163
# 4     That's not just paranoia (a healthy trait at t...          16
# ...                                                 ...         ...
# 3013  Tesla merch can be bought with Doge, soon Spac...      203072
# 3014  And Palmer always forgets to mention that he n...        3650
# 3015  You’re humble bro. Billy’s sense of humor &amp...       12148
# 3016                    I will keep supporting Dogecoin      396094
# 3017                  Supporting Doge wherever possible       10683
#
#       retweetCount sentiment  sentimentScore   startDate  ...   deltaVol_6  \
# 0               32                   -0.4019  2011-12-30  ...          NaN
# 1               67                    0.6616  2012-01-09  ...          NaN
# 2               51                    0.0000  2012-01-11  ...          NaN
# 3               43                   -0.0772  2012-01-13  ...          NaN
# 4               14                    0.0875  2012-01-13  ...          NaN
# ...            ...       ...             ...         ...  ...          ...
# 3013         19452                    0.0000  2022-05-26  ... -277380266.0
# 3014           310                    0.0000  2022-05-30  ... -186989464.0
# 3015          1228                    0.7430  2022-05-30  ... -186989464.0
# 3016         37257                    0.4404  2022-06-18  ... -219674079.0
# 3017          2073                    0.4404  2022-07-05  ... -104758604.0
#
#      deltaVol_7  percentVol_0  percentVol_1  percentVol_2  percentVol_3  \
# 0          None    173.131254     85.432607    195.909358    190.258976
# 1          None    -25.105909    -25.050167    -18.695652    513.199554
# 2          None      8.478358    718.146661    591.893500     87.446081
# 3          None    -15.431605    -77.088939    -77.341648    -87.959058
# 4          None    -15.431605    -77.088939    -77.341648    -87.959058
# ...         ...           ...           ...           ...           ...
# 3013       None     84.025066    -24.772231    -44.519239     -2.977158
# 3014       None     -2.642573     20.276895    -37.090973    -41.604004
# 3015       None     -2.642573     20.276895    -37.090973    -41.604004
# 3016       None     78.764656    -23.503963     61.248728     -2.870662
# 3017       None     -1.064971     -0.155980     10.205093    -36.939707
#
#       percentVol_4  percentVol_5  percentVol_6 percentVol_7
# 0              NaN           NaN           NaN         None
# 1              NaN           NaN           NaN         None
# 2              NaN           NaN           NaN         None
# 3              NaN           NaN           NaN         None
# 4              NaN           NaN           NaN         None
# ...            ...           ...           ...          ...
# 3013     -5.541058     16.696061    -38.963874         None
# 3014    -49.278787    -59.081293    -27.072585         None
# 3015    -49.278787    -59.081293    -27.072585         None
# 3016    -33.444861    -21.095632    -33.674476         None
# 3017    -25.646145    -19.119750    -25.980464         None
#
# [3018 rows x 44 columns]

# %%
df_dbSentimentData.drop_duplicates()
# Out:
#         id              tweetID financeType        date  \
# 0        1   153099684280410112       tesla  2011-12-31
# 1        2   156927468836630528       tesla  2012-01-10
# 2        3   157700726515183616       tesla  2012-01-12
# 3        4   159330976378519552       tesla  2012-01-17
# 4        5   159396536621596672       tesla  2012-01-17
# ...    ...                  ...         ...         ...
# 3013  3014  1530209049261658112        doge  2022-05-27
# 3014  3015  1531696049064116225        doge  2022-05-31
# 3015  3016  1531699416490557440        doge  2022-05-31
# 3016  3017  1538406040374595585        doge  2022-06-19
# 3017  3018  1544743525585141761        doge  2022-07-06
#
#                                                fullText  likesCount  \
# 0     Hacked my Tesla charge connector on a small is...         405
# 1     The exec conf room at Tesla used to be called ...         315
# 2     A Tesla Roadster just passed the 100,000 mile ...          15
# 3     Will communicate better in the future. Too man...         163
# 4     That's not just paranoia (a healthy trait at t...          16
# ...                                                 ...         ...
# 3013  Tesla merch can be bought with Doge, soon Spac...      203072
# 3014  And Palmer always forgets to mention that he n...        3650
# 3015  You’re humble bro. Billy’s sense of humor &amp...       12148
# 3016                    I will keep supporting Dogecoin      396094
# 3017                  Supporting Doge wherever possible       10683
#
#       retweetCount sentiment  sentimentScore   startDate  ...   deltaVol_6  \
# 0               32                   -0.4019  2011-12-30  ...          NaN
# 1               67                    0.6616  2012-01-09  ...          NaN
# 2               51                    0.0000  2012-01-11  ...          NaN
# 3               43                   -0.0772  2012-01-13  ...          NaN
# 4               14                    0.0875  2012-01-13  ...          NaN
# ...            ...       ...             ...         ...  ...          ...
# 3013         19452                    0.0000  2022-05-26  ... -277380266.0
# 3014           310                    0.0000  2022-05-30  ... -186989464.0
# 3015          1228                    0.7430  2022-05-30  ... -186989464.0
# 3016         37257                    0.4404  2022-06-18  ... -219674079.0
# 3017          2073                    0.4404  2022-07-05  ... -104758604.0
#
#      deltaVol_7  percentVol_0  percentVol_1  percentVol_2  percentVol_3  \
# 0          None    173.131254     85.432607    195.909358    190.258976
# 1          None    -25.105909    -25.050167    -18.695652    513.199554
# 2          None      8.478358    718.146661    591.893500     87.446081
# 3          None    -15.431605    -77.088939    -77.341648    -87.959058
# 4          None    -15.431605    -77.088939    -77.341648    -87.959058
# ...         ...           ...           ...           ...           ...
# 3013       None     84.025066    -24.772231    -44.519239     -2.977158
# 3014       None     -2.642573     20.276895    -37.090973    -41.604004
# 3015       None     -2.642573     20.276895    -37.090973    -41.604004
# 3016       None     78.764656    -23.503963     61.248728     -2.870662
# 3017       None     -1.064971     -0.155980     10.205093    -36.939707
#
#       percentVol_4  percentVol_5  percentVol_6 percentVol_7
# 0              NaN           NaN           NaN         None
# 1              NaN           NaN           NaN         None
# 2              NaN           NaN           NaN         None
# 3              NaN           NaN           NaN         None
# 4              NaN           NaN           NaN         None
# ...            ...           ...           ...          ...
# 3013     -5.541058     16.696061    -38.963874         None
# 3014    -49.278787    -59.081293    -27.072585         None
# 3015    -49.278787    -59.081293    -27.072585         None
# 3016    -33.444861    -21.095632    -33.674476         None
# 3017    -25.646145    -19.119750    -25.980464         None
#
# [3018 rows x 44 columns]

# %%
df_sentiment_percentage = df_dbSentimentData[["date","sentimentScore","likesCount","retweetCount","percentVol_1","percentVol_2","percentVol_3"]]
#df_sentiment_percentage.set_index("date", inplace=True)

# %%
df_sentiment_percentage.shape
# Out:
# (3018, 7)

# %%
df_sentiment_percentage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3018 entries, 0 to 3017
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            3018 non-null   object
#  1   sentimentScore  3018 non-null   float64
#  2   likesCount      3018 non-null   int64
#  3   retweetCount    3018 non-null   int64
#  4   percentVol_1    3012 non-null   float64
#  5   percentVol_2    3012 non-null   float64
#  6   percentVol_3    3010 non-null   float64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 165.2+ KB

# %%
i=0
impact = []
for i in range(0, len(df_sentiment_percentage)):
    row = df_sentiment_percentage.iloc[i]
    if (row["sentimentScore"] > 0.0 and row["percentVol_1"] > 0.0):

        impact.append(1)
    else:
        if(row["sentimentScore"] < 0.0 and row["percentVol_1"] < 0.0):
            impact.append(1)
        else:
              impact.append(0)
   
df = pd.DataFrame(impact,columns=["impact"])
df_sentiment_percentage = pd.concat([df_sentiment_percentage,df],axis=1)

# %%
df_sentiment_percentage.set_index("date", inplace=True)

# %%
df_sentiment_percentage
# Out:
#             sentimentScore  likesCount  retweetCount  percentVol_1  \
# date
# 2011-12-31         -0.4019         405            32     85.432607
# 2012-01-10          0.6616         315            67    -25.050167
# 2012-01-12          0.0000          15            51    718.146661
# 2012-01-17         -0.0772         163            43    -77.088939
# 2012-01-17          0.0875          16            14    -77.088939
# ...                    ...         ...           ...           ...
# 2022-05-27          0.0000      203072         19452    -24.772231
# 2022-05-31          0.0000        3650           310     20.276895
# 2022-05-31          0.7430       12148          1228     20.276895
# 2022-06-19          0.4404      396094         37257    -23.503963
# 2022-07-06          0.4404       10683          2073     -0.155980
#
#             percentVol_2  percentVol_3  impact
# date
# 2011-12-31    195.909358    190.258976       0
# 2012-01-10    -18.695652    513.199554       0
# 2012-01-12    591.893500     87.446081       0
# 2012-01-17    -77.341648    -87.959058       1
# 2012-01-17    -77.341648    -87.959058       0
# ...                  ...           ...     ...
# 2022-05-27    -44.519239     -2.977158       0
# 2022-05-31    -37.090973    -41.604004       0
# 2022-05-31    -37.090973    -41.604004       1
# 2022-06-19     61.248728     -2.870662       0
# 2022-07-06     10.205093    -36.939707       0
#
# [3018 rows x 7 columns]

# %%
df_sentiment_percentage.dropna(inplace=True)

# %%
df_sentiment_percentage.shape
# Out:
# (3010, 7)

# %%
df_sentiment_percentage["impact"].value_counts()
# Out:
# 0    1880
# 1    1130
# Name: impact, dtype: int64

# %%
df_sentiment_percentage[["sentimentScore","impact"]].plot(figsize=(16,4))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
#Lets see the scaled values
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(pd.DataFrame(df_sentiment_percentage)),columns=["sentimentScore","likesCount","retweetCount","percentVol_1","percentVol_2","percentVol_3","impact"])

df_scaled.index = df_sentiment_percentage.index
df_scaled
# Out:
#             sentimentScore  likesCount  retweetCount  percentVol_1  \
# date
# 2011-12-31       -1.483011   -0.319654     -0.301605      0.718075
# 2012-01-10        1.018959   -0.320245     -0.299559     -0.551355
# 2012-01-12       -0.537509   -0.322218     -0.300494      7.987861
# 2012-01-17       -0.719128   -0.321245     -0.300962     -1.149272
# 2012-01-17       -0.331658   -0.322211     -0.302657     -1.149272
# ...                    ...         ...           ...           ...
# 2022-05-27       -0.537509    1.012749      0.833809     -0.548162
# 2022-05-31       -0.537509   -0.298320     -0.285351     -0.030554
# 2022-05-31        1.210459   -0.242451     -0.231679     -0.030554
# 2022-06-19        0.498568    2.281742      1.874799     -0.533589
# 2022-07-06        0.498568   -0.252083     -0.182275     -0.265325
#
#             percentVol_2  percentVol_3    impact
# date
# 2011-12-31      1.995936      1.974852 -0.775283
# 2012-01-10     -0.418905      5.648818 -0.775283
# 2012-01-12      6.451745      0.805191 -0.775283
# 2012-01-17     -1.078818     -1.190323  1.289851
# 2012-01-17     -1.078818     -1.190323 -0.775283
# ...                  ...           ...       ...
# 2022-05-27     -0.709484     -0.223518 -0.775283
# 2022-05-31     -0.625898     -0.662960 -0.775283
# 2022-05-31     -0.625898     -0.662960  1.289851
# 2022-06-19      0.480669     -0.222306 -0.775283
# 2022-07-06     -0.093699     -0.609896 -0.775283
#
# [3010 rows x 7 columns]

# %%
from matplotlib import style
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(30, 5))

ax1 = fig.add_subplot(1,2,1)
df_scaled[["sentimentScore","impact"]].plot(ax=ax1)
ax1.set_ylabel('sentiment Score')
ax1.set_title('Sentiment vs Adjusted Close Percentage difference')

plt.show()

# %% [markdown]
# # Train Split

# %%
X = df_sentiment_percentage[["sentimentScore","likesCount","retweetCount"]]

y = df_sentiment_percentage["impact"].values.reshape(-1,1)

# %%
SPLIT = int(0.6 * len(X))
X_train = X[:SPLIT]
X_test = X[SPLIT:]

y_train = y[:SPLIT]
y_test = y[SPLIT:]

# %%
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
rfc = RandomForestClassifier(n_estimators=128, random_state=78) 
rfc.fit(X_train, y_train)
# Out:
# C:\Users\15125\AppData\Local\Temp/ipykernel_28656/1859614513.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfc.fit(X_train, y_train)
# RandomForestClassifier(n_estimators=128, random_state=78)

# %%
rfC_model = rfc.fit(X_train_scaled, y_train)
# Out:
# C:\Users\15125\AppData\Local\Temp/ipykernel_28656/340295679.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfC_model = rfc.fit(X_train_scaled, y_train)

# %%
predictions = rfC_model.predict(X_test_scaled)

# %%
# SAVE THE TRAINED MODEL
import pickle
filename = 'finalized_model.sav'
pickle.dump(rfC_model, open(filename, 'wb'))

# %%
# Calculating the confusion matrix.
cm = confusion_matrix(y_test, predictions)

# Create a DataFrame from the confusion matrix.
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])

cm_df
# Out:
#           Predicted 0  Predicted 1
# Actual 0          758            1
# Actual 1            5          440

# %%
acc_score = accuracy_score(y_test, predictions)
acc_score
# Out:
# 0.9950166112956811

# %%
# Displaying results
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0          758            1
# Actual 1            5          440
# Accuracy Score : 0.9950166112956811
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       759
#            1       1.00      0.99      0.99       445
#
#     accuracy                           1.00      1204
#    macro avg       1.00      0.99      0.99      1204
# weighted avg       1.00      1.00      1.00      1204

# %% [markdown]
# # Forecast if sentiment score will impact the prices ?

# %%
x_forecast_sentimentscore = np.array([-0.8 ])
x_forecast_likecount=np.array([233433])
x_forecast_retweetscore=np.array([34534])
x_forecast_date=["2022-07-27"]

# %%
x_F_retweetcount = pd.DataFrame(x_forecast_retweetscore,pd.to_datetime(x_forecast_date))
x_F_retweetcount
# Out:
#                 0
# 2022-07-27  34534

# %%
x_forecast = pd.DataFrame(pd.concat([pd.DataFrame(x_forecast_sentimentscore,pd.to_datetime(x_forecast_date)),pd.DataFrame(x_forecast_likecount,pd.to_datetime(x_forecast_date)),pd.DataFrame(x_forecast_retweetscore,pd.to_datetime(x_forecast_date))],axis=1))

# %%
x_forecast.columns=["sentimentScore","likesCount","retweetCount"]

# %%
x_forecast
# Out:
#             sentimentScore  likesCount  retweetCount
# 2022-07-27            -0.8      233433         34534

# %%
X_value = X_scaler.transform(x_forecast) #Predict for give above inputs

# %%
forecast = rfC_model.predict(X_value)
forecast
# Out:
# array([1], dtype=int64)

# %%
x_forecast_sentimentscore = np.array([0.9])
x_forecast_likecount=np.array([3205])
x_forecast_retweetscore=np.array([5345])
x_forecast_date=["2022-07-27"]

# %%
x_F_retweetcount = pd.DataFrame(x_forecast_retweetscore,pd.to_datetime(x_forecast_date))
x_forecast = pd.DataFrame(pd.concat([pd.DataFrame(x_forecast_sentimentscore,pd.to_datetime(x_forecast_date)),pd.DataFrame(x_forecast_likecount,pd.to_datetime(x_forecast_date)),pd.DataFrame(x_forecast_retweetscore,pd.to_datetime(x_forecast_date))],axis=1))
x_forecast.columns=["sentimentScore","likesCount","retweetCount"]
x_forecast
# Out:
#             sentimentScore  likesCount  retweetCount
# 2022-07-27             0.9        3205          5345

# %%
X_value = X_scaler.transform(x_forecast) #Predict for give above inputs

# %%
forecast = rfC_model.predict(X_value)
forecast
# Out:
# array([0], dtype=int64)

# %% [markdown]
# # Using saved Model

# %%
loaded_model = pickle.load(open(filename, 'rb'))

# %%
forecast = loaded_model.predict(X_value)
forecast
# Out:
# array([1], dtype=int64)
