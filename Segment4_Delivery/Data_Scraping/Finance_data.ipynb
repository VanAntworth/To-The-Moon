# %%
import time
import datetime
import pandas as pd

# %%
def get_price(stock):
    period1 = int(time.mktime(datetime.datetime(2010,1,1,23,59).timetuple()))
    period2 = int(time.mktime(datetime.datetime(2022,7,25,23,59).timetuple()))
    interval = '1d'
    query_string = f'https://query1.finance.yahoo.com/v7/finance/download/{stock}?period1={period1}&period2={period2}&interval={interval}&events=history&includeAdjustedClose=true'
    return query_string

# %%
stock = "DOGE-USD"
doge_price = pd.read_csv(get_price(stock))
doge_price
# Out:
#             Date      Open      High       Low     Close  Adj Close     Volume
# 0     2017-11-09  0.001207  0.001415  0.001181  0.001415   0.001415    6259550
# 1     2017-11-10  0.001421  0.001431  0.001125  0.001163   0.001163    4246520
# 2     2017-11-11  0.001146  0.001257  0.001141  0.001201   0.001201    2231080
# 3     2017-11-12  0.001189  0.001210  0.001002  0.001038   0.001038    3288960
# 4     2017-11-13  0.001046  0.001212  0.001019  0.001211   0.001211    2481270
# ...          ...       ...       ...       ...       ...        ...        ...
# 1716  2022-07-22  0.069970  0.071270  0.067003  0.067563   0.067563  479456105
# 1717  2022-07-23  0.067531  0.069332  0.066277  0.068124   0.068124  427922351
# 1718  2022-07-24  0.068116  0.068854  0.067589  0.067724   0.067724  369141492
# 1719  2022-07-25  0.067716  0.067880  0.062306  0.062306   0.062306  448572441
# 1720  2022-07-26  0.062319  0.062512  0.060425  0.062512   0.062512  416488015
#
# [1721 rows x 7 columns]

# %%
stock = "TSLA-USD"
tslaUsd_price = pd.read_csv(get_price(stock))
tslaUsd_price
# Out:
#            Date      Open      High       Low     Close  Adj Close  Volume
# 0    2020-11-06  1.046114  1.200094  0.826810  1.109129   1.109129  111066
# 1    2020-11-07  1.109129  1.200629  0.827261  1.097126   1.097126  129844
# 2    2020-11-08  1.097126  1.098143  1.062400  1.079512   1.079512  133412
# 3    2020-11-09  1.079512  1.080015  1.070853  1.077403   1.077403  182625
# 4    2020-11-10  1.077403  1.200757  0.827330  1.071106   1.071106  175186
# ..          ...       ...       ...       ...       ...        ...     ...
# 623  2022-07-22  1.286112  1.324757  1.272755  1.272755   1.272755   70602
# 624  2022-07-23  1.272755  1.307493  1.267588  1.297282   1.297282   84930
# 625  2022-07-24  1.297279  1.306783  1.284001  1.292568   1.292568   69599
# 626  2022-07-25  1.292571  1.293533  0.940044  1.250292   1.250292   99431
# 627  2022-07-26  1.250298  1.250298  1.186282  1.196867   1.196867  116361
#
# [628 rows x 7 columns]

# %%
stock = "TSLA"
tesla_price = pd.read_csv(get_price(stock))
tesla_price
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29    3.800000    5.000000    3.508000    4.778000    4.778000
# 1     2010-06-30    5.158000    6.084000    4.660000    4.766000    4.766000
# 2     2010-07-01    5.000000    5.184000    4.054000    4.392000    4.392000
# 3     2010-07-02    4.600000    4.620000    3.742000    3.840000    3.840000
# 4     2010-07-06    4.000000    4.000000    3.166000    3.222000    3.222000
# ...          ...         ...         ...         ...         ...         ...
# 3034  2022-07-19  735.000000  741.419983  710.929993  736.590027  736.590027
# 3035  2022-07-20  740.349976  751.989990  730.450012  742.500000  742.500000
# 3036  2022-07-21  765.320007  819.799988  764.599976  815.119995  815.119995
# 3037  2022-07-22  828.659973  842.359985  812.140015  816.729980  816.729980
# 3038  2022-07-25  816.650024  822.440002  802.200012  805.299988  805.299988
#
#         Volume
# 0     93831500
# 1     85935500
# 2     41094000
# 3     25699000
# 4     34334500
# ...        ...
# 3034  26963400
# 3035  29621400
# 3036  47344100
# 3037  34421200
# 3038  21357800
#
# [3039 rows x 7 columns]

# %%
stock = "TWTR"
twitter_price = pd.read_csv(get_price(stock))
twitter_price
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2013-11-07  45.099998  50.090000  44.000000  44.900002  44.900002
# 1     2013-11-08  45.930000  46.939999  40.689999  41.650002  41.650002
# 2     2013-11-11  40.500000  43.000000  39.400002  42.900002  42.900002
# 3     2013-11-12  43.660000  43.779999  41.830002  41.900002  41.900002
# 4     2013-11-13  41.029999  42.869999  40.759998  42.599998  42.599998
# ...          ...        ...        ...        ...        ...        ...
# 2187  2022-07-19  38.509998  40.500000  38.500000  39.490002  39.490002
# 2188  2022-07-20  39.560001  40.009998  38.820000  39.599998  39.599998
# 2189  2022-07-21  39.500000  40.099998  39.119999  39.520000  39.520000
# 2190  2022-07-22  38.900002  40.180000  38.709999  39.840000  39.840000
# 2191  2022-07-25  39.230000  39.599998  38.740002  39.240002  39.240002
#
#          Volume
# 0     117701600
# 1      27925300
# 2      16113900
# 3       6316700
# 4       8688300
# ...         ...
# 2187   37491800
# 2188   13946400
# 2189   11409800
# 2190   25163800
# 2191   10395600
#
# [2192 rows x 7 columns]

# %%
#stock = "spaceX"
#spaceX_price = pd.read_csv(get_price(stock))
#spaceX_price

# %%
doge_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1721 entries, 0 to 1720
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1721 non-null   object
#  1   Open       1721 non-null   float64
#  2   High       1721 non-null   float64
#  3   Low        1721 non-null   float64
#  4   Close      1721 non-null   float64
#  5   Adj Close  1721 non-null   float64
#  6   Volume     1721 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 94.2+ KB

# %%
doge_price.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
doge_price['Date'] = pd.to_datetime(doge_price['Date'], format='%Y-%m-%d')
twitter_price['Date'] = pd.to_datetime(twitter_price['Date'], format='%Y-%m-%d')
tesla_price['Date'] = pd.to_datetime(tesla_price['Date'], format='%Y-%m-%d')

# %%
doge_price.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
twitter_price.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
tesla_price.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
tesla_price['financeType']='tesla'
twitter_price['financeType']='twitter'
doge_price['financeType']='doge'

df_finance_tostore = pd.concat([tesla_price, twitter_price, doge_price],axis=0,ignore_index=False)

# %%
df_finance_tostore.rename(columns = {'Date':'date','Open':'open','High':'high','Low':'low','Close':'close','Adj Close':'adjustedClose','Volume':'volume'}, inplace = True)

# %%
df_finance_tostore = df_finance_tostore[['financeType','date','open','high','low','close','adjustedClose','volume']]

# %%
# Database related all the code is moved to this file
# %run -i "SqlConn.py"
#importing local py file
import SqlConn

# %%
#Insert Finance Data 
try:
    SqlConn.insertFinanceData(df_finance_tostore)
    print("Data transfer Done")
except BaseException as err:
    print(err)
# Out:
# Data transfer Done
