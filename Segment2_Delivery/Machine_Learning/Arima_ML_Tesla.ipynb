# %%
# %matplotlib inline
import pandas as pd 
import matplotlib 
import matplotlib.pyplot as plt
import datetime
import numpy as np
from datetime import datetime,timedelta

from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm

from sklearn.preprocessing import StandardScaler
from pmdarima.arima.utils import ndiffs
from pmdarima import auto_arima

# %%
# Database related all the code is moved to this file
# %run -i "SqlConn.py"
#importing local py file
import SqlConn

# %%
#Fetch only Finance Data
try:
    df_dbFinanceData = SqlConn.fetchFinanceData("tesla")
    print("Data transfer Done")
except BaseException as err:
    print(err)
# Out:
# Data transfer Done

# %%
#Fetch Tweets and Sentiment data - Join from Tweet and Sentiment tables
try:
    df_dbSentimentData = SqlConn.fetchTweetSentimentForModelling("tesla")
    print("Data transfer Done")
except BaseException as err:
    print(err)
# Out:
# Data transfer Done

# %%
df_dbFinanceData["date"] = pd.to_datetime(df_dbFinanceData["date"])
df_dbFinanceData.set_index("date", inplace=True)
df_dbFinanceData
# Out:
#            financeType        open        high         low       close  \
# date
# 2010-06-29       tesla    3.800000    5.000000    3.508000    4.778000
# 2010-06-30       tesla    5.158000    6.084000    4.660000    4.766000
# 2010-07-01       tesla    5.000000    5.184000    4.054000    4.392000
# 2010-07-02       tesla    4.600000    4.620000    3.742000    3.840000
# 2010-07-06       tesla    4.000000    4.000000    3.166000    3.222000
# ...                ...         ...         ...         ...         ...
# 2022-07-06       tesla  692.340027  703.690002  681.559998  695.200012
# 2022-07-07       tesla  701.760010  736.090027  696.630005  733.630005
# 2022-07-08       tesla  727.000000  764.940002  723.479980  752.289978
# 2022-07-11       tesla  756.309998  759.190002  700.880005  703.030029
# 2022-07-12       tesla  710.539978  719.320007  685.109985  699.210022
#
#             adjustedClose    volume
# date
# 2010-06-29       4.778000  93831500
# 2010-06-30       4.766000  85935500
# 2010-07-01       4.392000  41094000
# 2010-07-02       3.840000  25699000
# 2010-07-06       3.222000  34334500
# ...                   ...       ...
# 2022-07-06     695.200012  23951200
# 2022-07-07     733.630005  27310200
# 2022-07-08     752.289978  33343700
# 2022-07-11     703.030029  33080400
# 2022-07-12     699.210022  29310300
#
# [3030 rows x 7 columns]

# %%
df_dbSentimentData["date"] = pd.to_datetime(df_dbSentimentData["date"])
df_dbSentimentData.set_index("date",inplace=True)
df_dbSentimentData
# Out:
#                         tweetID financeType  \
# date
# 2012-01-11   156927468836630528       tesla
# 2012-01-13   157700726515183616       tesla
# 2012-01-17   159330976378519552       tesla
# 2012-01-17   159396536621596672       tesla
# 2012-02-10   168022238061268992       tesla
# ...                         ...         ...
# 2022-07-07  1545166492408328192       tesla
# 2022-07-07  1545166492408328192       tesla
# 2022-07-12  1546666417759653888       tesla
# 2022-07-12  1546666417759653888       tesla
# 2022-07-12  1546666417759653888       tesla
#
#                                                      fullText  replyCount  \
# date
# 2012-01-11  The exec conf room at Tesla used to be called ...        32.0
# 2012-01-13  A Tesla Roadster just passed the 100,000 mile ...         5.0
# 2012-01-17  Will communicate better in the future. Too man...        44.0
# 2012-01-17  That's not just paranoia (a healthy trait at t...        23.0
# 2012-02-10                                Tesla Model X video        12.0
# ...                                                       ...         ...
# 2022-07-07  Super fired up for future product development ...         NaN
# 2022-07-07  Super fired up for future product development ...         NaN
# 2022-07-12  Tesla’s automatic cabin overheat protection sh...         NaN
# 2022-07-12  Tesla’s automatic cabin overheat protection sh...         NaN
# 2022-07-12  Tesla’s automatic cabin overheat protection sh...         NaN
#
#             likesCount  retweetCount  sentimentScore sentiment  adjustedClose  \
# date
# 2012-01-11         315            67        0.350000  Positive       5.646000
# 2012-01-13          15            51        0.250000  Positive       4.558000
# 2012-01-17         163            43        0.150000  Positive       5.320000
# 2012-01-17          16            14        0.175000  Positive       5.320000
# 2012-02-10          16            47        0.000000   Neutral       6.220000
# ...                ...           ...             ...       ...            ...
# 2022-07-07      137575          8685        0.333333  Positive      38.790001
# 2022-07-07      137575          8685        0.333333  Positive     733.630005
# 2022-07-12       56429          4023        0.100000  Positive       0.060087
# 2022-07-12       56429          4023        0.100000  Positive      34.060001
# 2022-07-12       56429          4023        0.100000  Positive     699.210022
#
#                volume
# date
# 2012-01-11    3361500
# 2012-01-13   27502000
# 2012-01-17   23258000
# 2012-01-17   23258000
# 2012-02-10    9371000
# ...               ...
# 2022-07-07   13214900
# 2022-07-07   27310200
# 2022-07-12  298462083
# 2022-07-12   29539400
# 2022-07-12   29310300
#
# [3383 rows x 10 columns]

# %%
df_dbFinanceData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3030 entries, 2010-06-29 to 2022-07-12
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   financeType    3030 non-null   object
#  1   open           3030 non-null   float64
#  2   high           3030 non-null   float64
#  3   low            3030 non-null   float64
#  4   close          3030 non-null   float64
#  5   adjustedClose  3030 non-null   float64
#  6   volume         3030 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 189.4+ KB

# %%
df_dbFinanceData['adjustedClose'].plot(figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_dbFinanceData.index
# Out:
# DatetimeIndex(['2010-06-29', '2010-06-30', '2010-07-01', '2010-07-02',
#                '2010-07-06', '2010-07-07', '2010-07-08', '2010-07-09',
#                '2010-07-12', '2010-07-13',
#                ...
#                '2022-06-28', '2022-06-29', '2022-06-30', '2022-07-01',
#                '2022-07-05', '2022-07-06', '2022-07-07', '2022-07-08',
#                '2022-07-11', '2022-07-12'],
#               dtype='datetime64[ns]', name='date', length=3030, freq=None)

# %%
df_dbFinanceData['adjustedClose'].plot(xlim=['2020-01-01','2022-07-13'],ylim=[0,1400],figsize=(12,4),ls='--',c='green')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
#Resampling to display monthly data
df_resampled = df_dbFinanceData['adjustedClose'].resample(rule='M')
df_resampled.max().plot(kind='bar',figsize=(16,5))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_filteredData = df_dbFinanceData.loc['2020-01-01':'2022-7-13']
df_filteredData.index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2022-06-28', '2022-06-29', '2022-06-30', '2022-07-01',
#                '2022-07-05', '2022-07-06', '2022-07-07', '2022-07-08',
#                '2022-07-11', '2022-07-12'],
#               dtype='datetime64[ns]', name='date', length=636, freq=None)

# %%
#Nov 2021 was the month when Tesla had highest value - checked over internet and found Nov 4 2021 was marked as highest price for Tesla stocks.
df_filteredData['adjustedClose'].resample(rule='M').max().plot(kind='bar', figsize=(16,4))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_filteredData['adjustedClose'].plot(xlim=['2021-11-01','2021-11-30'],ylim=[0,1300],figsize=(12,4),ls='--',c='green')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# checked over internet and found Nov 4 2021 was marked as highest price for Tesla stocks.
df_filteredData.loc['2021-11-01':'2021-11-30']['adjustedClose'].plot(kind='bar',figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
#5 and 15 days rolling mean
df_dbFinanceData["adjustedClose:5 Days Rolling mean"]=df_dbFinanceData['adjustedClose'].rolling(5).mean() 
df_dbFinanceData["adjustedClose:15 Days Rolling mean"]=df_dbFinanceData['adjustedClose'].rolling(15).mean() 
df_dbFinanceData["adjustedClose:60 Days Rolling mean"]=df_dbFinanceData['adjustedClose'].rolling(60).mean() 
df_dbFinanceData
# Out:
#            financeType        open        high         low       close  \
# date
# 2010-06-29       tesla    3.800000    5.000000    3.508000    4.778000
# 2010-06-30       tesla    5.158000    6.084000    4.660000    4.766000
# 2010-07-01       tesla    5.000000    5.184000    4.054000    4.392000
# 2010-07-02       tesla    4.600000    4.620000    3.742000    3.840000
# 2010-07-06       tesla    4.000000    4.000000    3.166000    3.222000
# ...                ...         ...         ...         ...         ...
# 2022-07-06       tesla  692.340027  703.690002  681.559998  695.200012
# 2022-07-07       tesla  701.760010  736.090027  696.630005  733.630005
# 2022-07-08       tesla  727.000000  764.940002  723.479980  752.289978
# 2022-07-11       tesla  756.309998  759.190002  700.880005  703.030029
# 2022-07-12       tesla  710.539978  719.320007  685.109985  699.210022
#
#             adjustedClose    volume  adjustedClose:15 Days Rolling mean  \
# date
# 2010-06-29       4.778000  93831500                                 NaN
# 2010-06-30       4.766000  85935500                                 NaN
# 2010-07-01       4.392000  41094000                                 NaN
# 2010-07-02       3.840000  25699000                                 NaN
# 2010-07-06       3.222000  34334500                                 NaN
# ...                   ...       ...                                 ...
# 2022-07-06     695.200012  23951200                          692.051998
# 2022-07-07     733.630005  27310200                          696.782666
# 2022-07-08     752.289978  33343700                          700.335331
# 2022-07-11     703.030029  33080400                          704.584001
# 2022-07-12     699.210022  29310300                          707.846000
#
#             adjustedClose:5 Days Rolling mean      emw0.2      emw0.4  \
# date
# 2010-06-29                                NaN    4.778000    4.778000
# 2010-06-30                                NaN    4.775600    4.773200
# 2010-07-01                                NaN    4.698880    4.620720
# 2010-07-02                                NaN    4.527104    4.308432
# 2010-07-06                           4.199600    4.266083    3.873859
# ...                                       ...         ...         ...
# 2022-07-06                         687.015991  694.657106  693.169146
# 2022-07-07                         696.647998  702.451686  709.353490
# 2022-07-08                         712.421997  712.419344  726.528085
# 2022-07-11                         716.670007  710.541481  717.128863
# 2022-07-12                         716.672009  708.275189  709.961326
#
#              emw_span5  adjustedClose_first_diff  \
# date
# 2010-06-29    4.778000                       NaN
# 2010-06-30    4.769000                 -0.012000
# 2010-07-01    4.508000                 -0.374000
# 2010-07-02    4.057100                 -0.552000
# 2010-07-06    3.498066                 -0.618000
# ...                ...                       ...
# 2022-07-06  694.535709                 -4.000000
# 2022-07-07  720.598573                 38.429993
# 2022-07-08  741.726176                 18.659973
# 2022-07-11  715.928745                -49.259949
# 2022-07-12  704.782930                 -3.820007
#
#             adjustedClose:45 Days Rolling mean  \
# date
# 2010-06-29                                 NaN
# 2010-06-30                                 NaN
# 2010-07-01                                 NaN
# 2010-07-02                                 NaN
# 2010-07-06                                 NaN
# ...                                        ...
# 2022-07-06                          731.086443
# 2022-07-07                          727.323999
# 2022-07-08                          723.835998
# 2022-07-11                          718.289555
# 2022-07-12                          714.421332
#
#             adjustedClose:60 Days Rolling mean
# date
# 2010-06-29                                 NaN
# 2010-06-30                                 NaN
# 2010-07-01                                 NaN
# 2010-07-02                                 NaN
# 2010-07-06                                 NaN
# ...                                        ...
# 2022-07-06                          790.372000
# 2022-07-07                          785.507667
# 2022-07-08                          781.780333
# 2022-07-11                          777.048334
# 2022-07-12                          771.662334
#
# [3030 rows x 15 columns]

# %%
#smoothening the line
df_dbFinanceData[['adjustedClose','adjustedClose:5 Days Rolling mean','adjustedClose:15 Days Rolling mean']].plot(figsize=(16,5))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
#smoothening the line
df_dbFinanceData.loc['2020-01-01':'2022-7-13'][['adjustedClose','adjustedClose:5 Days Rolling mean','adjustedClose:15 Days Rolling mean','adjustedClose:60 Days Rolling mean']].plot(figsize=(16,5))

#rolling mean of 5 days is closer compared to 15 days
# Out:
# <AxesSubplot:xlabel='date'>

# %%
#Cummulative moving average
df_dbFinanceData['adjustedClose'].expanding().mean().plot(figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
#exponential weighted moving average
df_dbFinanceData['emw0.2']=df_dbFinanceData['adjustedClose'].ewm(alpha=0.2,adjust=False).mean()
df_dbFinanceData['emw0.4']=df_dbFinanceData['adjustedClose'].ewm(alpha=0.4,adjust=False).mean()
df_dbFinanceData['emw_span5']=df_dbFinanceData['adjustedClose'].ewm(span=2,).mean()

# %%
df_dbFinanceData[['adjustedClose','emw0.2','emw0.4','emw_span5']].plot(xlim=['2021-01-01','2022-7-13'],figsize=(16,5))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_dbFinanceData[['adjustedClose','emw0.2','emw0.4','emw_span5']].plot(xlim=['2021-11-01','2022-7-13'],figsize=(16,5))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# # Applying ARIMA Model

# %%
#Augmented Dickey–Fuller test
def adf_test(series):
    results = adfuller(series)
    print('ADF statistics: {}'.format(results[0]))
    print('P value: {}'.format(results[1]))
    if results[1] < 0.05:
        print("Ho Rejected - data is stationary")
    else:    
        print("Ho Accepted- data is not stationary")

# %%
adf_test(df_dbFinanceData['adjustedClose'])
# Out:
# ADF statistics: -0.3586377728879778
# P value: 0.9167791107833695
# Ho Accepted- data is not stationary

# %%
df_dbFinanceData['adjustedClose_first_diff']=df_dbFinanceData['adjustedClose']-df_dbFinanceData['adjustedClose'].shift(1)

# %%
adf_test(df_dbFinanceData['adjustedClose_first_diff'].dropna())
#d=1
# Out:
# ADF statistics: -10.966950784001796
# P value: 8.058634793412424e-20
# Ho Rejected - data is stationary

# %%
df_dbFinanceData
# Out:
#            financeType        open        high         low       close  \
# date
# 2010-06-29       tesla    3.800000    5.000000    3.508000    4.778000
# 2010-06-30       tesla    5.158000    6.084000    4.660000    4.766000
# 2010-07-01       tesla    5.000000    5.184000    4.054000    4.392000
# 2010-07-02       tesla    4.600000    4.620000    3.742000    3.840000
# 2010-07-06       tesla    4.000000    4.000000    3.166000    3.222000
# ...                ...         ...         ...         ...         ...
# 2022-07-06       tesla  692.340027  703.690002  681.559998  695.200012
# 2022-07-07       tesla  701.760010  736.090027  696.630005  733.630005
# 2022-07-08       tesla  727.000000  764.940002  723.479980  752.289978
# 2022-07-11       tesla  756.309998  759.190002  700.880005  703.030029
# 2022-07-12       tesla  710.539978  719.320007  685.109985  699.210022
#
#             adjustedClose    volume  adjustedClose:15 Days Rolling mean  \
# date
# 2010-06-29       4.778000  93831500                                 NaN
# 2010-06-30       4.766000  85935500                                 NaN
# 2010-07-01       4.392000  41094000                                 NaN
# 2010-07-02       3.840000  25699000                                 NaN
# 2010-07-06       3.222000  34334500                                 NaN
# ...                   ...       ...                                 ...
# 2022-07-06     695.200012  23951200                          692.051998
# 2022-07-07     733.630005  27310200                          696.782666
# 2022-07-08     752.289978  33343700                          700.335331
# 2022-07-11     703.030029  33080400                          704.584001
# 2022-07-12     699.210022  29310300                          707.846000
#
#             adjustedClose:5 Days Rolling mean      emw0.2      emw0.4  \
# date
# 2010-06-29                                NaN    4.778000    4.778000
# 2010-06-30                                NaN    4.775600    4.773200
# 2010-07-01                                NaN    4.698880    4.620720
# 2010-07-02                                NaN    4.527104    4.308432
# 2010-07-06                           4.199600    4.266083    3.873859
# ...                                       ...         ...         ...
# 2022-07-06                         687.015991  694.657106  693.169146
# 2022-07-07                         696.647998  702.451686  709.353490
# 2022-07-08                         712.421997  712.419344  726.528085
# 2022-07-11                         716.670007  710.541481  717.128863
# 2022-07-12                         716.672009  708.275189  709.961326
#
#              emw_span5  adjustedClose_first_diff  \
# date
# 2010-06-29    4.778000                       NaN
# 2010-06-30    4.769000                 -0.012000
# 2010-07-01    4.508000                 -0.374000
# 2010-07-02    4.057100                 -0.552000
# 2010-07-06    3.498066                 -0.618000
# ...                ...                       ...
# 2022-07-06  694.535709                 -4.000000
# 2022-07-07  720.598573                 38.429993
# 2022-07-08  741.726176                 18.659973
# 2022-07-11  715.928745                -49.259949
# 2022-07-12  704.782930                 -3.820007
#
#             adjustedClose:45 Days Rolling mean  \
# date
# 2010-06-29                                 NaN
# 2010-06-30                                 NaN
# 2010-07-01                                 NaN
# 2010-07-02                                 NaN
# 2010-07-06                                 NaN
# ...                                        ...
# 2022-07-06                          731.086443
# 2022-07-07                          727.323999
# 2022-07-08                          723.835998
# 2022-07-11                          718.289555
# 2022-07-12                          714.421332
#
#             adjustedClose:60 Days Rolling mean
# date
# 2010-06-29                                 NaN
# 2010-06-30                                 NaN
# 2010-07-01                                 NaN
# 2010-07-02                                 NaN
# 2010-07-06                                 NaN
# ...                                        ...
# 2022-07-06                          790.372000
# 2022-07-07                          785.507667
# 2022-07-08                          781.780333
# 2022-07-11                          777.048334
# 2022-07-12                          771.662334
#
# [3030 rows x 15 columns]

# %% [markdown]
# # Calculate AR(p), I(d), MA(q)

# %%
#Estimate ARIMA differencing term,
ndiffs(df_dbFinanceData['adjustedClose'],test='adf')
# Out:
# 1

# %%
diff= df_dbFinanceData['adjustedClose'].diff().dropna()
fig,(ax1,ax2)=plt.subplots(1, 2, figsize=(16,4))
ax1.plot(diff)
ax1.set_title("Difference once")
ax2.set_ylim(0, 1)
plot_pacf(diff, ax=ax2)
#p=2
# Out:
# C:\Users\15125\anaconda3\envs\PythonData\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
diff= df_dbFinanceData['adjustedClose'].diff().dropna()
fig,(ax1,ax2)=plt.subplots(1, 2, figsize=(16,4))
ax1.plot(diff)
ax1.set_title("Difference once")
ax2.set_ylim(0, 1)
plot_acf(diff, ax=ax2)
#q=2

# %% [markdown]
# #Other ways to find P and Q

# %%
acf = plot_acf(df_dbFinanceData['adjustedClose_first_diff'].dropna())
#q=2

# %%
acf = plot_pacf(df_dbFinanceData['adjustedClose_first_diff'].dropna())
#p=2
# Out:
# C:\Users\15125\anaconda3\envs\PythonData\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# third way to find p,d,q- using Auto_arima

# %%
stepwise_fit = auto_arima(df_dbFinanceData['adjustedClose'],trace=True,suppress_warnings=True)
stepwise_fit.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=10.59 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=23916.803, Time=0.19 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=23913.452, Time=0.39 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=23913.378, Time=1.11 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=23915.816, Time=0.19 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=23915.337, Time=2.52 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=23915.303, Time=1.47 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=23902.278, Time=6.99 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=23918.050, Time=5.39 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=23916.311, Time=2.03 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=23901.383, Time=6.59 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=23915.240, Time=1.13 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=23917.977, Time=4.77 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=23916.522, Time=1.34 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=23893.564, Time=14.40 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=23841.368, Time=14.69 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=23918.533, Time=6.18 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=17.73 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=23845.598, Time=14.89 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=18.64 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=23919.217, Time=7.04 sec
#  ARIMA(5,1,3)(0,0,0)[0] intercept   : AIC=23844.830, Time=16.88 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=23840.114, Time=6.83 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=inf, Time=7.48 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=23917.571, Time=2.28 sec
#  ARIMA(5,1,2)(0,0,0)[0]             : AIC=inf, Time=13.61 sec
#  ARIMA(4,1,3)(0,0,0)[0]             : AIC=23844.572, Time=8.99 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=23917.007, Time=2.05 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=inf, Time=10.99 sec
#  ARIMA(5,1,1)(0,0,0)[0]             : AIC=23918.306, Time=2.94 sec
#  ARIMA(5,1,3)(0,0,0)[0]             : AIC=23843.872, Time=9.95 sec
#
# Best model:  ARIMA(4,1,2)(0,0,0)[0]
# Total fit time: 220.489 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3030
# Model:               SARIMAX(4, 1, 2)   Log Likelihood              -11913.057
# Date:                Mon, 18 Jul 2022   AIC                          23840.114
# Time:                        10:47:07   BIC                          23882.226
# Sample:                             0   HQIC                         23855.255
#                                - 3030
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.1588      0.011   -107.115      0.000      -1.180      -1.138
# ar.L2         -0.9539      0.014    -69.001      0.000      -0.981      -0.927
# ar.L3         -0.0503      0.011     -4.740      0.000      -0.071      -0.029
# ar.L4          0.0459      0.007      6.487      0.000       0.032       0.060
# ma.L1          1.1329      0.007    151.321      0.000       1.118       1.148
# ma.L2          0.9229      0.008    118.057      0.000       0.908       0.938
# sigma2       152.6233      1.030    148.153      0.000     150.604     154.642
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):            111100.21
# Prob(Q):                              0.94   Prob(JB):                         0.00
# Heteroskedasticity (H):             892.49   Skew:                            -0.06
# Prob(H) (two-sided):                  0.00   Kurtosis:                        32.67
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# # Fitting the Model and Predicting

# %%
df_arima = df_dbFinanceData.copy()
df_arima.drop(columns=['financeType'],inplace=True)
train_dataset_end=datetime(2021,7,31)
test_dataset_end=datetime(2022,7,31)

# %%
train_data=df_arima[:train_dataset_end]
test_data=df_arima[train_dataset_end+timedelta(days=1):test_dataset_end]

# %%
##prediction
pred_start_date=test_data.index[0]
pred_end_date=test_data.index[-1]

# %%
train_data
# Out:
#                   open        high         low       close  adjustedClose  \
# date
# 2010-06-29    3.800000    5.000000    3.508000    4.778000       4.778000
# 2010-06-30    5.158000    6.084000    4.660000    4.766000       4.766000
# 2010-07-01    5.000000    5.184000    4.054000    4.392000       4.392000
# 2010-07-02    4.600000    4.620000    3.742000    3.840000       3.840000
# 2010-07-06    4.000000    4.000000    3.166000    3.222000       3.222000
# ...                ...         ...         ...         ...            ...
# 2021-07-26  650.969971  668.200012  647.109985  657.619995     657.619995
# 2021-07-27  663.400024  666.500000  627.239990  644.780029     644.780029
# 2021-07-28  647.000000  654.969971  639.400024  646.979980     646.979980
# 2021-07-29  649.789978  683.690002  648.799988  677.349976     677.349976
# 2021-07-30  671.760010  697.530029  669.000000  687.200012     687.200012
#
#               volume  adjustedClose:15 Days Rolling mean  \
# date
# 2010-06-29  93831500                                 NaN
# 2010-06-30  85935500                                 NaN
# 2010-07-01  41094000                                 NaN
# 2010-07-02  25699000                                 NaN
# 2010-07-06  34334500                                 NaN
# ...              ...                                 ...
# 2021-07-26  25336600                          655.246663
# 2021-07-27  32813300                          654.259998
# 2021-07-28  16006600                          654.415328
# 2021-07-29  30394600                          656.051327
# 2021-07-30  29656400                          658.067993
#
#             adjustedClose:5 Days Rolling mean      emw0.2      emw0.4  \
# date
# 2010-06-29                                NaN    4.778000    4.778000
# 2010-06-30                                NaN    4.775600    4.773200
# 2010-07-01                                NaN    4.698880    4.620720
# 2010-07-02                                NaN    4.527104    4.308432
# 2010-07-06                           4.199600    4.266083    3.873859
# ...                                       ...         ...         ...
# 2021-07-26                         653.209998  653.433650  652.344990
# 2021-07-27                         650.066003  651.702925  649.319006
# 2021-07-28                         648.404004  650.758336  648.383395
# 2021-07-29                         654.021997  656.076664  659.970028
# 2021-07-30                         662.785998  662.301334  670.862021
#
#              emw_span5  adjustedClose_first_diff  \
# date
# 2010-06-29    4.778000                       NaN
# 2010-06-30    4.769000                 -0.012000
# 2010-07-01    4.508000                 -0.374000
# 2010-07-02    4.057100                 -0.552000
# 2010-07-06    3.498066                 -0.618000
# ...                ...                       ...
# 2021-07-26  653.757041                 14.239990
# 2021-07-27  647.772366                -12.839966
# 2021-07-28  647.244109                  2.199951
# 2021-07-29  667.314687                 30.369996
# 2021-07-30  680.571570                  9.850036
#
#             adjustedClose:45 Days Rolling mean  \
# date
# 2010-06-29                                 NaN
# 2010-06-30                                 NaN
# 2010-07-01                                 NaN
# 2010-07-02                                 NaN
# 2010-07-06                                 NaN
# ...                                        ...
# 2021-07-26                          636.554667
# 2021-07-27                          637.974668
# 2021-07-28                          638.875556
# 2021-07-29                          640.490222
# 2021-07-30                          642.002889
#
#             adjustedClose:60 Days Rolling mean
# date
# 2010-06-29                                 NaN
# 2010-06-30                                 NaN
# 2010-07-01                                 NaN
# 2010-07-02                                 NaN
# 2010-07-06                                 NaN
# ...                                        ...
# 2021-07-26                          633.704168
# 2021-07-27                          632.626501
# 2021-07-28                          631.994501
# 2021-07-29                          632.057001
# 2021-07-30                          632.328001
#
# [2792 rows x 14 columns]

# %%
test_data
# Out:
#                   open        high         low       close  adjustedClose  \
# date
# 2021-08-02  700.000000  726.940002  698.400024  709.669983     709.669983
# 2021-08-03  719.000000  722.650024  701.010010  709.739990     709.739990
# 2021-08-04  711.000000  724.900024  708.929993  710.919983     710.919983
# 2021-08-05  716.000000  720.950012  711.409973  714.630005     714.630005
# 2021-08-06  711.900024  716.330017  697.630005  699.099976     699.099976
# ...                ...         ...         ...         ...            ...
# 2022-07-06  692.340027  703.690002  681.559998  695.200012     695.200012
# 2022-07-07  701.760010  736.090027  696.630005  733.630005     733.630005
# 2022-07-08  727.000000  764.940002  723.479980  752.289978     752.289978
# 2022-07-11  756.309998  759.190002  700.880005  703.030029     703.030029
# 2022-07-12  710.539978  719.320007  685.109985  699.210022     699.210022
#
#               volume  adjustedClose:15 Days Rolling mean  \
# date
# 2021-08-02  33615800                          659.665991
# 2021-08-03  21620300                          662.412659
# 2021-08-04  17002600                          666.248657
# 2021-08-05  12919600                          670.517326
# 2021-08-06  15623000                          674.175993
# ...              ...                                 ...
# 2022-07-06  23951200                          692.051998
# 2022-07-07  27310200                          696.782666
# 2022-07-08  33343700                          700.335331
# 2022-07-11  33080400                          704.584001
# 2022-07-12  29310300                          707.846000
#
#             adjustedClose:5 Days Rolling mean      emw0.2      emw0.4  \
# date
# 2021-08-02                         673.195996  671.775064  686.385206
# 2021-08-03                         686.187988  679.368049  695.727120
# 2021-08-04                         698.975989  685.678436  701.804265
# 2021-08-05                         706.431995  691.468750  706.934561
# 2021-08-06                         708.811987  692.994995  703.800727
# ...                                       ...         ...         ...
# 2022-07-06                         687.015991  694.657106  693.169146
# 2022-07-07                         696.647998  702.451686  709.353490
# 2022-07-08                         712.421997  712.419344  726.528085
# 2022-07-11                         716.670007  710.541481  717.128863
# 2022-07-12                         716.672009  708.275189  709.961326
#
#              emw_span5  adjustedClose_first_diff  \
# date
# 2021-08-02  699.970512                 22.469971
# 2021-08-03  706.483497                  0.070007
# 2021-08-04  709.441154                  1.179993
# 2021-08-05  712.900388                  3.710022
# 2021-08-06  703.700113                -15.530029
# ...                ...                       ...
# 2022-07-06  694.535709                 -4.000000
# 2022-07-07  720.598573                 38.429993
# 2022-07-08  741.726176                 18.659973
# 2022-07-11  715.928745                -49.259949
# 2022-07-12  704.782930                 -3.820007
#
#             adjustedClose:45 Days Rolling mean  \
# date
# 2021-08-02                          643.754445
# 2021-08-03                          645.632667
# 2021-08-04                          647.566444
# 2021-08-05                          650.000000
# 2021-08-06                          652.805777
# ...                                        ...
# 2022-07-06                          731.086443
# 2022-07-07                          727.323999
# 2022-07-08                          723.835998
# 2022-07-11                          718.289555
# 2022-07-12                          714.421332
#
#             adjustedClose:60 Days Rolling mean
# date
# 2021-08-02                          633.096834
# 2021-08-03                          633.719668
# 2021-08-04                          635.084334
# 2021-08-05                          636.708168
# 2021-08-06                          638.528334
# ...                                        ...
# 2022-07-06                          790.372000
# 2022-07-07                          785.507667
# 2022-07-08                          781.780333
# 2022-07-11                          777.048334
# 2022-07-12                          771.662334
#
# [238 rows x 14 columns]

# %%
startdate=datetime(2019,1,1)
plt.figure(figsize=(16,5))
plt.grid(True)
plt.xlabel("Date")
plt.ylabel("Adjusted Closing Price")
plt.plot(train_data[startdate:],'blue', label="training data")
plt.plot(test_data, 'green' , label="testing data")
#plt.legend(loc="upper left")
# Out:
# [<matplotlib.lines.Line2D at 0x25567e22c10>,
#  <matplotlib.lines.Line2D at 0x25567e22b80>,
#  <matplotlib.lines.Line2D at 0x25567e22d00>,
#  <matplotlib.lines.Line2D at 0x25567e22e20>,
#  <matplotlib.lines.Line2D at 0x25567e22f40>,
#  <matplotlib.lines.Line2D at 0x25567e310a0>,
#  <matplotlib.lines.Line2D at 0x25567e311c0>,
#  <matplotlib.lines.Line2D at 0x25567e312e0>,
#  <matplotlib.lines.Line2D at 0x25567e31400>,
#  <matplotlib.lines.Line2D at 0x25567e31520>,
#  <matplotlib.lines.Line2D at 0x25567e31640>,
#  <matplotlib.lines.Line2D at 0x25567e31760>]

# %% [markdown]
# # Train the ARIMA Model

# %% [raw]
# # - Scenario 1 - (p,d,q) = (2,1,2) - Currently executed
# # - Scenario 1 - (p,d,q) = (4,1,2) - Change the order to try other best parameter set as per Auto-Arima

# %%
model_ARIMA=sm.tsa.arima.ARIMA(train_data['adjustedClose'],order=(4,1,2))
# Out:
# C:\Users\15125\anaconda3\envs\PythonData\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\15125\anaconda3\envs\PythonData\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\15125\anaconda3\envs\PythonData\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
model_ARIMA_fit = model_ARIMA.fit()
# Out:
# C:\Users\15125\anaconda3\envs\PythonData\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\15125\anaconda3\envs\PythonData\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\15125\anaconda3\envs\PythonData\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
model_ARIMA_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:          adjustedClose   No. Observations:                 2792
# Model:                 ARIMA(4, 1, 2)   Log Likelihood               -9565.205
# Date:                Mon, 18 Jul 2022   AIC                          19144.410
# Time:                        23:36:39   BIC                          19185.949
# Sample:                             0   HQIC                         19159.406
#                                - 2792
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.2182      0.007   -180.006      0.000      -1.231      -1.205
# ar.L2         -1.0354      0.009   -119.372      0.000      -1.052      -1.018
# ar.L3         -0.0720      0.007     -9.611      0.000      -0.087      -0.057
# ar.L4          0.0303      0.006      5.449      0.000       0.019       0.041
# ma.L1          1.1638      0.004    265.135      0.000       1.155       1.172
# ma.L2          0.9621      0.004    238.527      0.000       0.954       0.970
# sigma2        55.4660      0.331    167.413      0.000      54.817      56.115
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):            204269.02
# Prob(Q):                              0.85   Prob(JB):                         0.00
# Heteroskedasticity (H):             405.31   Skew:                             0.86
# Prob(H) (two-sided):                  0.00   Kurtosis:                        44.88
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
model_ARIMA_fit.resid.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
resids = pd.DataFrame(model_ARIMA_fit.resid)
fig, (ax1, ax2) = plt.subplots(1 ,2, figsize=(16,4))
ax1.plot(resids)
ax2.hist(resids, density=True)
# Out:
# (array([1.88277450e-05, 1.12966470e-04, 2.63588430e-04, 1.18614793e-03,
#         4.90839312e-02, 1.31794215e-03, 4.70693625e-04, 7.53109799e-05,
#         1.88277450e-05, 1.88277450e-05]),
#  array([-85.68725154, -66.66393306, -47.64061457, -28.61729609,
#          -9.59397761,   9.42934088,  28.45265936,  47.47597785,
#          66.49929633,  85.52261482, 104.5459333 ]),
#  <BarContainer object of 10 artists>)

# %%
##prediction
pred_start_date=pd.to_datetime(test_data.index[0])
pred_end_date=pd.to_datetime(test_data.index[-1])
print(pred_start_date)
print(pred_end_date)
# Out:
# 2021-08-02 00:00:00
# 2022-07-12 00:00:00

# %%
-len(train_data)
# Out:
# -2792

# %%
from statsmodels.graphics.tsaplots import plot_predict
adjustedCloseByArima_pred =model_ARIMA_fit.predict(start=len(train_data),end=(len(train_data) + len(test_data)-1)) 
adjustedCloseByArima_predictions = model_ARIMA_fit.get_prediction(start = -len(test_data))
residuals = test_data['adjustedClose']-adjustedCloseByArima_pred
print("Predicted Adjustclose Values")
print(adjustedCloseByArima_pred)
plot_predict(model_ARIMA_fit, start=1, end=60,dynamic=False)
# Out:
# C:\Users\15125\anaconda3\envs\PythonData\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# Predicted Adjustclose Values
# 2792    687.551030
# 2793    690.047568
# 2794    686.854619
# 2795    688.432709
# 2796    689.647149
#            ...
# 3025    688.347442
# 3026    688.348850
# 3027    688.350059
# 3028    688.347399
# 3029    688.349197
# Name: predicted_mean, Length: 238, dtype: float64

# %%
df_yPred = adjustedCloseByArima_predictions.summary_frame(alpha=0.10)

# Extract prediction mean
mean_forecast = adjustedCloseByArima_predictions.predicted_mean

# Get confidence intervals of predictions
confidence_intervals = adjustedCloseByArima_predictions.conf_int()
confidence_intervals
# Out:
#             lower adjustedClose  upper adjustedClose
# date
# 2020-08-20           365.532276           394.726148
# 2020-08-21           383.322603           412.516474
# 2020-08-24           392.095059           421.288930
# 2020-08-25           392.297676           421.491547
# 2020-08-26           389.010573           418.204444
# ...                         ...                  ...
# 2021-07-26           634.159987           663.353858
# 2021-07-27           637.124491           666.318362
# 2021-07-28           631.770162           660.964033
# 2021-07-29           635.828393           665.022264
# 2021-07-30           656.759607           685.953478
#
# [238 rows x 2 columns]

# %%
df_yPred.plot(figsize=(16,5))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
d1 = pd.DataFrame(test_data['adjustedClose'])
d2 = pd.DataFrame(mean_forecast)
d2['date'] = d1.index
d2.set_index('date',inplace=True)
df_y_yPred = pd.concat([d1,d2],axis=1)

# %%
df_y_yPred
# Out:
#             adjustedClose  predicted_mean
# date
# 2021-08-02     709.669983      380.129212
# 2021-08-03     709.739990      397.919539
# 2021-08-04     710.919983      406.691995
# 2021-08-05     714.630005      406.894612
# 2021-08-06     699.099976      403.607509
# ...                   ...             ...
# 2022-07-06     695.200012      648.756922
# 2022-07-07     733.630005      651.721427
# 2022-07-08     752.289978      646.367098
# 2022-07-11     703.030029      650.425328
# 2022-07-12     699.210022      671.356542
#
# [238 rows x 2 columns]

# %%
df_y_yPred.plot(figsize=(17,5))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# # Forecasting

# %%
step = 30
fc = model_ARIMA_fit.forecast(step)
lst_fc = list(fc)
lst_fc
# Out:
# C:\Users\15125\anaconda3\envs\PythonData\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# [687.5510301906418,
#  690.0475678718947,
#  686.854618877983,
#  688.4327091252804,
#  689.6471494782261,
#  686.8394974601284,
#  688.7917448319304,
#  689.2810228059028,
#  686.9026989133203,
#  689.0675245472831,
#  688.9168986255509,
#  687.0450631152041,
#  689.2531696445045,
#  688.5779387560583,
#  687.2444574924573,
#  689.3521803921735,
#  688.2809185111826,
#  687.4791193614537,
#  689.3727747758096,
#  688.0372580408921,
#  687.7287044422178,
#  689.3266590950093,
#  687.8531883313658,
#  687.9753133281037,
#  689.227726026829,
#  687.7302251275403,
#  688.2041932989282,
#  689.0908339068013,
#  687.6658556906588,
#  688.4041294958535]

# %%
fc
# Out:
# 2792    687.551030
# 2793    690.047568
# 2794    686.854619
# 2795    688.432709
# 2796    689.647149
# 2797    686.839497
# 2798    688.791745
# 2799    689.281023
# 2800    686.902699
# 2801    689.067525
# 2802    688.916899
# 2803    687.045063
# 2804    689.253170
# 2805    688.577939
# 2806    687.244457
# 2807    689.352180
# 2808    688.280919
# 2809    687.479119
# 2810    689.372775
# 2811    688.037258
# 2812    687.728704
# 2813    689.326659
# 2814    687.853188
# 2815    687.975313
# 2816    689.227726
# 2817    687.730225
# 2818    688.204193
# 2819    689.090834
# 2820    687.665856
# 2821    688.404129
# Name: predicted_mean, dtype: float64

# %%
import datetime
end_date = pred_end_date 

date_future = end_date + datetime.timedelta(41)

df_future_dates = pd.date_range(start=end_date, end=date_future,freq='B')
df_future_dates
# Out:
# DatetimeIndex(['2022-07-12', '2022-07-13', '2022-07-14', '2022-07-15',
#                '2022-07-18', '2022-07-19', '2022-07-20', '2022-07-21',
#                '2022-07-22', '2022-07-25', '2022-07-26', '2022-07-27',
#                '2022-07-28', '2022-07-29', '2022-08-01', '2022-08-02',
#                '2022-08-03', '2022-08-04', '2022-08-05', '2022-08-08',
#                '2022-08-09', '2022-08-10', '2022-08-11', '2022-08-12',
#                '2022-08-15', '2022-08-16', '2022-08-17', '2022-08-18',
#                '2022-08-19', '2022-08-22'],
#               dtype='datetime64[ns]', freq='B')

# %%
df_future_dates
# Out:
# DatetimeIndex(['2022-07-12', '2022-07-13', '2022-07-14', '2022-07-15',
#                '2022-07-18', '2022-07-19', '2022-07-20', '2022-07-21',
#                '2022-07-22', '2022-07-25', '2022-07-26', '2022-07-27',
#                '2022-07-28', '2022-07-29', '2022-08-01', '2022-08-02',
#                '2022-08-03', '2022-08-04', '2022-08-05', '2022-08-08',
#                '2022-08-09', '2022-08-10', '2022-08-11', '2022-08-12',
#                '2022-08-15', '2022-08-16', '2022-08-17', '2022-08-18',
#                '2022-08-19', '2022-08-22'],
#               dtype='datetime64[ns]', freq='B')

# %%
df_combine = pd.DataFrame(df_future_dates,lst_fc)
df_combine.columns=['date']
df_combine
# Out:
#                  date
# 687.551030 2022-07-12
# 690.047568 2022-07-13
# 686.854619 2022-07-14
# 688.432709 2022-07-15
# 689.647149 2022-07-18
# 686.839497 2022-07-19
# 688.791745 2022-07-20
# 689.281023 2022-07-21
# 686.902699 2022-07-22
# 689.067525 2022-07-25
# 688.916899 2022-07-26
# 687.045063 2022-07-27
# 689.253170 2022-07-28
# 688.577939 2022-07-29
# 687.244457 2022-08-01
# 689.352180 2022-08-02
# 688.280919 2022-08-03
# 687.479119 2022-08-04
# 689.372775 2022-08-05
# 688.037258 2022-08-08
# 687.728704 2022-08-09
# 689.326659 2022-08-10
# 687.853188 2022-08-11
# 687.975313 2022-08-12
# 689.227726 2022-08-15
# 687.730225 2022-08-16
# 688.204193 2022-08-17
# 689.090834 2022-08-18
# 687.665856 2022-08-19
# 688.404129 2022-08-22

# %%
df_combine = df_combine.reset_index()
df_combine = df_combine.set_index('date')
df_combine
# Out:
#                  index
# date
# 2022-07-12  687.551030
# 2022-07-13  690.047568
# 2022-07-14  686.854619
# 2022-07-15  688.432709
# 2022-07-18  689.647149
# 2022-07-19  686.839497
# 2022-07-20  688.791745
# 2022-07-21  689.281023
# 2022-07-22  686.902699
# 2022-07-25  689.067525
# 2022-07-26  688.916899
# 2022-07-27  687.045063
# 2022-07-28  689.253170
# 2022-07-29  688.577939
# 2022-08-01  687.244457
# 2022-08-02  689.352180
# 2022-08-03  688.280919
# 2022-08-04  687.479119
# 2022-08-05  689.372775
# 2022-08-08  688.037258
# 2022-08-09  687.728704
# 2022-08-10  689.326659
# 2022-08-11  687.853188
# 2022-08-12  687.975313
# 2022-08-15  689.227726
# 2022-08-16  687.730225
# 2022-08-17  688.204193
# 2022-08-18  689.090834
# 2022-08-19  687.665856
# 2022-08-22  688.404129

# %%
df_combine.rename(columns={"index":"forecasted_mean"},inplace=True)

# %%
df_combine
# Out:
#             forecasted_mean
# date
# 2022-07-12       687.551030
# 2022-07-13       690.047568
# 2022-07-14       686.854619
# 2022-07-15       688.432709
# 2022-07-18       689.647149
# 2022-07-19       686.839497
# 2022-07-20       688.791745
# 2022-07-21       689.281023
# 2022-07-22       686.902699
# 2022-07-25       689.067525
# 2022-07-26       688.916899
# 2022-07-27       687.045063
# 2022-07-28       689.253170
# 2022-07-29       688.577939
# 2022-08-01       687.244457
# 2022-08-02       689.352180
# 2022-08-03       688.280919
# 2022-08-04       687.479119
# 2022-08-05       689.372775
# 2022-08-08       688.037258
# 2022-08-09       687.728704
# 2022-08-10       689.326659
# 2022-08-11       687.853188
# 2022-08-12       687.975313
# 2022-08-15       689.227726
# 2022-08-16       687.730225
# 2022-08-17       688.204193
# 2022-08-18       689.090834
# 2022-08-19       687.665856
# 2022-08-22       688.404129

# %%
test_data
# Out:
#                   open        high         low       close  adjustedClose  \
# date
# 2021-08-02  700.000000  726.940002  698.400024  709.669983     709.669983
# 2021-08-03  719.000000  722.650024  701.010010  709.739990     709.739990
# 2021-08-04  711.000000  724.900024  708.929993  710.919983     710.919983
# 2021-08-05  716.000000  720.950012  711.409973  714.630005     714.630005
# 2021-08-06  711.900024  716.330017  697.630005  699.099976     699.099976
# ...                ...         ...         ...         ...            ...
# 2022-07-06  692.340027  703.690002  681.559998  695.200012     695.200012
# 2022-07-07  701.760010  736.090027  696.630005  733.630005     733.630005
# 2022-07-08  727.000000  764.940002  723.479980  752.289978     752.289978
# 2022-07-11  756.309998  759.190002  700.880005  703.030029     703.030029
# 2022-07-12  710.539978  719.320007  685.109985  699.210022     699.210022
#
#               volume  adjustedClose:15 Days Rolling mean  \
# date
# 2021-08-02  33615800                          659.665991
# 2021-08-03  21620300                          662.412659
# 2021-08-04  17002600                          666.248657
# 2021-08-05  12919600                          670.517326
# 2021-08-06  15623000                          674.175993
# ...              ...                                 ...
# 2022-07-06  23951200                          692.051998
# 2022-07-07  27310200                          696.782666
# 2022-07-08  33343700                          700.335331
# 2022-07-11  33080400                          704.584001
# 2022-07-12  29310300                          707.846000
#
#             adjustedClose:5 Days Rolling mean      emw0.2      emw0.4  \
# date
# 2021-08-02                         673.195996  671.775064  686.385206
# 2021-08-03                         686.187988  679.368049  695.727120
# 2021-08-04                         698.975989  685.678436  701.804265
# 2021-08-05                         706.431995  691.468750  706.934561
# 2021-08-06                         708.811987  692.994995  703.800727
# ...                                       ...         ...         ...
# 2022-07-06                         687.015991  694.657106  693.169146
# 2022-07-07                         696.647998  702.451686  709.353490
# 2022-07-08                         712.421997  712.419344  726.528085
# 2022-07-11                         716.670007  710.541481  717.128863
# 2022-07-12                         716.672009  708.275189  709.961326
#
#              emw_span5  adjustedClose_first_diff  \
# date
# 2021-08-02  699.970512                 22.469971
# 2021-08-03  706.483497                  0.070007
# 2021-08-04  709.441154                  1.179993
# 2021-08-05  712.900388                  3.710022
# 2021-08-06  703.700113                -15.530029
# ...                ...                       ...
# 2022-07-06  694.535709                 -4.000000
# 2022-07-07  720.598573                 38.429993
# 2022-07-08  741.726176                 18.659973
# 2022-07-11  715.928745                -49.259949
# 2022-07-12  704.782930                 -3.820007
#
#             adjustedClose:45 Days Rolling mean  \
# date
# 2021-08-02                          643.754445
# 2021-08-03                          645.632667
# 2021-08-04                          647.566444
# 2021-08-05                          650.000000
# 2021-08-06                          652.805777
# ...                                        ...
# 2022-07-06                          731.086443
# 2022-07-07                          727.323999
# 2022-07-08                          723.835998
# 2022-07-11                          718.289555
# 2022-07-12                          714.421332
#
#             adjustedClose:60 Days Rolling mean
# date
# 2021-08-02                          633.096834
# 2021-08-03                          633.719668
# 2021-08-04                          635.084334
# 2021-08-05                          636.708168
# 2021-08-06                          638.528334
# ...                                        ...
# 2022-07-06                          790.372000
# 2022-07-07                          785.507667
# 2022-07-08                          781.780333
# 2022-07-11                          777.048334
# 2022-07-12                          771.662334
#
# [238 rows x 14 columns]

# %%
test_data
# Out:
#                   open        high         low       close  adjustedClose  \
# date
# 2021-08-02  700.000000  726.940002  698.400024  709.669983     709.669983
# 2021-08-03  719.000000  722.650024  701.010010  709.739990     709.739990
# 2021-08-04  711.000000  724.900024  708.929993  710.919983     710.919983
# 2021-08-05  716.000000  720.950012  711.409973  714.630005     714.630005
# 2021-08-06  711.900024  716.330017  697.630005  699.099976     699.099976
# ...                ...         ...         ...         ...            ...
# 2022-07-06  692.340027  703.690002  681.559998  695.200012     695.200012
# 2022-07-07  701.760010  736.090027  696.630005  733.630005     733.630005
# 2022-07-08  727.000000  764.940002  723.479980  752.289978     752.289978
# 2022-07-11  756.309998  759.190002  700.880005  703.030029     703.030029
# 2022-07-12  710.539978  719.320007  685.109985  699.210022     699.210022
#
#               volume  adjustedClose:15 Days Rolling mean  \
# date
# 2021-08-02  33615800                          659.665991
# 2021-08-03  21620300                          662.412659
# 2021-08-04  17002600                          666.248657
# 2021-08-05  12919600                          670.517326
# 2021-08-06  15623000                          674.175993
# ...              ...                                 ...
# 2022-07-06  23951200                          692.051998
# 2022-07-07  27310200                          696.782666
# 2022-07-08  33343700                          700.335331
# 2022-07-11  33080400                          704.584001
# 2022-07-12  29310300                          707.846000
#
#             adjustedClose:5 Days Rolling mean      emw0.2      emw0.4  \
# date
# 2021-08-02                         673.195996  671.775064  686.385206
# 2021-08-03                         686.187988  679.368049  695.727120
# 2021-08-04                         698.975989  685.678436  701.804265
# 2021-08-05                         706.431995  691.468750  706.934561
# 2021-08-06                         708.811987  692.994995  703.800727
# ...                                       ...         ...         ...
# 2022-07-06                         687.015991  694.657106  693.169146
# 2022-07-07                         696.647998  702.451686  709.353490
# 2022-07-08                         712.421997  712.419344  726.528085
# 2022-07-11                         716.670007  710.541481  717.128863
# 2022-07-12                         716.672009  708.275189  709.961326
#
#              emw_span5  adjustedClose_first_diff  \
# date
# 2021-08-02  699.970512                 22.469971
# 2021-08-03  706.483497                  0.070007
# 2021-08-04  709.441154                  1.179993
# 2021-08-05  712.900388                  3.710022
# 2021-08-06  703.700113                -15.530029
# ...                ...                       ...
# 2022-07-06  694.535709                 -4.000000
# 2022-07-07  720.598573                 38.429993
# 2022-07-08  741.726176                 18.659973
# 2022-07-11  715.928745                -49.259949
# 2022-07-12  704.782930                 -3.820007
#
#             adjustedClose:45 Days Rolling mean  \
# date
# 2021-08-02                          643.754445
# 2021-08-03                          645.632667
# 2021-08-04                          647.566444
# 2021-08-05                          650.000000
# 2021-08-06                          652.805777
# ...                                        ...
# 2022-07-06                          731.086443
# 2022-07-07                          727.323999
# 2022-07-08                          723.835998
# 2022-07-11                          718.289555
# 2022-07-12                          714.421332
#
#             adjustedClose:60 Days Rolling mean
# date
# 2021-08-02                          633.096834
# 2021-08-03                          633.719668
# 2021-08-04                          635.084334
# 2021-08-05                          636.708168
# 2021-08-06                          638.528334
# ...                                        ...
# 2022-07-06                          790.372000
# 2022-07-07                          785.507667
# 2022-07-08                          781.780333
# 2022-07-11                          777.048334
# 2022-07-12                          771.662334
#
# [238 rows x 14 columns]

# %%
#plot the predictions for validation set
plt.figure(figsize=(16, 8))
plt.plot(test_data["adjustedClose:60 Days Rolling mean"], label='Adj Close Rolling mean 60 days')
#plt.plot(valid, label='Valid')
plt.plot(df_y_yPred["predicted_mean"], label='Prediction mean')
plt.plot(df_combine["forecasted_mean"], label='Forecast mean')
plt.legend()
plt.show()

# %%
mape = np.mean(np.abs(np.array(fc[:1])-np.array(test_data["adjustedClose"]))/np.abs(test_data["adjustedClose"]))
print("MAPE: " + str(mape))
#MEAN ABSOLUTE PERCENTAGE ERROR (MAPE) = 19.9% mean this model as performed Good
# Out:
# MAPE: 0.19924269813614326
